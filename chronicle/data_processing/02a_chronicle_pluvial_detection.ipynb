# %% [markdown]
# # Chronicle Flood Database Intersection with MERIT Hydro dataset
#
# This notebook provides a comprehensive analysis of the Chronicle urban flood dataset, containing over 880,000 flood events worldwide from 2000-2025.

# %% [markdown]
# ## Hydro-merit upa index:

# %%
# ============================================
# 0) IMPORTS
# ============================================
import os
import glob
import math
import pandas as pd
import geopandas as gpd
from shapely import wkt
import numpy as np
import ee
import geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ============================================
# 1) CONFIGURATION
# ============================================
PKL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl"
GEOM_WKT_COL = "geometry_wkt"

# Earth Engine dataset
MERIT_IMAGE_ID = "MERIT/Hydro/v1_0_1"
UPA_BAND = "upa"  # upstream drainage area (km^2)

# Batch settings
BATCH_SIZE = 50
N_BATCHES_TO_RUN = 5000  # Will run 30 NEW batches

# Zonal stats settings
SCALE_M = 90

# Output settings
OUT_DIR = r"D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs"

# The final output filenames (PKL)
OUT_STATS_PKL_ALL = os.path.join(OUT_DIR, "pfdi_stats_ALL_batches.pkl")
OUT_ENRICHED_PKL = os.path.join(OUT_DIR, "chronicle_df_with_pfdi_FULL.pkl")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ============================================
# 2) HELPERS
# ============================================
def ensure_out_dir(path):
    """Create output directory if it doesn't exist."""
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)


def fix_geometry_safe(geom):
    """Fix minor geometry issues; returns original geometry if fix fails."""
    try:
        if geom is None:
            return None
        return geom.buffer(0)
    except Exception:
        return geom


def add_event_id(df_in):
    """Add stable integer event_id based on the DataFrame index."""
    df_out = df_in.copy()
    df_out["event_id"] = df_out.index.astype(int)
    return df_out


def compute_area_km2(gdf_wgs84):
    """Compute polygon area in km^2 using an equal-area CRS."""
    gdf_area = gdf_wgs84.to_crs("EPSG:6933").copy()
    return (gdf_area.geometry.area / 1_000_000.0).astype(float)


def ee_fc_to_df(fc):
    """Convert an EE FeatureCollection to a pandas DataFrame with robust fallbacks."""
    if hasattr(geemap, "ee_to_df"):
        return geemap.ee_to_df(fc)

    if hasattr(geemap, "ee_to_pandas"):
        return geemap.ee_to_pandas(fc)

    # Fallback: pull features client-side (slower, but robust for small batches)
    features = fc.getInfo().get("features", [])
    rows = [f.get("properties", {}) for f in features]
    return pd.DataFrame(rows)


def initialize_ee():
    """Initialize Earth Engine; authenticate interactively if needed."""
    try:
        ee.Initialize()
        print("Earth Engine initialized.")
    except Exception:
        print("Earth Engine not initialized. Running authentication...")
        ee.Authenticate()
        ee.Initialize()
        print("Earth Engine authenticated and initialized.")


def pick_stat_column(columns, preferred, fallback):
    """Pick a column name from EE output (supports with/without band prefix)."""
    if preferred in columns:
        return preferred
    if fallback in columns:
        return fallback
    return None


def get_start_params_fast(out_dir):
    """
    Finds the last batch file, reads ONLY that file, 
    and determines the next row index based on the max event_id.
    This ensures continuity even if batch sizes change.
    """
    if not os.path.exists(out_dir):
        return 0, 0
    
    # 1. Find all PKL files
    pattern = os.path.join(out_dir, "pfdi_stats_batch_*.pkl")
    files = glob.glob(pattern)
    
    if not files:
        return 0, 0
    
    # 2. Identify the file with the highest batch number
    max_batch = -1
    last_file_path = None
    
    for f in files:
        try:
            filename = os.path.basename(f)
            # filename format: pfdi_stats_batch_XXXX.pkl
            num_part = filename.split('_')[-1].split('.')[0]
            batch_num = int(num_part)
            
            if batch_num > max_batch:
                max_batch = batch_num
                last_file_path = f
        except ValueError:
            continue
            
    if last_file_path is None:
        return 0, 0

    print(f"Checking last saved file for continuity: {os.path.basename(last_file_path)}")
    
    # 3. Read ONLY the last file to find the last processed event_id
    try:
        df_last = pd.read_pickle(last_file_path)
        if "event_id" in df_last.columns and not df_last.empty:
            last_event_id = df_last["event_id"].max()
            # The next row index corresponds to event_id + 1 (assuming event_id matches index)
            next_row_idx = int(last_event_id) + 1
        else:
            print("Warning: Last file was empty or missing event_id. Starting manual check recommended.")
            # Fallback: assume we just continue batch numbering but start index is unknown (risk of overlap/gap)
            return max_batch + 1, 0 
            
    except Exception as e:
        print(f"Error reading last file: {e}")
        return max_batch + 1, 0

    return max_batch + 1, next_row_idx
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ============================================
# 3) AUTHENTICATE & INITIALIZE EARTH ENGINE
# ============================================
initialize_ee()


# ============================================
# 4) LOAD PKL AND PREPARE GEODATAFRAME
# ============================================
ensure_out_dir(OUT_DIR)

df = pd.read_pickle(PKL_PATH)
df = add_event_id(df)

if GEOM_WKT_COL not in df.columns:
    raise ValueError(f"Column '{GEOM_WKT_COL}' not found. Available columns: {list(df.columns)}")

gdf = gpd.GeoDataFrame(
    df,
    geometry=df[GEOM_WKT_COL].apply(wkt.loads),
    crs="EPSG:4326"
)

gdf["geometry"] = gdf["geometry"].apply(fix_geometry_safe)
gdf = gdf[gdf.geometry.notnull()].copy()

gdf_min = gdf[["event_id", "geometry"]].copy()
gdf_min["poly_area_km2"] = compute_area_km2(gdf_min)

print("Chronicle GeoDataFrame loaded.")
print("Total Rows in Dataset:", len(gdf_min))


# ============================================
# 5) LOAD MERIT HYDRO
# ============================================
merit = ee.Image(MERIT_IMAGE_ID)
upa = merit.select(UPA_BAND)

# ============================================
# 6) DEFINE REDUCER
# ============================================
reducer = ee.Reducer.max().combine(
    ee.Reducer.percentile([95, 99]),
    sharedInputs=True
)


# ============================================
# 7) RUN NEW BATCHES (SMART RESUME)
# ============================================
# Get start params using the optimized method
next_batch_id, start_row_idx = get_start_params_fast(OUT_DIR)
n_rows = len(gdf_min)

print(f"--- SMART AUTO-DETECT ---")
print(f"Next Batch File ID: {next_batch_id}")
print(f"Last Processed Event ID : {start_row_idx - 1}")
print(f"Resuming from Row Index: {start_row_idx}")
print(f"Planning to run {N_BATCHES_TO_RUN} new batches of size {BATCH_SIZE}.")

# Initialize manual counters
current_row_idx = start_row_idx
current_batch_id = next_batch_id

# batch_outputs = []

# Loop for the requested number of batches
for _ in range(N_BATCHES_TO_RUN):
    
    # Define start and end rows for THIS batch
    i0 = current_row_idx
    i1 = min(current_row_idx + BATCH_SIZE, n_rows)

    # Stop if we have exceeded the dataset size
    if i0 >= n_rows:
        print("Reached end of dataset. Stopping.")
        break

    print(f"Processing Batch {current_batch_id} (Rows {i0} - {i1})...")

    gdf_batch = gdf_min.iloc[i0:i1].copy()

    # Convert batch polygons to EE FeatureCollection
    fc = geemap.geopandas_to_ee(gdf_batch[["event_id", "geometry"]])

    # Compute zonal stats
    stats_fc = upa.reduceRegions(
        collection=fc,
        reducer=reducer,
        scale=SCALE_M,
        tileScale=8
    )

    df_stats = ee_fc_to_df(stats_fc)

    # Merge local area
    df_area = gdf_batch[["event_id", "poly_area_km2"]].copy()
    out = df_stats.merge(df_area, on="event_id", how="left")

    # Handle EE output column naming differences
    max_col = pick_stat_column(out.columns, "upa_max", "max")
    p95_col = pick_stat_column(out.columns, "upa_p95", "p95")
    p99_col = pick_stat_column(out.columns, "upa_p99", "p99")

    if p95_col is None:
        print(f"Warning: Batch {current_batch_id} returned empty or invalid stats.")
        # Advance counters even if failed, to avoid infinite loop
        current_row_idx += BATCH_SIZE
        current_batch_id += 1
        continue

    # Compute PFDI with explicit name
    out["PFDI_p95"] = out[p95_col] / out["poly_area_km2"]

    # Standardize column names
    rename_map = {}
    if max_col is not None:
        rename_map[max_col] = "upa_max"
    if p95_col is not None:
        rename_map[p95_col] = "upa_p95"
    if p99_col is not None:
        rename_map[p99_col] = "upa_p99"
    out = out.rename(columns=rename_map)

    # Keep a clean set of columns
    keep_cols = ["event_id", "poly_area_km2", "upa_max", "upa_p95", "upa_p99", "PFDI_p95"]
    keep_cols = [c for c in keep_cols if c in out.columns]
    out = out[keep_cols].copy()

    # Save partial result immediately as PKL
    partial_path = os.path.join(OUT_DIR, f"pfdi_stats_batch_{current_batch_id:04d}.pkl")
    out.to_pickle(partial_path)
    
#     batch_outputs.append(out)

    print(f"Finished batch {current_batch_id}. Saved: {os.path.basename(partial_path)}")

# Optional: Force clean up to be super safe
    del out, df_stats, fc
    import gc
    gc.collect()
    
    # Update counters for next iteration
    current_row_idx += BATCH_SIZE
    current_batch_id += 1
# Out:
# Earth Engine initialized.
# Chronicle GeoDataFrame loaded.
# Total Rows in Dataset: 882972
# Checking last saved file for continuity: pfdi_stats_batch_10437.pkl
# --- SMART AUTO-DETECT ---
# Next Batch File ID: 10438
# Last Processed Event ID : 833069
# Resuming from Row Index: 833070
# Planning to run 5000 new batches of size 50.
# Processing Batch 10438 (Rows 833070 - 833120)...
# Finished batch 10438. Saved: pfdi_stats_batch_10438.pkl
# Processing Batch 10439 (Rows 833120 - 833170)...
# Finished batch 10439. Saved: pfdi_stats_batch_10439.pkl
# Processing Batch 10440 (Rows 833170 - 833220)...
# Finished batch 10440. Saved: pfdi_stats_batch_10440.pkl
# Processing Batch 10441 (Rows 833220 - 833270)...
# Finished batch 10441. Saved: pfdi_stats_batch_10441.pkl
# Processing Batch 10442 (Rows 833270 - 833320)...
# Finished batch 10442. Saved: pfdi_stats_batch_10442.pkl
# Processing Batch 10443 (Rows 833320 - 833370)...
# Finished batch 10443. Saved: pfdi_stats_batch_10443.pkl
# Processing Batch 10444 (Rows 833370 - 833420)...
# Finished batch 10444. Saved: pfdi_stats_batch_10444.pkl
# Processing Batch 10445 (Rows 833420 - 833470)...
# Finished batch 10445. Saved: pfdi_stats_batch_10445.pkl
# Processing Batch 10446 (Rows 833470 - 833520)...
# Finished batch 10446. Saved: pfdi_stats_batch_10446.pkl
# Processing Batch 10447 (Rows 833520 - 833570)...
# Finished batch 10447. Saved: pfdi_stats_batch_10447.pkl
# Processing Batch 10448 (Rows 833570 - 833620)...
# Finished batch 10448. Saved: pfdi_stats_batch_10448.pkl
# Processing Batch 10449 (Rows 833620 - 833670)...
# Finished batch 10449. Saved: pfdi_stats_batch_10449.pkl
# Processing Batch 10450 (Rows 833670 - 833720)...
# Finished batch 10450. Saved: pfdi_stats_batch_10450.pkl
# Processing Batch 10451 (Rows 833720 - 833770)...
# Finished batch 10451. Saved: pfdi_stats_batch_10451.pkl
# Processing Batch 10452 (Rows 833770 - 833820)...
# Finished batch 10452. Saved: pfdi_stats_batch_10452.pkl
# Processing Batch 10453 (Rows 833820 - 833870)...
# Finished batch 10453. Saved: pfdi_stats_batch_10453.pkl
# Processing Batch 10454 (Rows 833870 - 833920)...
# Finished batch 10454. Saved: pfdi_stats_batch_10454.pkl
# Processing Batch 10455 (Rows 833920 - 833970)...
# Finished batch 10455. Saved: pfdi_stats_batch_10455.pkl
# Processing Batch 10456 (Rows 833970 - 834020)...
# Finished batch 10456. Saved: pfdi_stats_batch_10456.pkl
# Processing Batch 10457 (Rows 834020 - 834070)...
# Finished batch 10457. Saved: pfdi_stats_batch_10457.pkl
# Processing Batch 10458 (Rows 834070 - 834120)...
# Finished batch 10458. Saved: pfdi_stats_batch_10458.pkl
# Processing Batch 10459 (Rows 834120 - 834170)...
# Finished batch 10459. Saved: pfdi_stats_batch_10459.pkl
# Processing Batch 10460 (Rows 834170 - 834220)...
# Finished batch 10460. Saved: pfdi_stats_batch_10460.pkl
# Processing Batch 10461 (Rows 834220 - 834270)...
# Finished batch 10461. Saved: pfdi_stats_batch_10461.pkl
# Processing Batch 10462 (Rows 834270 - 834320)...
# Finished batch 10462. Saved: pfdi_stats_batch_10462.pkl
# Processing Batch 10463 (Rows 834320 - 834370)...
# Finished batch 10463. Saved: pfdi_stats_batch_10463.pkl
# Processing Batch 10464 (Rows 834370 - 834420)...
# Finished batch 10464. Saved: pfdi_stats_batch_10464.pkl
# Processing Batch 10465 (Rows 834420 - 834470)...
# Finished batch 10465. Saved: pfdi_stats_batch_10465.pkl
# Processing Batch 10466 (Rows 834470 - 834520)...
# Finished batch 10466. Saved: pfdi_stats_batch_10466.pkl
# Processing Batch 10467 (Rows 834520 - 834570)...
# Finished batch 10467. Saved: pfdi_stats_batch_10467.pkl
# Processing Batch 10468 (Rows 834570 - 834620)...
# Finished batch 10468. Saved: pfdi_stats_batch_10468.pkl
# Processing Batch 10469 (Rows 834620 - 834670)...
# Finished batch 10469. Saved: pfdi_stats_batch_10469.pkl
# Processing Batch 10470 (Rows 834670 - 834720)...
# Finished batch 10470. Saved: pfdi_stats_batch_10470.pkl
# Processing Batch 10471 (Rows 834720 - 834770)...
# Finished batch 10471. Saved: pfdi_stats_batch_10471.pkl
# Processing Batch 10472 (Rows 834770 - 834820)...
# Finished batch 10472. Saved: pfdi_stats_batch_10472.pkl
# Processing Batch 10473 (Rows 834820 - 834870)...
# Finished batch 10473. Saved: pfdi_stats_batch_10473.pkl
# Processing Batch 10474 (Rows 834870 - 834920)...
# Finished batch 10474. Saved: pfdi_stats_batch_10474.pkl
# Processing Batch 10475 (Rows 834920 - 834970)...
# Finished batch 10475. Saved: pfdi_stats_batch_10475.pkl
# Processing Batch 10476 (Rows 834970 - 835020)...
# Finished batch 10476. Saved: pfdi_stats_batch_10476.pkl
# Processing Batch 10477 (Rows 835020 - 835070)...
# Finished batch 10477. Saved: pfdi_stats_batch_10477.pkl
# Processing Batch 10478 (Rows 835070 - 835120)...
# Finished batch 10478. Saved: pfdi_stats_batch_10478.pkl
# Processing Batch 10479 (Rows 835120 - 835170)...
# Finished batch 10479. Saved: pfdi_stats_batch_10479.pkl
# Processing Batch 10480 (Rows 835170 - 835220)...
# Finished batch 10480. Saved: pfdi_stats_batch_10480.pkl
# Processing Batch 10481 (Rows 835220 - 835270)...
# Finished batch 10481. Saved: pfdi_stats_batch_10481.pkl
# Processing Batch 10482 (Rows 835270 - 835320)...
# Finished batch 10482. Saved: pfdi_stats_batch_10482.pkl
# Processing Batch 10483 (Rows 835320 - 835370)...
# Finished batch 10483. Saved: pfdi_stats_batch_10483.pkl
# Processing Batch 10484 (Rows 835370 - 835420)...
# Finished batch 10484. Saved: pfdi_stats_batch_10484.pkl
# Processing Batch 10485 (Rows 835420 - 835470)...
# Finished batch 10485. Saved: pfdi_stats_batch_10485.pkl
# Processing Batch 10486 (Rows 835470 - 835520)...
# Finished batch 10486. Saved: pfdi_stats_batch_10486.pkl
# Processing Batch 10487 (Rows 835520 - 835570)...
# Finished batch 10487. Saved: pfdi_stats_batch_10487.pkl
# Processing Batch 10488 (Rows 835570 - 835620)...
# Finished batch 10488. Saved: pfdi_stats_batch_10488.pkl
# Processing Batch 10489 (Rows 835620 - 835670)...
# Finished batch 10489. Saved: pfdi_stats_batch_10489.pkl
# Processing Batch 10490 (Rows 835670 - 835720)...
# Finished batch 10490. Saved: pfdi_stats_batch_10490.pkl
# Processing Batch 10491 (Rows 835720 - 835770)...
# Finished batch 10491. Saved: pfdi_stats_batch_10491.pkl
# Processing Batch 10492 (Rows 835770 - 835820)...
# Finished batch 10492. Saved: pfdi_stats_batch_10492.pkl
# Processing Batch 10493 (Rows 835820 - 835870)...
# Finished batch 10493. Saved: pfdi_stats_batch_10493.pkl
# Processing Batch 10494 (Rows 835870 - 835920)...
# Finished batch 10494. Saved: pfdi_stats_batch_10494.pkl
# Processing Batch 10495 (Rows 835920 - 835970)...
# Finished batch 10495. Saved: pfdi_stats_batch_10495.pkl
# Processing Batch 10496 (Rows 835970 - 836020)...
# Finished batch 10496. Saved: pfdi_stats_batch_10496.pkl
# Processing Batch 10497 (Rows 836020 - 836070)...
# Finished batch 10497. Saved: pfdi_stats_batch_10497.pkl
# Processing Batch 10498 (Rows 836070 - 836120)...
# Finished batch 10498. Saved: pfdi_stats_batch_10498.pkl
# Processing Batch 10499 (Rows 836120 - 836170)...
# Finished batch 10499. Saved: pfdi_stats_batch_10499.pkl
# Processing Batch 10500 (Rows 836170 - 836220)...
# Finished batch 10500. Saved: pfdi_stats_batch_10500.pkl
# Processing Batch 10501 (Rows 836220 - 836270)...
# Finished batch 10501. Saved: pfdi_stats_batch_10501.pkl
# Processing Batch 10502 (Rows 836270 - 836320)...
# Finished batch 10502. Saved: pfdi_stats_batch_10502.pkl
# Processing Batch 10503 (Rows 836320 - 836370)...
# Finished batch 10503. Saved: pfdi_stats_batch_10503.pkl
# Processing Batch 10504 (Rows 836370 - 836420)...
# Finished batch 10504. Saved: pfdi_stats_batch_10504.pkl
# Processing Batch 10505 (Rows 836420 - 836470)...
# Finished batch 10505. Saved: pfdi_stats_batch_10505.pkl
# Processing Batch 10506 (Rows 836470 - 836520)...
# Finished batch 10506. Saved: pfdi_stats_batch_10506.pkl
# Processing Batch 10507 (Rows 836520 - 836570)...
# Finished batch 10507. Saved: pfdi_stats_batch_10507.pkl
# Processing Batch 10508 (Rows 836570 - 836620)...
# Finished batch 10508. Saved: pfdi_stats_batch_10508.pkl
# Processing Batch 10509 (Rows 836620 - 836670)...
# Finished batch 10509. Saved: pfdi_stats_batch_10509.pkl
# Processing Batch 10510 (Rows 836670 - 836720)...
# Finished batch 10510. Saved: pfdi_stats_batch_10510.pkl
# Processing Batch 10511 (Rows 836720 - 836770)...
# Finished batch 10511. Saved: pfdi_stats_batch_10511.pkl
# Processing Batch 10512 (Rows 836770 - 836820)...
# Finished batch 10512. Saved: pfdi_stats_batch_10512.pkl
# Processing Batch 10513 (Rows 836820 - 836870)...
# Finished batch 10513. Saved: pfdi_stats_batch_10513.pkl
# Processing Batch 10514 (Rows 836870 - 836920)...
# Finished batch 10514. Saved: pfdi_stats_batch_10514.pkl
# Processing Batch 10515 (Rows 836920 - 836970)...
# Finished batch 10515. Saved: pfdi_stats_batch_10515.pkl
# Processing Batch 10516 (Rows 836970 - 837020)...
# Finished batch 10516. Saved: pfdi_stats_batch_10516.pkl
# Processing Batch 10517 (Rows 837020 - 837070)...
# Finished batch 10517. Saved: pfdi_stats_batch_10517.pkl
# Processing Batch 10518 (Rows 837070 - 837120)...
# Finished batch 10518. Saved: pfdi_stats_batch_10518.pkl
# Processing Batch 10519 (Rows 837120 - 837170)...
# Finished batch 10519. Saved: pfdi_stats_batch_10519.pkl
# Processing Batch 10520 (Rows 837170 - 837220)...
# Finished batch 10520. Saved: pfdi_stats_batch_10520.pkl
# Processing Batch 10521 (Rows 837220 - 837270)...
# Finished batch 10521. Saved: pfdi_stats_batch_10521.pkl
# Processing Batch 10522 (Rows 837270 - 837320)...
# Finished batch 10522. Saved: pfdi_stats_batch_10522.pkl
# Processing Batch 10523 (Rows 837320 - 837370)...
# Finished batch 10523. Saved: pfdi_stats_batch_10523.pkl
# Processing Batch 10524 (Rows 837370 - 837420)...
# Finished batch 10524. Saved: pfdi_stats_batch_10524.pkl
# Processing Batch 10525 (Rows 837420 - 837470)...
# Finished batch 10525. Saved: pfdi_stats_batch_10525.pkl
# Processing Batch 10526 (Rows 837470 - 837520)...
# Finished batch 10526. Saved: pfdi_stats_batch_10526.pkl
# Processing Batch 10527 (Rows 837520 - 837570)...
# Finished batch 10527. Saved: pfdi_stats_batch_10527.pkl
# Processing Batch 10528 (Rows 837570 - 837620)...
# Finished batch 10528. Saved: pfdi_stats_batch_10528.pkl
# Processing Batch 10529 (Rows 837620 - 837670)...
# Finished batch 10529. Saved: pfdi_stats_batch_10529.pkl
# Processing Batch 10530 (Rows 837670 - 837720)...
# Finished batch 10530. Saved: pfdi_stats_batch_10530.pkl
# Processing Batch 10531 (Rows 837720 - 837770)...
# Finished batch 10531. Saved: pfdi_stats_batch_10531.pkl
# Processing Batch 10532 (Rows 837770 - 837820)...
# Finished batch 10532. Saved: pfdi_stats_batch_10532.pkl
# Processing Batch 10533 (Rows 837820 - 837870)...
# Finished batch 10533. Saved: pfdi_stats_batch_10533.pkl
# Processing Batch 10534 (Rows 837870 - 837920)...
# Finished batch 10534. Saved: pfdi_stats_batch_10534.pkl
# Processing Batch 10535 (Rows 837920 - 837970)...
# Finished batch 10535. Saved: pfdi_stats_batch_10535.pkl
# Processing Batch 10536 (Rows 837970 - 838020)...
# Finished batch 10536. Saved: pfdi_stats_batch_10536.pkl
# Processing Batch 10537 (Rows 838020 - 838070)...
# Finished batch 10537. Saved: pfdi_stats_batch_10537.pkl
# Processing Batch 10538 (Rows 838070 - 838120)...
# Finished batch 10538. Saved: pfdi_stats_batch_10538.pkl
# Processing Batch 10539 (Rows 838120 - 838170)...
# Finished batch 10539. Saved: pfdi_stats_batch_10539.pkl
# Processing Batch 10540 (Rows 838170 - 838220)...
# Finished batch 10540. Saved: pfdi_stats_batch_10540.pkl
# Processing Batch 10541 (Rows 838220 - 838270)...
# Finished batch 10541. Saved: pfdi_stats_batch_10541.pkl
# Processing Batch 10542 (Rows 838270 - 838320)...
# Finished batch 10542. Saved: pfdi_stats_batch_10542.pkl
# Processing Batch 10543 (Rows 838320 - 838370)...
# Finished batch 10543. Saved: pfdi_stats_batch_10543.pkl
# Processing Batch 10544 (Rows 838370 - 838420)...
# Finished batch 10544. Saved: pfdi_stats_batch_10544.pkl
# Processing Batch 10545 (Rows 838420 - 838470)...
# Finished batch 10545. Saved: pfdi_stats_batch_10545.pkl
# Processing Batch 10546 (Rows 838470 - 838520)...
# Finished batch 10546. Saved: pfdi_stats_batch_10546.pkl
# Processing Batch 10547 (Rows 838520 - 838570)...
# Finished batch 10547. Saved: pfdi_stats_batch_10547.pkl
# Processing Batch 10548 (Rows 838570 - 838620)...
# Finished batch 10548. Saved: pfdi_stats_batch_10548.pkl
# Processing Batch 10549 (Rows 838620 - 838670)...
# Finished batch 10549. Saved: pfdi_stats_batch_10549.pkl
# Processing Batch 10550 (Rows 838670 - 838720)...
# Finished batch 10550. Saved: pfdi_stats_batch_10550.pkl
# Processing Batch 10551 (Rows 838720 - 838770)...
# Finished batch 10551. Saved: pfdi_stats_batch_10551.pkl
# Processing Batch 10552 (Rows 838770 - 838820)...
# Finished batch 10552. Saved: pfdi_stats_batch_10552.pkl
# Processing Batch 10553 (Rows 838820 - 838870)...
# Finished batch 10553. Saved: pfdi_stats_batch_10553.pkl
# Processing Batch 10554 (Rows 838870 - 838920)...
# Finished batch 10554. Saved: pfdi_stats_batch_10554.pkl
# Processing Batch 10555 (Rows 838920 - 838970)...
# Finished batch 10555. Saved: pfdi_stats_batch_10555.pkl
# Processing Batch 10556 (Rows 838970 - 839020)...
# Finished batch 10556. Saved: pfdi_stats_batch_10556.pkl
# Processing Batch 10557 (Rows 839020 - 839070)...
# Finished batch 10557. Saved: pfdi_stats_batch_10557.pkl
# Processing Batch 10558 (Rows 839070 - 839120)...
# Finished batch 10558. Saved: pfdi_stats_batch_10558.pkl
# Processing Batch 10559 (Rows 839120 - 839170)...
# Finished batch 10559. Saved: pfdi_stats_batch_10559.pkl
# Processing Batch 10560 (Rows 839170 - 839220)...
# Finished batch 10560. Saved: pfdi_stats_batch_10560.pkl
# Processing Batch 10561 (Rows 839220 - 839270)...
# Finished batch 10561. Saved: pfdi_stats_batch_10561.pkl
# Processing Batch 10562 (Rows 839270 - 839320)...
# Finished batch 10562. Saved: pfdi_stats_batch_10562.pkl
# Processing Batch 10563 (Rows 839320 - 839370)...
# Finished batch 10563. Saved: pfdi_stats_batch_10563.pkl
# Processing Batch 10564 (Rows 839370 - 839420)...
# Finished batch 10564. Saved: pfdi_stats_batch_10564.pkl
# Processing Batch 10565 (Rows 839420 - 839470)...
# Finished batch 10565. Saved: pfdi_stats_batch_10565.pkl
# Processing Batch 10566 (Rows 839470 - 839520)...
# Finished batch 10566. Saved: pfdi_stats_batch_10566.pkl
# Processing Batch 10567 (Rows 839520 - 839570)...
# Finished batch 10567. Saved: pfdi_stats_batch_10567.pkl
# Processing Batch 10568 (Rows 839570 - 839620)...
# Finished batch 10568. Saved: pfdi_stats_batch_10568.pkl
# Processing Batch 10569 (Rows 839620 - 839670)...
# Finished batch 10569. Saved: pfdi_stats_batch_10569.pkl
# Processing Batch 10570 (Rows 839670 - 839720)...
# Finished batch 10570. Saved: pfdi_stats_batch_10570.pkl
# Processing Batch 10571 (Rows 839720 - 839770)...
# Finished batch 10571. Saved: pfdi_stats_batch_10571.pkl
# Processing Batch 10572 (Rows 839770 - 839820)...
# Finished batch 10572. Saved: pfdi_stats_batch_10572.pkl
# Processing Batch 10573 (Rows 839820 - 839870)...
# Finished batch 10573. Saved: pfdi_stats_batch_10573.pkl
# Processing Batch 10574 (Rows 839870 - 839920)...
# Finished batch 10574. Saved: pfdi_stats_batch_10574.pkl
# Processing Batch 10575 (Rows 839920 - 839970)...
# Finished batch 10575. Saved: pfdi_stats_batch_10575.pkl
# Processing Batch 10576 (Rows 839970 - 840020)...
# Finished batch 10576. Saved: pfdi_stats_batch_10576.pkl
# Processing Batch 10577 (Rows 840020 - 840070)...
# Finished batch 10577. Saved: pfdi_stats_batch_10577.pkl
# Processing Batch 10578 (Rows 840070 - 840120)...
# Finished batch 10578. Saved: pfdi_stats_batch_10578.pkl
# Processing Batch 10579 (Rows 840120 - 840170)...
# Finished batch 10579. Saved: pfdi_stats_batch_10579.pkl
# Processing Batch 10580 (Rows 840170 - 840220)...
# Finished batch 10580. Saved: pfdi_stats_batch_10580.pkl
# Processing Batch 10581 (Rows 840220 - 840270)...
# Finished batch 10581. Saved: pfdi_stats_batch_10581.pkl
# Processing Batch 10582 (Rows 840270 - 840320)...
# Finished batch 10582. Saved: pfdi_stats_batch_10582.pkl
# Processing Batch 10583 (Rows 840320 - 840370)...
# Finished batch 10583. Saved: pfdi_stats_batch_10583.pkl
# Processing Batch 10584 (Rows 840370 - 840420)...
# Finished batch 10584. Saved: pfdi_stats_batch_10584.pkl
# Processing Batch 10585 (Rows 840420 - 840470)...
# Finished batch 10585. Saved: pfdi_stats_batch_10585.pkl
# Processing Batch 10586 (Rows 840470 - 840520)...
# Finished batch 10586. Saved: pfdi_stats_batch_10586.pkl
# Processing Batch 10587 (Rows 840520 - 840570)...
# Finished batch 10587. Saved: pfdi_stats_batch_10587.pkl
# Processing Batch 10588 (Rows 840570 - 840620)...
# Finished batch 10588. Saved: pfdi_stats_batch_10588.pkl
# Processing Batch 10589 (Rows 840620 - 840670)...
# Finished batch 10589. Saved: pfdi_stats_batch_10589.pkl
# Processing Batch 10590 (Rows 840670 - 840720)...
# Finished batch 10590. Saved: pfdi_stats_batch_10590.pkl
# Processing Batch 10591 (Rows 840720 - 840770)...
# Finished batch 10591. Saved: pfdi_stats_batch_10591.pkl
# Processing Batch 10592 (Rows 840770 - 840820)...
# Finished batch 10592. Saved: pfdi_stats_batch_10592.pkl
# Processing Batch 10593 (Rows 840820 - 840870)...
# Finished batch 10593. Saved: pfdi_stats_batch_10593.pkl
# Processing Batch 10594 (Rows 840870 - 840920)...
# Finished batch 10594. Saved: pfdi_stats_batch_10594.pkl
# Processing Batch 10595 (Rows 840920 - 840970)...
# Finished batch 10595. Saved: pfdi_stats_batch_10595.pkl
# Processing Batch 10596 (Rows 840970 - 841020)...
# Finished batch 10596. Saved: pfdi_stats_batch_10596.pkl
# Processing Batch 10597 (Rows 841020 - 841070)...
# Finished batch 10597. Saved: pfdi_stats_batch_10597.pkl
# Processing Batch 10598 (Rows 841070 - 841120)...
# Finished batch 10598. Saved: pfdi_stats_batch_10598.pkl
# Processing Batch 10599 (Rows 841120 - 841170)...
# Finished batch 10599. Saved: pfdi_stats_batch_10599.pkl
# Processing Batch 10600 (Rows 841170 - 841220)...
# Finished batch 10600. Saved: pfdi_stats_batch_10600.pkl
# Processing Batch 10601 (Rows 841220 - 841270)...
# Finished batch 10601. Saved: pfdi_stats_batch_10601.pkl
# Processing Batch 10602 (Rows 841270 - 841320)...
# Finished batch 10602. Saved: pfdi_stats_batch_10602.pkl
# Processing Batch 10603 (Rows 841320 - 841370)...
# Finished batch 10603. Saved: pfdi_stats_batch_10603.pkl
# Processing Batch 10604 (Rows 841370 - 841420)...
# Finished batch 10604. Saved: pfdi_stats_batch_10604.pkl
# Processing Batch 10605 (Rows 841420 - 841470)...
# Finished batch 10605. Saved: pfdi_stats_batch_10605.pkl
# Processing Batch 10606 (Rows 841470 - 841520)...
# Finished batch 10606. Saved: pfdi_stats_batch_10606.pkl
# Processing Batch 10607 (Rows 841520 - 841570)...
# Finished batch 10607. Saved: pfdi_stats_batch_10607.pkl
# Processing Batch 10608 (Rows 841570 - 841620)...
# Finished batch 10608. Saved: pfdi_stats_batch_10608.pkl
# Processing Batch 10609 (Rows 841620 - 841670)...
# Finished batch 10609. Saved: pfdi_stats_batch_10609.pkl
# Processing Batch 10610 (Rows 841670 - 841720)...
# Finished batch 10610. Saved: pfdi_stats_batch_10610.pkl
# Processing Batch 10611 (Rows 841720 - 841770)...
# Finished batch 10611. Saved: pfdi_stats_batch_10611.pkl
# Processing Batch 10612 (Rows 841770 - 841820)...
# Finished batch 10612. Saved: pfdi_stats_batch_10612.pkl
# Processing Batch 10613 (Rows 841820 - 841870)...
# Finished batch 10613. Saved: pfdi_stats_batch_10613.pkl
# Processing Batch 10614 (Rows 841870 - 841920)...
# Finished batch 10614. Saved: pfdi_stats_batch_10614.pkl
# Processing Batch 10615 (Rows 841920 - 841970)...
# Finished batch 10615. Saved: pfdi_stats_batch_10615.pkl
# Processing Batch 10616 (Rows 841970 - 842020)...
# Finished batch 10616. Saved: pfdi_stats_batch_10616.pkl
# Processing Batch 10617 (Rows 842020 - 842070)...
# Finished batch 10617. Saved: pfdi_stats_batch_10617.pkl
# Processing Batch 10618 (Rows 842070 - 842120)...
# Finished batch 10618. Saved: pfdi_stats_batch_10618.pkl
# Processing Batch 10619 (Rows 842120 - 842170)...
# Finished batch 10619. Saved: pfdi_stats_batch_10619.pkl
# Processing Batch 10620 (Rows 842170 - 842220)...
# Finished batch 10620. Saved: pfdi_stats_batch_10620.pkl
# Processing Batch 10621 (Rows 842220 - 842270)...
# Finished batch 10621. Saved: pfdi_stats_batch_10621.pkl
# Processing Batch 10622 (Rows 842270 - 842320)...
# Finished batch 10622. Saved: pfdi_stats_batch_10622.pkl
# Processing Batch 10623 (Rows 842320 - 842370)...
# Finished batch 10623. Saved: pfdi_stats_batch_10623.pkl
# Processing Batch 10624 (Rows 842370 - 842420)...
# Finished batch 10624. Saved: pfdi_stats_batch_10624.pkl
# Processing Batch 10625 (Rows 842420 - 842470)...
# Finished batch 10625. Saved: pfdi_stats_batch_10625.pkl
# Processing Batch 10626 (Rows 842470 - 842520)...
# Finished batch 10626. Saved: pfdi_stats_batch_10626.pkl
# Processing Batch 10627 (Rows 842520 - 842570)...
# Finished batch 10627. Saved: pfdi_stats_batch_10627.pkl
# Processing Batch 10628 (Rows 842570 - 842620)...
# Finished batch 10628. Saved: pfdi_stats_batch_10628.pkl
# Processing Batch 10629 (Rows 842620 - 842670)...
# Finished batch 10629. Saved: pfdi_stats_batch_10629.pkl
# Processing Batch 10630 (Rows 842670 - 842720)...
# Finished batch 10630. Saved: pfdi_stats_batch_10630.pkl
# Processing Batch 10631 (Rows 842720 - 842770)...
# Finished batch 10631. Saved: pfdi_stats_batch_10631.pkl
# Processing Batch 10632 (Rows 842770 - 842820)...
# Finished batch 10632. Saved: pfdi_stats_batch_10632.pkl
# Processing Batch 10633 (Rows 842820 - 842870)...
# Finished batch 10633. Saved: pfdi_stats_batch_10633.pkl
# Processing Batch 10634 (Rows 842870 - 842920)...
# Finished batch 10634. Saved: pfdi_stats_batch_10634.pkl
# Processing Batch 10635 (Rows 842920 - 842970)...
# Finished batch 10635. Saved: pfdi_stats_batch_10635.pkl
# Processing Batch 10636 (Rows 842970 - 843020)...
# Finished batch 10636. Saved: pfdi_stats_batch_10636.pkl
# Processing Batch 10637 (Rows 843020 - 843070)...
# Finished batch 10637. Saved: pfdi_stats_batch_10637.pkl
# Processing Batch 10638 (Rows 843070 - 843120)...
# Finished batch 10638. Saved: pfdi_stats_batch_10638.pkl
# Processing Batch 10639 (Rows 843120 - 843170)...
# Finished batch 10639. Saved: pfdi_stats_batch_10639.pkl
# Processing Batch 10640 (Rows 843170 - 843220)...
# Finished batch 10640. Saved: pfdi_stats_batch_10640.pkl
# Processing Batch 10641 (Rows 843220 - 843270)...
# Finished batch 10641. Saved: pfdi_stats_batch_10641.pkl
# Processing Batch 10642 (Rows 843270 - 843320)...
# Finished batch 10642. Saved: pfdi_stats_batch_10642.pkl
# Processing Batch 10643 (Rows 843320 - 843370)...
# Finished batch 10643. Saved: pfdi_stats_batch_10643.pkl
# Processing Batch 10644 (Rows 843370 - 843420)...
# Finished batch 10644. Saved: pfdi_stats_batch_10644.pkl
# Processing Batch 10645 (Rows 843420 - 843470)...
# Finished batch 10645. Saved: pfdi_stats_batch_10645.pkl
# Processing Batch 10646 (Rows 843470 - 843520)...
# Finished batch 10646. Saved: pfdi_stats_batch_10646.pkl
# Processing Batch 10647 (Rows 843520 - 843570)...
# Finished batch 10647. Saved: pfdi_stats_batch_10647.pkl
# Processing Batch 10648 (Rows 843570 - 843620)...
# Finished batch 10648. Saved: pfdi_stats_batch_10648.pkl
# Processing Batch 10649 (Rows 843620 - 843670)...
# Finished batch 10649. Saved: pfdi_stats_batch_10649.pkl
# Processing Batch 10650 (Rows 843670 - 843720)...
# Finished batch 10650. Saved: pfdi_stats_batch_10650.pkl
# Processing Batch 10651 (Rows 843720 - 843770)...
# Finished batch 10651. Saved: pfdi_stats_batch_10651.pkl
# Processing Batch 10652 (Rows 843770 - 843820)...
# Finished batch 10652. Saved: pfdi_stats_batch_10652.pkl
# Processing Batch 10653 (Rows 843820 - 843870)...
# Finished batch 10653. Saved: pfdi_stats_batch_10653.pkl
# Processing Batch 10654 (Rows 843870 - 843920)...
# Finished batch 10654. Saved: pfdi_stats_batch_10654.pkl
# Processing Batch 10655 (Rows 843920 - 843970)...
# Finished batch 10655. Saved: pfdi_stats_batch_10655.pkl
# Processing Batch 10656 (Rows 843970 - 844020)...
# Finished batch 10656. Saved: pfdi_stats_batch_10656.pkl
# Processing Batch 10657 (Rows 844020 - 844070)...
# Finished batch 10657. Saved: pfdi_stats_batch_10657.pkl
# Processing Batch 10658 (Rows 844070 - 844120)...
# Finished batch 10658. Saved: pfdi_stats_batch_10658.pkl
# Processing Batch 10659 (Rows 844120 - 844170)...
# Finished batch 10659. Saved: pfdi_stats_batch_10659.pkl
# Processing Batch 10660 (Rows 844170 - 844220)...
# Finished batch 10660. Saved: pfdi_stats_batch_10660.pkl
# Processing Batch 10661 (Rows 844220 - 844270)...
# Finished batch 10661. Saved: pfdi_stats_batch_10661.pkl
# Processing Batch 10662 (Rows 844270 - 844320)...
# Finished batch 10662. Saved: pfdi_stats_batch_10662.pkl
# Processing Batch 10663 (Rows 844320 - 844370)...
# Finished batch 10663. Saved: pfdi_stats_batch_10663.pkl
# Processing Batch 10664 (Rows 844370 - 844420)...
# Finished batch 10664. Saved: pfdi_stats_batch_10664.pkl
# Processing Batch 10665 (Rows 844420 - 844470)...
# Finished batch 10665. Saved: pfdi_stats_batch_10665.pkl
# Processing Batch 10666 (Rows 844470 - 844520)...
# Finished batch 10666. Saved: pfdi_stats_batch_10666.pkl
# Processing Batch 10667 (Rows 844520 - 844570)...
# Finished batch 10667. Saved: pfdi_stats_batch_10667.pkl
# Processing Batch 10668 (Rows 844570 - 844620)...
# Finished batch 10668. Saved: pfdi_stats_batch_10668.pkl
# Processing Batch 10669 (Rows 844620 - 844670)...
# Finished batch 10669. Saved: pfdi_stats_batch_10669.pkl
# Processing Batch 10670 (Rows 844670 - 844720)...
# Finished batch 10670. Saved: pfdi_stats_batch_10670.pkl
# Processing Batch 10671 (Rows 844720 - 844770)...
# Finished batch 10671. Saved: pfdi_stats_batch_10671.pkl
# Processing Batch 10672 (Rows 844770 - 844820)...
# Finished batch 10672. Saved: pfdi_stats_batch_10672.pkl
# Processing Batch 10673 (Rows 844820 - 844870)...
# Finished batch 10673. Saved: pfdi_stats_batch_10673.pkl
# Processing Batch 10674 (Rows 844870 - 844920)...
# Finished batch 10674. Saved: pfdi_stats_batch_10674.pkl
# Processing Batch 10675 (Rows 844920 - 844970)...
# Finished batch 10675. Saved: pfdi_stats_batch_10675.pkl
# Processing Batch 10676 (Rows 844970 - 845020)...
# Finished batch 10676. Saved: pfdi_stats_batch_10676.pkl
# Processing Batch 10677 (Rows 845020 - 845070)...
# Finished batch 10677. Saved: pfdi_stats_batch_10677.pkl
# Processing Batch 10678 (Rows 845070 - 845120)...
# Finished batch 10678. Saved: pfdi_stats_batch_10678.pkl
# Processing Batch 10679 (Rows 845120 - 845170)...
# Finished batch 10679. Saved: pfdi_stats_batch_10679.pkl
# Processing Batch 10680 (Rows 845170 - 845220)...
# Finished batch 10680. Saved: pfdi_stats_batch_10680.pkl
# Processing Batch 10681 (Rows 845220 - 845270)...
# Finished batch 10681. Saved: pfdi_stats_batch_10681.pkl
# Processing Batch 10682 (Rows 845270 - 845320)...
# Finished batch 10682. Saved: pfdi_stats_batch_10682.pkl
# Processing Batch 10683 (Rows 845320 - 845370)...
# Finished batch 10683. Saved: pfdi_stats_batch_10683.pkl
# Processing Batch 10684 (Rows 845370 - 845420)...
# Finished batch 10684. Saved: pfdi_stats_batch_10684.pkl
# Processing Batch 10685 (Rows 845420 - 845470)...
# Finished batch 10685. Saved: pfdi_stats_batch_10685.pkl
# Processing Batch 10686 (Rows 845470 - 845520)...
# Finished batch 10686. Saved: pfdi_stats_batch_10686.pkl
# Processing Batch 10687 (Rows 845520 - 845570)...
# Finished batch 10687. Saved: pfdi_stats_batch_10687.pkl
# Processing Batch 10688 (Rows 845570 - 845620)...
# Finished batch 10688. Saved: pfdi_stats_batch_10688.pkl
# Processing Batch 10689 (Rows 845620 - 845670)...
# Finished batch 10689. Saved: pfdi_stats_batch_10689.pkl
# Processing Batch 10690 (Rows 845670 - 845720)...
# Finished batch 10690. Saved: pfdi_stats_batch_10690.pkl
# Processing Batch 10691 (Rows 845720 - 845770)...
# Finished batch 10691. Saved: pfdi_stats_batch_10691.pkl
# Processing Batch 10692 (Rows 845770 - 845820)...
# Finished batch 10692. Saved: pfdi_stats_batch_10692.pkl
# Processing Batch 10693 (Rows 845820 - 845870)...
# Finished batch 10693. Saved: pfdi_stats_batch_10693.pkl
# Processing Batch 10694 (Rows 845870 - 845920)...
# Finished batch 10694. Saved: pfdi_stats_batch_10694.pkl
# Processing Batch 10695 (Rows 845920 - 845970)...
# Finished batch 10695. Saved: pfdi_stats_batch_10695.pkl
# Processing Batch 10696 (Rows 845970 - 846020)...
# Finished batch 10696. Saved: pfdi_stats_batch_10696.pkl
# Processing Batch 10697 (Rows 846020 - 846070)...
# Finished batch 10697. Saved: pfdi_stats_batch_10697.pkl
# Processing Batch 10698 (Rows 846070 - 846120)...
# Finished batch 10698. Saved: pfdi_stats_batch_10698.pkl
# Processing Batch 10699 (Rows 846120 - 846170)...
# Finished batch 10699. Saved: pfdi_stats_batch_10699.pkl
# Processing Batch 10700 (Rows 846170 - 846220)...
# Finished batch 10700. Saved: pfdi_stats_batch_10700.pkl
# Processing Batch 10701 (Rows 846220 - 846270)...
# Finished batch 10701. Saved: pfdi_stats_batch_10701.pkl
# Processing Batch 10702 (Rows 846270 - 846320)...
# Finished batch 10702. Saved: pfdi_stats_batch_10702.pkl
# Processing Batch 10703 (Rows 846320 - 846370)...
# Finished batch 10703. Saved: pfdi_stats_batch_10703.pkl
# Processing Batch 10704 (Rows 846370 - 846420)...
# Finished batch 10704. Saved: pfdi_stats_batch_10704.pkl
# Processing Batch 10705 (Rows 846420 - 846470)...
# Finished batch 10705. Saved: pfdi_stats_batch_10705.pkl
# Processing Batch 10706 (Rows 846470 - 846520)...
# Finished batch 10706. Saved: pfdi_stats_batch_10706.pkl
# Processing Batch 10707 (Rows 846520 - 846570)...
# Finished batch 10707. Saved: pfdi_stats_batch_10707.pkl
# Processing Batch 10708 (Rows 846570 - 846620)...
# Finished batch 10708. Saved: pfdi_stats_batch_10708.pkl
# Processing Batch 10709 (Rows 846620 - 846670)...
# Finished batch 10709. Saved: pfdi_stats_batch_10709.pkl
# Processing Batch 10710 (Rows 846670 - 846720)...
# Finished batch 10710. Saved: pfdi_stats_batch_10710.pkl
# Processing Batch 10711 (Rows 846720 - 846770)...
# Finished batch 10711. Saved: pfdi_stats_batch_10711.pkl
# Processing Batch 10712 (Rows 846770 - 846820)...
# Finished batch 10712. Saved: pfdi_stats_batch_10712.pkl
# Processing Batch 10713 (Rows 846820 - 846870)...
# Finished batch 10713. Saved: pfdi_stats_batch_10713.pkl
# Processing Batch 10714 (Rows 846870 - 846920)...
# Finished batch 10714. Saved: pfdi_stats_batch_10714.pkl
# Processing Batch 10715 (Rows 846920 - 846970)...
# Finished batch 10715. Saved: pfdi_stats_batch_10715.pkl
# Processing Batch 10716 (Rows 846970 - 847020)...
# Finished batch 10716. Saved: pfdi_stats_batch_10716.pkl
# Processing Batch 10717 (Rows 847020 - 847070)...
# Finished batch 10717. Saved: pfdi_stats_batch_10717.pkl
# Processing Batch 10718 (Rows 847070 - 847120)...
# Finished batch 10718. Saved: pfdi_stats_batch_10718.pkl
# Processing Batch 10719 (Rows 847120 - 847170)...
# Finished batch 10719. Saved: pfdi_stats_batch_10719.pkl
# Processing Batch 10720 (Rows 847170 - 847220)...
# Finished batch 10720. Saved: pfdi_stats_batch_10720.pkl
# Processing Batch 10721 (Rows 847220 - 847270)...
# Finished batch 10721. Saved: pfdi_stats_batch_10721.pkl
# Processing Batch 10722 (Rows 847270 - 847320)...
# Finished batch 10722. Saved: pfdi_stats_batch_10722.pkl
# Processing Batch 10723 (Rows 847320 - 847370)...
# Finished batch 10723. Saved: pfdi_stats_batch_10723.pkl
# Processing Batch 10724 (Rows 847370 - 847420)...
# Finished batch 10724. Saved: pfdi_stats_batch_10724.pkl
# Processing Batch 10725 (Rows 847420 - 847470)...
# Finished batch 10725. Saved: pfdi_stats_batch_10725.pkl
# Processing Batch 10726 (Rows 847470 - 847520)...
# Finished batch 10726. Saved: pfdi_stats_batch_10726.pkl
# Processing Batch 10727 (Rows 847520 - 847570)...
# Finished batch 10727. Saved: pfdi_stats_batch_10727.pkl
# Processing Batch 10728 (Rows 847570 - 847620)...
# Finished batch 10728. Saved: pfdi_stats_batch_10728.pkl
# Processing Batch 10729 (Rows 847620 - 847670)...
# Finished batch 10729. Saved: pfdi_stats_batch_10729.pkl
# Processing Batch 10730 (Rows 847670 - 847720)...
# Finished batch 10730. Saved: pfdi_stats_batch_10730.pkl
# Processing Batch 10731 (Rows 847720 - 847770)...
# Finished batch 10731. Saved: pfdi_stats_batch_10731.pkl
# Processing Batch 10732 (Rows 847770 - 847820)...
# Finished batch 10732. Saved: pfdi_stats_batch_10732.pkl
# Processing Batch 10733 (Rows 847820 - 847870)...
# Finished batch 10733. Saved: pfdi_stats_batch_10733.pkl
# Processing Batch 10734 (Rows 847870 - 847920)...
# Finished batch 10734. Saved: pfdi_stats_batch_10734.pkl
# Processing Batch 10735 (Rows 847920 - 847970)...
# Finished batch 10735. Saved: pfdi_stats_batch_10735.pkl
# Processing Batch 10736 (Rows 847970 - 848020)...
# Finished batch 10736. Saved: pfdi_stats_batch_10736.pkl
# Processing Batch 10737 (Rows 848020 - 848070)...
# Finished batch 10737. Saved: pfdi_stats_batch_10737.pkl
# Processing Batch 10738 (Rows 848070 - 848120)...
# Finished batch 10738. Saved: pfdi_stats_batch_10738.pkl
# Processing Batch 10739 (Rows 848120 - 848170)...
# Finished batch 10739. Saved: pfdi_stats_batch_10739.pkl
# Processing Batch 10740 (Rows 848170 - 848220)...
# Finished batch 10740. Saved: pfdi_stats_batch_10740.pkl
# Processing Batch 10741 (Rows 848220 - 848270)...
# Finished batch 10741. Saved: pfdi_stats_batch_10741.pkl
# Processing Batch 10742 (Rows 848270 - 848320)...
# Finished batch 10742. Saved: pfdi_stats_batch_10742.pkl
# Processing Batch 10743 (Rows 848320 - 848370)...
# Finished batch 10743. Saved: pfdi_stats_batch_10743.pkl
# Processing Batch 10744 (Rows 848370 - 848420)...
# Finished batch 10744. Saved: pfdi_stats_batch_10744.pkl
# Processing Batch 10745 (Rows 848420 - 848470)...
# Finished batch 10745. Saved: pfdi_stats_batch_10745.pkl
# Processing Batch 10746 (Rows 848470 - 848520)...
# Finished batch 10746. Saved: pfdi_stats_batch_10746.pkl
# Processing Batch 10747 (Rows 848520 - 848570)...
# Finished batch 10747. Saved: pfdi_stats_batch_10747.pkl
# Processing Batch 10748 (Rows 848570 - 848620)...
# Finished batch 10748. Saved: pfdi_stats_batch_10748.pkl
# Processing Batch 10749 (Rows 848620 - 848670)...
# Finished batch 10749. Saved: pfdi_stats_batch_10749.pkl
# Processing Batch 10750 (Rows 848670 - 848720)...
# Finished batch 10750. Saved: pfdi_stats_batch_10750.pkl
# Processing Batch 10751 (Rows 848720 - 848770)...
# Finished batch 10751. Saved: pfdi_stats_batch_10751.pkl
# Processing Batch 10752 (Rows 848770 - 848820)...
# Finished batch 10752. Saved: pfdi_stats_batch_10752.pkl
# Processing Batch 10753 (Rows 848820 - 848870)...
# Finished batch 10753. Saved: pfdi_stats_batch_10753.pkl
# Processing Batch 10754 (Rows 848870 - 848920)...
# Finished batch 10754. Saved: pfdi_stats_batch_10754.pkl
# Processing Batch 10755 (Rows 848920 - 848970)...
# Finished batch 10755. Saved: pfdi_stats_batch_10755.pkl
# Processing Batch 10756 (Rows 848970 - 849020)...
# Finished batch 10756. Saved: pfdi_stats_batch_10756.pkl
# Processing Batch 10757 (Rows 849020 - 849070)...
# Finished batch 10757. Saved: pfdi_stats_batch_10757.pkl
# Processing Batch 10758 (Rows 849070 - 849120)...
# Finished batch 10758. Saved: pfdi_stats_batch_10758.pkl
# Processing Batch 10759 (Rows 849120 - 849170)...
# Finished batch 10759. Saved: pfdi_stats_batch_10759.pkl
# Processing Batch 10760 (Rows 849170 - 849220)...
# Finished batch 10760. Saved: pfdi_stats_batch_10760.pkl
# Processing Batch 10761 (Rows 849220 - 849270)...
# Finished batch 10761. Saved: pfdi_stats_batch_10761.pkl
# Processing Batch 10762 (Rows 849270 - 849320)...
# Finished batch 10762. Saved: pfdi_stats_batch_10762.pkl
# Processing Batch 10763 (Rows 849320 - 849370)...
# Finished batch 10763. Saved: pfdi_stats_batch_10763.pkl
# Processing Batch 10764 (Rows 849370 - 849420)...
# Finished batch 10764. Saved: pfdi_stats_batch_10764.pkl
# Processing Batch 10765 (Rows 849420 - 849470)...
# Finished batch 10765. Saved: pfdi_stats_batch_10765.pkl
# Processing Batch 10766 (Rows 849470 - 849520)...
# Finished batch 10766. Saved: pfdi_stats_batch_10766.pkl
# Processing Batch 10767 (Rows 849520 - 849570)...
# Finished batch 10767. Saved: pfdi_stats_batch_10767.pkl
# Processing Batch 10768 (Rows 849570 - 849620)...
# Finished batch 10768. Saved: pfdi_stats_batch_10768.pkl
# Processing Batch 10769 (Rows 849620 - 849670)...
# Finished batch 10769. Saved: pfdi_stats_batch_10769.pkl
# Processing Batch 10770 (Rows 849670 - 849720)...
# Finished batch 10770. Saved: pfdi_stats_batch_10770.pkl
# Processing Batch 10771 (Rows 849720 - 849770)...
# Finished batch 10771. Saved: pfdi_stats_batch_10771.pkl
# Processing Batch 10772 (Rows 849770 - 849820)...
# Finished batch 10772. Saved: pfdi_stats_batch_10772.pkl
# Processing Batch 10773 (Rows 849820 - 849870)...
# Finished batch 10773. Saved: pfdi_stats_batch_10773.pkl
# Processing Batch 10774 (Rows 849870 - 849920)...
# Finished batch 10774. Saved: pfdi_stats_batch_10774.pkl
# Processing Batch 10775 (Rows 849920 - 849970)...
# Finished batch 10775. Saved: pfdi_stats_batch_10775.pkl
# Processing Batch 10776 (Rows 849970 - 850020)...
# Finished batch 10776. Saved: pfdi_stats_batch_10776.pkl
# Processing Batch 10777 (Rows 850020 - 850070)...
# Finished batch 10777. Saved: pfdi_stats_batch_10777.pkl
# Processing Batch 10778 (Rows 850070 - 850120)...
# Finished batch 10778. Saved: pfdi_stats_batch_10778.pkl
# Processing Batch 10779 (Rows 850120 - 850170)...
# Finished batch 10779. Saved: pfdi_stats_batch_10779.pkl
# Processing Batch 10780 (Rows 850170 - 850220)...
# Finished batch 10780. Saved: pfdi_stats_batch_10780.pkl
# Processing Batch 10781 (Rows 850220 - 850270)...
# Finished batch 10781. Saved: pfdi_stats_batch_10781.pkl
# Processing Batch 10782 (Rows 850270 - 850320)...
# Finished batch 10782. Saved: pfdi_stats_batch_10782.pkl
# Processing Batch 10783 (Rows 850320 - 850370)...
# Finished batch 10783. Saved: pfdi_stats_batch_10783.pkl
# Processing Batch 10784 (Rows 850370 - 850420)...
# Finished batch 10784. Saved: pfdi_stats_batch_10784.pkl
# Processing Batch 10785 (Rows 850420 - 850470)...
# Finished batch 10785. Saved: pfdi_stats_batch_10785.pkl
# Processing Batch 10786 (Rows 850470 - 850520)...
# Finished batch 10786. Saved: pfdi_stats_batch_10786.pkl
# Processing Batch 10787 (Rows 850520 - 850570)...
# Finished batch 10787. Saved: pfdi_stats_batch_10787.pkl
# Processing Batch 10788 (Rows 850570 - 850620)...
# Finished batch 10788. Saved: pfdi_stats_batch_10788.pkl
# Processing Batch 10789 (Rows 850620 - 850670)...
# Finished batch 10789. Saved: pfdi_stats_batch_10789.pkl
# Processing Batch 10790 (Rows 850670 - 850720)...
# Finished batch 10790. Saved: pfdi_stats_batch_10790.pkl
# Processing Batch 10791 (Rows 850720 - 850770)...
# Finished batch 10791. Saved: pfdi_stats_batch_10791.pkl
# Processing Batch 10792 (Rows 850770 - 850820)...
# Finished batch 10792. Saved: pfdi_stats_batch_10792.pkl
# Processing Batch 10793 (Rows 850820 - 850870)...
# Finished batch 10793. Saved: pfdi_stats_batch_10793.pkl
# Processing Batch 10794 (Rows 850870 - 850920)...
# Finished batch 10794. Saved: pfdi_stats_batch_10794.pkl
# Processing Batch 10795 (Rows 850920 - 850970)...
# Finished batch 10795. Saved: pfdi_stats_batch_10795.pkl
# Processing Batch 10796 (Rows 850970 - 851020)...
# Finished batch 10796. Saved: pfdi_stats_batch_10796.pkl
# Processing Batch 10797 (Rows 851020 - 851070)...
# Finished batch 10797. Saved: pfdi_stats_batch_10797.pkl
# Processing Batch 10798 (Rows 851070 - 851120)...
# Finished batch 10798. Saved: pfdi_stats_batch_10798.pkl
# Processing Batch 10799 (Rows 851120 - 851170)...
# Finished batch 10799. Saved: pfdi_stats_batch_10799.pkl
# Processing Batch 10800 (Rows 851170 - 851220)...
# Finished batch 10800. Saved: pfdi_stats_batch_10800.pkl
# Processing Batch 10801 (Rows 851220 - 851270)...
# Finished batch 10801. Saved: pfdi_stats_batch_10801.pkl
# Processing Batch 10802 (Rows 851270 - 851320)...
# Finished batch 10802. Saved: pfdi_stats_batch_10802.pkl
# Processing Batch 10803 (Rows 851320 - 851370)...
# Finished batch 10803. Saved: pfdi_stats_batch_10803.pkl
# Processing Batch 10804 (Rows 851370 - 851420)...
# Finished batch 10804. Saved: pfdi_stats_batch_10804.pkl
# Processing Batch 10805 (Rows 851420 - 851470)...
# Finished batch 10805. Saved: pfdi_stats_batch_10805.pkl
# Processing Batch 10806 (Rows 851470 - 851520)...
# Finished batch 10806. Saved: pfdi_stats_batch_10806.pkl
# Processing Batch 10807 (Rows 851520 - 851570)...
# Finished batch 10807. Saved: pfdi_stats_batch_10807.pkl
# Processing Batch 10808 (Rows 851570 - 851620)...
# Finished batch 10808. Saved: pfdi_stats_batch_10808.pkl
# Processing Batch 10809 (Rows 851620 - 851670)...
# Finished batch 10809. Saved: pfdi_stats_batch_10809.pkl
# Processing Batch 10810 (Rows 851670 - 851720)...
# Finished batch 10810. Saved: pfdi_stats_batch_10810.pkl
# Processing Batch 10811 (Rows 851720 - 851770)...
# Finished batch 10811. Saved: pfdi_stats_batch_10811.pkl
# Processing Batch 10812 (Rows 851770 - 851820)...
# Finished batch 10812. Saved: pfdi_stats_batch_10812.pkl
# Processing Batch 10813 (Rows 851820 - 851870)...
# Finished batch 10813. Saved: pfdi_stats_batch_10813.pkl
# Processing Batch 10814 (Rows 851870 - 851920)...
# Finished batch 10814. Saved: pfdi_stats_batch_10814.pkl
# Processing Batch 10815 (Rows 851920 - 851970)...
# Finished batch 10815. Saved: pfdi_stats_batch_10815.pkl
# Processing Batch 10816 (Rows 851970 - 852020)...
# Finished batch 10816. Saved: pfdi_stats_batch_10816.pkl
# Processing Batch 10817 (Rows 852020 - 852070)...
# Finished batch 10817. Saved: pfdi_stats_batch_10817.pkl
# Processing Batch 10818 (Rows 852070 - 852120)...
# Finished batch 10818. Saved: pfdi_stats_batch_10818.pkl
# Processing Batch 10819 (Rows 852120 - 852170)...
# Finished batch 10819. Saved: pfdi_stats_batch_10819.pkl
# Processing Batch 10820 (Rows 852170 - 852220)...
# Finished batch 10820. Saved: pfdi_stats_batch_10820.pkl
# Processing Batch 10821 (Rows 852220 - 852270)...
# Finished batch 10821. Saved: pfdi_stats_batch_10821.pkl
# Processing Batch 10822 (Rows 852270 - 852320)...
# Finished batch 10822. Saved: pfdi_stats_batch_10822.pkl
# Processing Batch 10823 (Rows 852320 - 852370)...
# Finished batch 10823. Saved: pfdi_stats_batch_10823.pkl
# Processing Batch 10824 (Rows 852370 - 852420)...
# Finished batch 10824. Saved: pfdi_stats_batch_10824.pkl
# Processing Batch 10825 (Rows 852420 - 852470)...
# Finished batch 10825. Saved: pfdi_stats_batch_10825.pkl
# Processing Batch 10826 (Rows 852470 - 852520)...
# Finished batch 10826. Saved: pfdi_stats_batch_10826.pkl
# Processing Batch 10827 (Rows 852520 - 852570)...
# Finished batch 10827. Saved: pfdi_stats_batch_10827.pkl
# Processing Batch 10828 (Rows 852570 - 852620)...
# Finished batch 10828. Saved: pfdi_stats_batch_10828.pkl
# Processing Batch 10829 (Rows 852620 - 852670)...
# Finished batch 10829. Saved: pfdi_stats_batch_10829.pkl
# Processing Batch 10830 (Rows 852670 - 852720)...
# Finished batch 10830. Saved: pfdi_stats_batch_10830.pkl
# Processing Batch 10831 (Rows 852720 - 852770)...
# Finished batch 10831. Saved: pfdi_stats_batch_10831.pkl
# Processing Batch 10832 (Rows 852770 - 852820)...
# Finished batch 10832. Saved: pfdi_stats_batch_10832.pkl
# Processing Batch 10833 (Rows 852820 - 852870)...
# Finished batch 10833. Saved: pfdi_stats_batch_10833.pkl
# Processing Batch 10834 (Rows 852870 - 852920)...
# Finished batch 10834. Saved: pfdi_stats_batch_10834.pkl
# Processing Batch 10835 (Rows 852920 - 852970)...
# Finished batch 10835. Saved: pfdi_stats_batch_10835.pkl
# Processing Batch 10836 (Rows 852970 - 853020)...
# Finished batch 10836. Saved: pfdi_stats_batch_10836.pkl
# Processing Batch 10837 (Rows 853020 - 853070)...
# Finished batch 10837. Saved: pfdi_stats_batch_10837.pkl
# Processing Batch 10838 (Rows 853070 - 853120)...
# Finished batch 10838. Saved: pfdi_stats_batch_10838.pkl
# Processing Batch 10839 (Rows 853120 - 853170)...
# Finished batch 10839. Saved: pfdi_stats_batch_10839.pkl
# Processing Batch 10840 (Rows 853170 - 853220)...
# Finished batch 10840. Saved: pfdi_stats_batch_10840.pkl
# Processing Batch 10841 (Rows 853220 - 853270)...
# Finished batch 10841. Saved: pfdi_stats_batch_10841.pkl
# Processing Batch 10842 (Rows 853270 - 853320)...
# Finished batch 10842. Saved: pfdi_stats_batch_10842.pkl
# Processing Batch 10843 (Rows 853320 - 853370)...
# Finished batch 10843. Saved: pfdi_stats_batch_10843.pkl
# Processing Batch 10844 (Rows 853370 - 853420)...
# Finished batch 10844. Saved: pfdi_stats_batch_10844.pkl
# Processing Batch 10845 (Rows 853420 - 853470)...
# Finished batch 10845. Saved: pfdi_stats_batch_10845.pkl
# Processing Batch 10846 (Rows 853470 - 853520)...
# Finished batch 10846. Saved: pfdi_stats_batch_10846.pkl
# Processing Batch 10847 (Rows 853520 - 853570)...
# Finished batch 10847. Saved: pfdi_stats_batch_10847.pkl
# Processing Batch 10848 (Rows 853570 - 853620)...
# Finished batch 10848. Saved: pfdi_stats_batch_10848.pkl
# Processing Batch 10849 (Rows 853620 - 853670)...
# Finished batch 10849. Saved: pfdi_stats_batch_10849.pkl
# Processing Batch 10850 (Rows 853670 - 853720)...
# Finished batch 10850. Saved: pfdi_stats_batch_10850.pkl
# Processing Batch 10851 (Rows 853720 - 853770)...
# Finished batch 10851. Saved: pfdi_stats_batch_10851.pkl
# Processing Batch 10852 (Rows 853770 - 853820)...
# Finished batch 10852. Saved: pfdi_stats_batch_10852.pkl
# Processing Batch 10853 (Rows 853820 - 853870)...
# Finished batch 10853. Saved: pfdi_stats_batch_10853.pkl
# Processing Batch 10854 (Rows 853870 - 853920)...
# Finished batch 10854. Saved: pfdi_stats_batch_10854.pkl
# Processing Batch 10855 (Rows 853920 - 853970)...
# Finished batch 10855. Saved: pfdi_stats_batch_10855.pkl
# Processing Batch 10856 (Rows 853970 - 854020)...
# Finished batch 10856. Saved: pfdi_stats_batch_10856.pkl
# Processing Batch 10857 (Rows 854020 - 854070)...
# Finished batch 10857. Saved: pfdi_stats_batch_10857.pkl
# Processing Batch 10858 (Rows 854070 - 854120)...
# Finished batch 10858. Saved: pfdi_stats_batch_10858.pkl
# Processing Batch 10859 (Rows 854120 - 854170)...
# Finished batch 10859. Saved: pfdi_stats_batch_10859.pkl
# Processing Batch 10860 (Rows 854170 - 854220)...
# Finished batch 10860. Saved: pfdi_stats_batch_10860.pkl
# Processing Batch 10861 (Rows 854220 - 854270)...
# Finished batch 10861. Saved: pfdi_stats_batch_10861.pkl
# Processing Batch 10862 (Rows 854270 - 854320)...
# Finished batch 10862. Saved: pfdi_stats_batch_10862.pkl
# Processing Batch 10863 (Rows 854320 - 854370)...
# Finished batch 10863. Saved: pfdi_stats_batch_10863.pkl
# Processing Batch 10864 (Rows 854370 - 854420)...
# Finished batch 10864. Saved: pfdi_stats_batch_10864.pkl
# Processing Batch 10865 (Rows 854420 - 854470)...
# Finished batch 10865. Saved: pfdi_stats_batch_10865.pkl
# Processing Batch 10866 (Rows 854470 - 854520)...
# Finished batch 10866. Saved: pfdi_stats_batch_10866.pkl
# Processing Batch 10867 (Rows 854520 - 854570)...
# Finished batch 10867. Saved: pfdi_stats_batch_10867.pkl
# Processing Batch 10868 (Rows 854570 - 854620)...
# Finished batch 10868. Saved: pfdi_stats_batch_10868.pkl
# Processing Batch 10869 (Rows 854620 - 854670)...
# Finished batch 10869. Saved: pfdi_stats_batch_10869.pkl
# Processing Batch 10870 (Rows 854670 - 854720)...
# Finished batch 10870. Saved: pfdi_stats_batch_10870.pkl
# Processing Batch 10871 (Rows 854720 - 854770)...
# Finished batch 10871. Saved: pfdi_stats_batch_10871.pkl
# Processing Batch 10872 (Rows 854770 - 854820)...
# Finished batch 10872. Saved: pfdi_stats_batch_10872.pkl
# Processing Batch 10873 (Rows 854820 - 854870)...
# Finished batch 10873. Saved: pfdi_stats_batch_10873.pkl
# Processing Batch 10874 (Rows 854870 - 854920)...
# Finished batch 10874. Saved: pfdi_stats_batch_10874.pkl
# Processing Batch 10875 (Rows 854920 - 854970)...
# Finished batch 10875. Saved: pfdi_stats_batch_10875.pkl
# Processing Batch 10876 (Rows 854970 - 855020)...
# Finished batch 10876. Saved: pfdi_stats_batch_10876.pkl
# Processing Batch 10877 (Rows 855020 - 855070)...
# Finished batch 10877. Saved: pfdi_stats_batch_10877.pkl
# Processing Batch 10878 (Rows 855070 - 855120)...
# Finished batch 10878. Saved: pfdi_stats_batch_10878.pkl
# Processing Batch 10879 (Rows 855120 - 855170)...
# Finished batch 10879. Saved: pfdi_stats_batch_10879.pkl
# Processing Batch 10880 (Rows 855170 - 855220)...
# Finished batch 10880. Saved: pfdi_stats_batch_10880.pkl
# Processing Batch 10881 (Rows 855220 - 855270)...
# Finished batch 10881. Saved: pfdi_stats_batch_10881.pkl
# Processing Batch 10882 (Rows 855270 - 855320)...
# Finished batch 10882. Saved: pfdi_stats_batch_10882.pkl
# Processing Batch 10883 (Rows 855320 - 855370)...
# Finished batch 10883. Saved: pfdi_stats_batch_10883.pkl
# Processing Batch 10884 (Rows 855370 - 855420)...
# Finished batch 10884. Saved: pfdi_stats_batch_10884.pkl
# Processing Batch 10885 (Rows 855420 - 855470)...
# Finished batch 10885. Saved: pfdi_stats_batch_10885.pkl
# Processing Batch 10886 (Rows 855470 - 855520)...
# Finished batch 10886. Saved: pfdi_stats_batch_10886.pkl
# Processing Batch 10887 (Rows 855520 - 855570)...
# Finished batch 10887. Saved: pfdi_stats_batch_10887.pkl
# Processing Batch 10888 (Rows 855570 - 855620)...
# Finished batch 10888. Saved: pfdi_stats_batch_10888.pkl
# Processing Batch 10889 (Rows 855620 - 855670)...
# Finished batch 10889. Saved: pfdi_stats_batch_10889.pkl
# Processing Batch 10890 (Rows 855670 - 855720)...
# Finished batch 10890. Saved: pfdi_stats_batch_10890.pkl
# Processing Batch 10891 (Rows 855720 - 855770)...
# Finished batch 10891. Saved: pfdi_stats_batch_10891.pkl
# ...
# Processing Batch 11285 (Rows 875420 - 875470)...
# Finished batch 11285. Saved: pfdi_stats_batch_11285.pkl
# Processing Batch 11286 (Rows 875470 - 875520)...
# Finished batch 11286. Saved: pfdi_stats_batch_11286.pkl
# Processing Batch 11287 (Rows 875520 - 875570)...
# Finished batch 11287. Saved: pfdi_stats_batch_11287.pkl
# Processing Batch 11288 (Rows 875570 - 875620)...
# Finished batch 11288. Saved: pfdi_stats_batch_11288.pkl
# Processing Batch 11289 (Rows 875620 - 875670)...
# Finished batch 11289. Saved: pfdi_stats_batch_11289.pkl
# Processing Batch 11290 (Rows 875670 - 875720)...
# Finished batch 11290. Saved: pfdi_stats_batch_11290.pkl
# Processing Batch 11291 (Rows 875720 - 875770)...
# Finished batch 11291. Saved: pfdi_stats_batch_11291.pkl
# Processing Batch 11292 (Rows 875770 - 875820)...
# Finished batch 11292. Saved: pfdi_stats_batch_11292.pkl
# Processing Batch 11293 (Rows 875820 - 875870)...
# Finished batch 11293. Saved: pfdi_stats_batch_11293.pkl
# Processing Batch 11294 (Rows 875870 - 875920)...
# Finished batch 11294. Saved: pfdi_stats_batch_11294.pkl
# Processing Batch 11295 (Rows 875920 - 875970)...
# Finished batch 11295. Saved: pfdi_stats_batch_11295.pkl
# Processing Batch 11296 (Rows 875970 - 876020)...
# Finished batch 11296. Saved: pfdi_stats_batch_11296.pkl
# Processing Batch 11297 (Rows 876020 - 876070)...
# Finished batch 11297. Saved: pfdi_stats_batch_11297.pkl
# Processing Batch 11298 (Rows 876070 - 876120)...
# Finished batch 11298. Saved: pfdi_stats_batch_11298.pkl
# Processing Batch 11299 (Rows 876120 - 876170)...
# Finished batch 11299. Saved: pfdi_stats_batch_11299.pkl
# Processing Batch 11300 (Rows 876170 - 876220)...
# Finished batch 11300. Saved: pfdi_stats_batch_11300.pkl
# Processing Batch 11301 (Rows 876220 - 876270)...
# Finished batch 11301. Saved: pfdi_stats_batch_11301.pkl
# Processing Batch 11302 (Rows 876270 - 876320)...
# Finished batch 11302. Saved: pfdi_stats_batch_11302.pkl
# Processing Batch 11303 (Rows 876320 - 876370)...
# Finished batch 11303. Saved: pfdi_stats_batch_11303.pkl
# Processing Batch 11304 (Rows 876370 - 876420)...
# Finished batch 11304. Saved: pfdi_stats_batch_11304.pkl
# Processing Batch 11305 (Rows 876420 - 876470)...
# Finished batch 11305. Saved: pfdi_stats_batch_11305.pkl
# Processing Batch 11306 (Rows 876470 - 876520)...
# Finished batch 11306. Saved: pfdi_stats_batch_11306.pkl
# Processing Batch 11307 (Rows 876520 - 876570)...
# Finished batch 11307. Saved: pfdi_stats_batch_11307.pkl
# Processing Batch 11308 (Rows 876570 - 876620)...
# Finished batch 11308. Saved: pfdi_stats_batch_11308.pkl
# Processing Batch 11309 (Rows 876620 - 876670)...
# Finished batch 11309. Saved: pfdi_stats_batch_11309.pkl
# Processing Batch 11310 (Rows 876670 - 876720)...
# Finished batch 11310. Saved: pfdi_stats_batch_11310.pkl
# Processing Batch 11311 (Rows 876720 - 876770)...
# Finished batch 11311. Saved: pfdi_stats_batch_11311.pkl
# Processing Batch 11312 (Rows 876770 - 876820)...
# Finished batch 11312. Saved: pfdi_stats_batch_11312.pkl
# Processing Batch 11313 (Rows 876820 - 876870)...
# Finished batch 11313. Saved: pfdi_stats_batch_11313.pkl
# Processing Batch 11314 (Rows 876870 - 876920)...
# Finished batch 11314. Saved: pfdi_stats_batch_11314.pkl
# Processing Batch 11315 (Rows 876920 - 876970)...
# Finished batch 11315. Saved: pfdi_stats_batch_11315.pkl
# Processing Batch 11316 (Rows 876970 - 877020)...
# Finished batch 11316. Saved: pfdi_stats_batch_11316.pkl
# Processing Batch 11317 (Rows 877020 - 877070)...
# Finished batch 11317. Saved: pfdi_stats_batch_11317.pkl
# Processing Batch 11318 (Rows 877070 - 877120)...
# Finished batch 11318. Saved: pfdi_stats_batch_11318.pkl
# Processing Batch 11319 (Rows 877120 - 877170)...
# Finished batch 11319. Saved: pfdi_stats_batch_11319.pkl
# Processing Batch 11320 (Rows 877170 - 877220)...
# Finished batch 11320. Saved: pfdi_stats_batch_11320.pkl
# Processing Batch 11321 (Rows 877220 - 877270)...
# Finished batch 11321. Saved: pfdi_stats_batch_11321.pkl
# Processing Batch 11322 (Rows 877270 - 877320)...
# Finished batch 11322. Saved: pfdi_stats_batch_11322.pkl
# Processing Batch 11323 (Rows 877320 - 877370)...
# Finished batch 11323. Saved: pfdi_stats_batch_11323.pkl
# Processing Batch 11324 (Rows 877370 - 877420)...
# Finished batch 11324. Saved: pfdi_stats_batch_11324.pkl
# Processing Batch 11325 (Rows 877420 - 877470)...
# Finished batch 11325. Saved: pfdi_stats_batch_11325.pkl
# Processing Batch 11326 (Rows 877470 - 877520)...
# Finished batch 11326. Saved: pfdi_stats_batch_11326.pkl
# Processing Batch 11327 (Rows 877520 - 877570)...
# Finished batch 11327. Saved: pfdi_stats_batch_11327.pkl
# Processing Batch 11328 (Rows 877570 - 877620)...
# Finished batch 11328. Saved: pfdi_stats_batch_11328.pkl
# Processing Batch 11329 (Rows 877620 - 877670)...
# Finished batch 11329. Saved: pfdi_stats_batch_11329.pkl
# Processing Batch 11330 (Rows 877670 - 877720)...
# Finished batch 11330. Saved: pfdi_stats_batch_11330.pkl
# Processing Batch 11331 (Rows 877720 - 877770)...
# Finished batch 11331. Saved: pfdi_stats_batch_11331.pkl
# Processing Batch 11332 (Rows 877770 - 877820)...
# Finished batch 11332. Saved: pfdi_stats_batch_11332.pkl
# Processing Batch 11333 (Rows 877820 - 877870)...
# Finished batch 11333. Saved: pfdi_stats_batch_11333.pkl
# Processing Batch 11334 (Rows 877870 - 877920)...
# Finished batch 11334. Saved: pfdi_stats_batch_11334.pkl
# Processing Batch 11335 (Rows 877920 - 877970)...
# Finished batch 11335. Saved: pfdi_stats_batch_11335.pkl
# Processing Batch 11336 (Rows 877970 - 878020)...
# Finished batch 11336. Saved: pfdi_stats_batch_11336.pkl
# Processing Batch 11337 (Rows 878020 - 878070)...
# Finished batch 11337. Saved: pfdi_stats_batch_11337.pkl
# Processing Batch 11338 (Rows 878070 - 878120)...
# Finished batch 11338. Saved: pfdi_stats_batch_11338.pkl
# Processing Batch 11339 (Rows 878120 - 878170)...
# Finished batch 11339. Saved: pfdi_stats_batch_11339.pkl
# Processing Batch 11340 (Rows 878170 - 878220)...
# Finished batch 11340. Saved: pfdi_stats_batch_11340.pkl
# Processing Batch 11341 (Rows 878220 - 878270)...
# Finished batch 11341. Saved: pfdi_stats_batch_11341.pkl
# Processing Batch 11342 (Rows 878270 - 878320)...
# Finished batch 11342. Saved: pfdi_stats_batch_11342.pkl
# Processing Batch 11343 (Rows 878320 - 878370)...
# Finished batch 11343. Saved: pfdi_stats_batch_11343.pkl
# Processing Batch 11344 (Rows 878370 - 878420)...
# Finished batch 11344. Saved: pfdi_stats_batch_11344.pkl
# Processing Batch 11345 (Rows 878420 - 878470)...
# Finished batch 11345. Saved: pfdi_stats_batch_11345.pkl
# Processing Batch 11346 (Rows 878470 - 878520)...
# Finished batch 11346. Saved: pfdi_stats_batch_11346.pkl
# Processing Batch 11347 (Rows 878520 - 878570)...
# Finished batch 11347. Saved: pfdi_stats_batch_11347.pkl
# Processing Batch 11348 (Rows 878570 - 878620)...
# Finished batch 11348. Saved: pfdi_stats_batch_11348.pkl
# Processing Batch 11349 (Rows 878620 - 878670)...
# Finished batch 11349. Saved: pfdi_stats_batch_11349.pkl
# Processing Batch 11350 (Rows 878670 - 878720)...
# Finished batch 11350. Saved: pfdi_stats_batch_11350.pkl
# Processing Batch 11351 (Rows 878720 - 878770)...
# Finished batch 11351. Saved: pfdi_stats_batch_11351.pkl
# Processing Batch 11352 (Rows 878770 - 878820)...
# Finished batch 11352. Saved: pfdi_stats_batch_11352.pkl
# Processing Batch 11353 (Rows 878820 - 878870)...
# Finished batch 11353. Saved: pfdi_stats_batch_11353.pkl
# Processing Batch 11354 (Rows 878870 - 878920)...
# Finished batch 11354. Saved: pfdi_stats_batch_11354.pkl
# Processing Batch 11355 (Rows 878920 - 878970)...
# Finished batch 11355. Saved: pfdi_stats_batch_11355.pkl
# Processing Batch 11356 (Rows 878970 - 879020)...
# Finished batch 11356. Saved: pfdi_stats_batch_11356.pkl
# Processing Batch 11357 (Rows 879020 - 879070)...
# Finished batch 11357. Saved: pfdi_stats_batch_11357.pkl
# Processing Batch 11358 (Rows 879070 - 879120)...
# Finished batch 11358. Saved: pfdi_stats_batch_11358.pkl
# Processing Batch 11359 (Rows 879120 - 879170)...
# Finished batch 11359. Saved: pfdi_stats_batch_11359.pkl
# Processing Batch 11360 (Rows 879170 - 879220)...
# Finished batch 11360. Saved: pfdi_stats_batch_11360.pkl
# Processing Batch 11361 (Rows 879220 - 879270)...
# Finished batch 11361. Saved: pfdi_stats_batch_11361.pkl
# Processing Batch 11362 (Rows 879270 - 879320)...
# Finished batch 11362. Saved: pfdi_stats_batch_11362.pkl
# Processing Batch 11363 (Rows 879320 - 879370)...
# Finished batch 11363. Saved: pfdi_stats_batch_11363.pkl
# Processing Batch 11364 (Rows 879370 - 879420)...
# Finished batch 11364. Saved: pfdi_stats_batch_11364.pkl
# Processing Batch 11365 (Rows 879420 - 879470)...
# Finished batch 11365. Saved: pfdi_stats_batch_11365.pkl
# Processing Batch 11366 (Rows 879470 - 879520)...
# Finished batch 11366. Saved: pfdi_stats_batch_11366.pkl
# Processing Batch 11367 (Rows 879520 - 879570)...
# Finished batch 11367. Saved: pfdi_stats_batch_11367.pkl
# Processing Batch 11368 (Rows 879570 - 879620)...
# Finished batch 11368. Saved: pfdi_stats_batch_11368.pkl
# Processing Batch 11369 (Rows 879620 - 879670)...
# Finished batch 11369. Saved: pfdi_stats_batch_11369.pkl
# Processing Batch 11370 (Rows 879670 - 879720)...
# Finished batch 11370. Saved: pfdi_stats_batch_11370.pkl
# Processing Batch 11371 (Rows 879720 - 879770)...
# Finished batch 11371. Saved: pfdi_stats_batch_11371.pkl
# Processing Batch 11372 (Rows 879770 - 879820)...
# Finished batch 11372. Saved: pfdi_stats_batch_11372.pkl
# Processing Batch 11373 (Rows 879820 - 879870)...
# Finished batch 11373. Saved: pfdi_stats_batch_11373.pkl
# Processing Batch 11374 (Rows 879870 - 879920)...
# Finished batch 11374. Saved: pfdi_stats_batch_11374.pkl
# Processing Batch 11375 (Rows 879920 - 879970)...
# Finished batch 11375. Saved: pfdi_stats_batch_11375.pkl
# Processing Batch 11376 (Rows 879970 - 880020)...
# Finished batch 11376. Saved: pfdi_stats_batch_11376.pkl
# Processing Batch 11377 (Rows 880020 - 880070)...
# Finished batch 11377. Saved: pfdi_stats_batch_11377.pkl
# Processing Batch 11378 (Rows 880070 - 880120)...
# Finished batch 11378. Saved: pfdi_stats_batch_11378.pkl
# Processing Batch 11379 (Rows 880120 - 880170)...
# Finished batch 11379. Saved: pfdi_stats_batch_11379.pkl
# Processing Batch 11380 (Rows 880170 - 880220)...
# Finished batch 11380. Saved: pfdi_stats_batch_11380.pkl
# Processing Batch 11381 (Rows 880220 - 880270)...
# Finished batch 11381. Saved: pfdi_stats_batch_11381.pkl
# Processing Batch 11382 (Rows 880270 - 880320)...
# Finished batch 11382. Saved: pfdi_stats_batch_11382.pkl
# Processing Batch 11383 (Rows 880320 - 880370)...
# Finished batch 11383. Saved: pfdi_stats_batch_11383.pkl
# Processing Batch 11384 (Rows 880370 - 880420)...
# Finished batch 11384. Saved: pfdi_stats_batch_11384.pkl
# Processing Batch 11385 (Rows 880420 - 880470)...
# Finished batch 11385. Saved: pfdi_stats_batch_11385.pkl
# Processing Batch 11386 (Rows 880470 - 880520)...
# Finished batch 11386. Saved: pfdi_stats_batch_11386.pkl
# Processing Batch 11387 (Rows 880520 - 880570)...
# Finished batch 11387. Saved: pfdi_stats_batch_11387.pkl
# Processing Batch 11388 (Rows 880570 - 880620)...
# Finished batch 11388. Saved: pfdi_stats_batch_11388.pkl
# Processing Batch 11389 (Rows 880620 - 880670)...
# Finished batch 11389. Saved: pfdi_stats_batch_11389.pkl
# Processing Batch 11390 (Rows 880670 - 880720)...
# Finished batch 11390. Saved: pfdi_stats_batch_11390.pkl
# Processing Batch 11391 (Rows 880720 - 880770)...
# Finished batch 11391. Saved: pfdi_stats_batch_11391.pkl
# Processing Batch 11392 (Rows 880770 - 880820)...
# Finished batch 11392. Saved: pfdi_stats_batch_11392.pkl
# Processing Batch 11393 (Rows 880820 - 880870)...
# Finished batch 11393. Saved: pfdi_stats_batch_11393.pkl
# Processing Batch 11394 (Rows 880870 - 880920)...
# Finished batch 11394. Saved: pfdi_stats_batch_11394.pkl
# Processing Batch 11395 (Rows 880920 - 880970)...
# Finished batch 11395. Saved: pfdi_stats_batch_11395.pkl
# Processing Batch 11396 (Rows 880970 - 881020)...
# Finished batch 11396. Saved: pfdi_stats_batch_11396.pkl
# Processing Batch 11397 (Rows 881020 - 881070)...
# Finished batch 11397. Saved: pfdi_stats_batch_11397.pkl
# Processing Batch 11398 (Rows 881070 - 881120)...
# Finished batch 11398. Saved: pfdi_stats_batch_11398.pkl
# Processing Batch 11399 (Rows 881120 - 881170)...
# Finished batch 11399. Saved: pfdi_stats_batch_11399.pkl
# Processing Batch 11400 (Rows 881170 - 881220)...
# Finished batch 11400. Saved: pfdi_stats_batch_11400.pkl
# Processing Batch 11401 (Rows 881220 - 881270)...
# Finished batch 11401. Saved: pfdi_stats_batch_11401.pkl
# Processing Batch 11402 (Rows 881270 - 881320)...
# Finished batch 11402. Saved: pfdi_stats_batch_11402.pkl
# Processing Batch 11403 (Rows 881320 - 881370)...
# Finished batch 11403. Saved: pfdi_stats_batch_11403.pkl
# Processing Batch 11404 (Rows 881370 - 881420)...
# Finished batch 11404. Saved: pfdi_stats_batch_11404.pkl
# Processing Batch 11405 (Rows 881420 - 881470)...
# Finished batch 11405. Saved: pfdi_stats_batch_11405.pkl
# Processing Batch 11406 (Rows 881470 - 881520)...
# Finished batch 11406. Saved: pfdi_stats_batch_11406.pkl
# Processing Batch 11407 (Rows 881520 - 881570)...
# Finished batch 11407. Saved: pfdi_stats_batch_11407.pkl
# Processing Batch 11408 (Rows 881570 - 881620)...
# Finished batch 11408. Saved: pfdi_stats_batch_11408.pkl
# Processing Batch 11409 (Rows 881620 - 881670)...
# Finished batch 11409. Saved: pfdi_stats_batch_11409.pkl
# Processing Batch 11410 (Rows 881670 - 881720)...
# Finished batch 11410. Saved: pfdi_stats_batch_11410.pkl
# Processing Batch 11411 (Rows 881720 - 881770)...
# Finished batch 11411. Saved: pfdi_stats_batch_11411.pkl
# Processing Batch 11412 (Rows 881770 - 881820)...
# Finished batch 11412. Saved: pfdi_stats_batch_11412.pkl
# Processing Batch 11413 (Rows 881820 - 881870)...
# Finished batch 11413. Saved: pfdi_stats_batch_11413.pkl
# Processing Batch 11414 (Rows 881870 - 881920)...
# Finished batch 11414. Saved: pfdi_stats_batch_11414.pkl
# Processing Batch 11415 (Rows 881920 - 881970)...
# Finished batch 11415. Saved: pfdi_stats_batch_11415.pkl
# Processing Batch 11416 (Rows 881970 - 882020)...
# Finished batch 11416. Saved: pfdi_stats_batch_11416.pkl
# Processing Batch 11417 (Rows 882020 - 882070)...
# Finished batch 11417. Saved: pfdi_stats_batch_11417.pkl
# Processing Batch 11418 (Rows 882070 - 882120)...
# Finished batch 11418. Saved: pfdi_stats_batch_11418.pkl
# Processing Batch 11419 (Rows 882120 - 882170)...
# Finished batch 11419. Saved: pfdi_stats_batch_11419.pkl
# Processing Batch 11420 (Rows 882170 - 882220)...
# Finished batch 11420. Saved: pfdi_stats_batch_11420.pkl
# Processing Batch 11421 (Rows 882220 - 882270)...
# Finished batch 11421. Saved: pfdi_stats_batch_11421.pkl
# Processing Batch 11422 (Rows 882270 - 882320)...
# Finished batch 11422. Saved: pfdi_stats_batch_11422.pkl
# Processing Batch 11423 (Rows 882320 - 882370)...
# Finished batch 11423. Saved: pfdi_stats_batch_11423.pkl
# Processing Batch 11424 (Rows 882370 - 882420)...
# Finished batch 11424. Saved: pfdi_stats_batch_11424.pkl
# Processing Batch 11425 (Rows 882420 - 882470)...
# Finished batch 11425. Saved: pfdi_stats_batch_11425.pkl
# Processing Batch 11426 (Rows 882470 - 882520)...
# Finished batch 11426. Saved: pfdi_stats_batch_11426.pkl
# Processing Batch 11427 (Rows 882520 - 882570)...
# Finished batch 11427. Saved: pfdi_stats_batch_11427.pkl
# Processing Batch 11428 (Rows 882570 - 882620)...
# Finished batch 11428. Saved: pfdi_stats_batch_11428.pkl
# Processing Batch 11429 (Rows 882620 - 882670)...
# Finished batch 11429. Saved: pfdi_stats_batch_11429.pkl
# Processing Batch 11430 (Rows 882670 - 882720)...
# Finished batch 11430. Saved: pfdi_stats_batch_11430.pkl
# Processing Batch 11431 (Rows 882720 - 882770)...
# Finished batch 11431. Saved: pfdi_stats_batch_11431.pkl
# Processing Batch 11432 (Rows 882770 - 882820)...
# Finished batch 11432. Saved: pfdi_stats_batch_11432.pkl
# Processing Batch 11433 (Rows 882820 - 882870)...
# Finished batch 11433. Saved: pfdi_stats_batch_11433.pkl
# Processing Batch 11434 (Rows 882870 - 882920)...
# Finished batch 11434. Saved: pfdi_stats_batch_11434.pkl
# Processing Batch 11435 (Rows 882920 - 882970)...
# Finished batch 11435. Saved: pfdi_stats_batch_11435.pkl
# Processing Batch 11436 (Rows 882970 - 882972)...
# Finished batch 11436. Saved: pfdi_stats_batch_11436.pkl
# Reached end of dataset. Stopping.

# %%
df_enriched
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#         Unnamed: 0                              uuid    area_km2 version  \
# 0                0  93e48341dbaa4be29a38b856d94206c5  191.436317    v3.1
# 1                1  939149831ea34c3e94712cc42c17c46a   14.208894    v3.1
# 2                2  931831f75479454cb3938811e64ce882   28.562733    v3.1
# 3                3  91bc68dde43646289c9e75b7d59e1711  108.562378    v3.1
# 4                4  8b849511de80423f98918f55af323e7e    0.104375    v3.1
# ...            ...                               ...         ...     ...
# 882967      882967  7dcf66e5f2cb41aeabbca2eceb2a8097  170.996837    v3.1
# 882968      882968  315638fd86a7475faa9080ad49611dcf   47.735869    v3.1
# 882969      882969  2a7732d881444a50b302459a74147b78    2.111778    v3.1
# 882970      882970  728e991979374bcf8be0ceec27f83474   69.695840    v3.1
# 882971      882971  4f4b5bb45a56407d8aeee1001c0f3a32   55.454698    v3.1
#
#           start_time      end_time  duration_days  \
# 0       9.466848e+08  9.466848e+08              1
# 1       9.466848e+08  9.466848e+08              1
# 2       9.466848e+08  9.466848e+08              1
# 3       9.466848e+08  9.466848e+08              1
# 4       9.466848e+08  9.466848e+08              1
# ...              ...           ...            ...
# 882967  1.761437e+09  1.761437e+09              1
# 882968  1.761437e+09  1.761437e+09              1
# 882969  1.761437e+09  1.761437e+09              1
# 882970  1.761437e+09  1.761437e+09              1
# 882971  1.761437e+09  1.761437e+09              1
#
#                                              geometry_wkt  \
# 0       POLYGON ((-7.6844751 33.499789, -7.5516781 33....
# 1       POLYGON ((-7.9863739 29.745153, -7.9965878 29....
# 2       POLYGON ((-98.97432499999999 19.337026, -98.93...
# 3       POLYGON ((30.936502 -29.872152, 30.928104 -29....
# 4       POLYGON ((16.547385 38.687964, 16.549982 38.68...
# ...                                                   ...
# 882967  POLYGON ((105.7873 21.524524, 105.70281 21.576...
# 882968  POLYGON ((108.19657 15.435928, 108.21532 15.49...
# 882969  POLYGON ((110.4417 -6.949991, 110.44865 -6.938...
# 882970  POLYGON ((107.57804 16.494362, 107.62911 16.46...
# 882971  POLYGON ((108.15568 15.394025, 108.14388 15.33...
#
#         urban_built_up_area_m2  polygon_total_area_m2  urban_percentage  \
# 0                    4608358.0           1.531473e+08          3.009102
# 1                     751304.0           9.880934e+06          7.603573
# 2                    3757833.0           1.180029e+07         31.845253
# 3                   26634641.0           1.273836e+08         20.908999
# 4                      49138.0           1.051849e+05         46.715826
# ...                        ...                    ...               ...
# 882967              13188502.0           1.484232e+08          8.885740
# 882968                104740.0           5.231977e+07          0.200192
# 882969                190181.0           2.413080e+06          7.881256
# 882970              10160252.0           6.160880e+07         16.491560
# 882971                 47594.0           3.495405e+07          0.136162
#
#         event_id  poly_area_km2      upa_max    upa_p95      upa_p99  \
# 0              0     152.737360  2144.798828   0.231797   506.047577
# 1              1       9.846162  1930.907593  24.820149  1929.830884
# 2              2      11.730829  8171.314453   0.613581     0.613581
# 3              3     126.937144  4441.062012   0.377705   243.834593
# 4              4       0.105030     0.107175   0.073682     0.073682
# ...          ...            ...          ...        ...          ...
# 882967    882967     147.693325  3142.486816   0.228462  2677.571888
# 882968    882968      52.021208    49.398094   1.377442    18.209266
# 882969    882969       2.397496    69.979530  57.835690    58.735450
# 882970    882970      61.264040  1600.166748   0.151170  1586.783159
# 882971    882971      34.744722  1439.864014   0.188242  1392.694507
#
#          PFDI_p95    idx_p95
# 0        0.001518   0.000010
# 1        2.520794   0.256018
# 2        0.052305   0.004459
# 3        0.002976   0.000023
# 4        0.701532   6.679364
# ...           ...        ...
# 882967   0.001547   0.000010
# 882968   0.026478   0.000509
# 882969  24.123371  10.061902
# 882970   0.002468   0.000040
# 882971   0.005418   0.000156
#
# [882972 rows x 18 columns]

# %%
# ============================================
# 8) CONCAT ALL BATCH RESULTS (OLD AND NEW)
# ============================================
print("\n--- FINALIZING ---")
print("Merging all PKL files found in output directory (previous + current)...")

pkl_pattern = os.path.join(OUT_DIR, "pfdi_stats_batch_*.pkl")
all_pkl_files = glob.glob(pkl_pattern)

if not all_pkl_files:
    print("No PKL files found. Nothing to merge.")
else:
    print(f"Found {len(all_pkl_files)} batch files to merge.")

    # Read and concatenate
    df_pfdi_stats = pd.concat((pd.read_pickle(f) for f in all_pkl_files), ignore_index=True)

    # Remove duplicates (safety check)
    # Keep last in case newer runs overwrote/updated an event
    df_pfdi_stats = df_pfdi_stats.drop_duplicates(subset=["event_id"], keep="last")

    # Save combined stats PKL
    df_pfdi_stats.to_pickle(OUT_STATS_PKL_ALL)
    print("Saved combined stats table:", OUT_STATS_PKL_ALL)
    print(f"Total unique events processed so far: {len(df_pfdi_stats)}")

    # ============================================
    # 9) MERGE PFDI BACK INTO THE ORIGINAL PKL
    # ============================================
    print("Merging with original DataFrame...")

    df_orig = pd.read_pickle(PKL_PATH)
    df_orig = add_event_id(df_orig)

    df_enriched = df_orig.merge(df_pfdi_stats, on="event_id", how="left")

    # ============================================
    # 10) QC + CALCULATE PFDI INDICES (SAVE THIS VERSION)
    # ============================================
    print("Applying QC filters and computing PFDI indices...")

    # Replace inf with NaN
    df_enriched = df_enriched.replace([np.inf, -np.inf], np.nan)

    cols_to_check = ["upa_p95", "upa_p99", "upa_max", "poly_area_km2"]

    # Drop missing key columns, then filter for positive values
    df_enriched_clean = df_enriched.dropna(subset=cols_to_check).copy()

    df_enriched_clean = df_enriched_clean[
        (df_enriched_clean["upa_p95"] > 0) &
        (df_enriched_clean["upa_p99"] > 0) &
        (df_enriched_clean["upa_max"] > 0) &
        (df_enriched_clean["poly_area_km2"] > 0)
    ].copy()

    # Compute PFDI indices (define them explicitly from UPA / area)
    df_enriched_clean["PFDI_p95"] = df_enriched_clean["upa_p95"] / df_enriched_clean["poly_area_km2"]
    df_enriched_clean["PFDI_p99"] = df_enriched_clean["upa_p99"] / df_enriched_clean["poly_area_km2"]
    df_enriched_clean["PFDI_max"] = df_enriched_clean["upa_max"] / df_enriched_clean["poly_area_km2"]

    print(f"Rows before QC: {len(df_enriched)}")
    print(f"Rows after QC (positive values & no NaNs): {len(df_enriched_clean)}")

    # Save the final PKL (clean + computed)
    df_enriched_clean.to_pickle(OUT_ENRICHED_PKL)
    print("Saved FINAL enriched+clean PKL:", OUT_ENRICHED_PKL)

    # Validation print
    if "PFDI_p95" in df_enriched_clean.columns:
        count_valid = df_enriched_clean["PFDI_p95"].count()
        print(f"Enriched+clean PKL contains {count_valid} events with valid PFDI_p95 data.")
    else:
        print("Warning: PFDI_p95 column not found in final DataFrame.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --- FINALIZING ---
# Merging all PKL files found in output directory (previous + current)...
# Found 11437 batch files to merge.
# Saved combined stats table: D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\pfdi_stats_ALL_batches.pkl
# Total unique events processed so far: 882972
# Merging with original DataFrame...
# Applying QC filters and computing PFDI indices...
# Rows before QC: 882972
# Rows after QC (positive values & no NaNs): 882957
# Saved FINAL enriched+clean PKL: D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\chronicle_df_with_pfdi_FULL.pkl
# Enriched+clean PKL contains 882957 events with valid PFDI_p95 data.

# %%
df_enriched_clean
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#         Unnamed: 0                              uuid    area_km2 version  \
# 0                0  93e48341dbaa4be29a38b856d94206c5  191.436317    v3.1
# 1                1  939149831ea34c3e94712cc42c17c46a   14.208894    v3.1
# 2                2  931831f75479454cb3938811e64ce882   28.562733    v3.1
# 3                3  91bc68dde43646289c9e75b7d59e1711  108.562378    v3.1
# 4                4  8b849511de80423f98918f55af323e7e    0.104375    v3.1
# ...            ...                               ...         ...     ...
# 882967      882967  7dcf66e5f2cb41aeabbca2eceb2a8097  170.996837    v3.1
# 882968      882968  315638fd86a7475faa9080ad49611dcf   47.735869    v3.1
# 882969      882969  2a7732d881444a50b302459a74147b78    2.111778    v3.1
# 882970      882970  728e991979374bcf8be0ceec27f83474   69.695840    v3.1
# 882971      882971  4f4b5bb45a56407d8aeee1001c0f3a32   55.454698    v3.1
#
#           start_time      end_time  duration_days  \
# 0       9.466848e+08  9.466848e+08              1
# 1       9.466848e+08  9.466848e+08              1
# 2       9.466848e+08  9.466848e+08              1
# 3       9.466848e+08  9.466848e+08              1
# 4       9.466848e+08  9.466848e+08              1
# ...              ...           ...            ...
# 882967  1.761437e+09  1.761437e+09              1
# 882968  1.761437e+09  1.761437e+09              1
# 882969  1.761437e+09  1.761437e+09              1
# 882970  1.761437e+09  1.761437e+09              1
# 882971  1.761437e+09  1.761437e+09              1
#
#                                              geometry_wkt  \
# 0       POLYGON ((-7.6844751 33.499789, -7.5516781 33....
# 1       POLYGON ((-7.9863739 29.745153, -7.9965878 29....
# 2       POLYGON ((-98.97432499999999 19.337026, -98.93...
# 3       POLYGON ((30.936502 -29.872152, 30.928104 -29....
# 4       POLYGON ((16.547385 38.687964, 16.549982 38.68...
# ...                                                   ...
# 882967  POLYGON ((105.7873 21.524524, 105.70281 21.576...
# 882968  POLYGON ((108.19657 15.435928, 108.21532 15.49...
# 882969  POLYGON ((110.4417 -6.949991, 110.44865 -6.938...
# 882970  POLYGON ((107.57804 16.494362, 107.62911 16.46...
# 882971  POLYGON ((108.15568 15.394025, 108.14388 15.33...
#
#         urban_built_up_area_m2  polygon_total_area_m2  urban_percentage  \
# 0                    4608358.0           1.531473e+08          3.009102
# 1                     751304.0           9.880934e+06          7.603573
# 2                    3757833.0           1.180029e+07         31.845253
# 3                   26634641.0           1.273836e+08         20.908999
# 4                      49138.0           1.051849e+05         46.715826
# ...                        ...                    ...               ...
# 882967              13188502.0           1.484232e+08          8.885740
# 882968                104740.0           5.231977e+07          0.200192
# 882969                190181.0           2.413080e+06          7.881256
# 882970              10160252.0           6.160880e+07         16.491560
# 882971                 47594.0           3.495405e+07          0.136162
#
#         event_id  poly_area_km2      upa_max    upa_p95      upa_p99  \
# 0              0     152.737360  2144.798828   0.231797   506.047577
# 1              1       9.846162  1930.907593  24.820149  1929.830884
# 2              2      11.730829  8171.314453   0.613581     0.613581
# 3              3     126.937144  4441.062012   0.377705   243.834593
# 4              4       0.105030     0.107175   0.073682     0.073682
# ...          ...            ...          ...        ...          ...
# 882967    882967     147.693325  3142.486816   0.228462  2677.571888
# 882968    882968      52.021208    49.398094   1.377442    18.209266
# 882969    882969       2.397496    69.979530  57.835690    58.735450
# 882970    882970      61.264040  1600.166748   0.151170  1586.783159
# 882971    882971      34.744722  1439.864014   0.188242  1392.694507
#
#          PFDI_p95    PFDI_p99    PFDI_max
# 0        0.001518    3.313188   14.042398
# 1        2.520794  195.998295  196.107648
# 2        0.052305    0.052305  696.567534
# 3        0.002976    1.920908   34.986308
# 4        0.701532    0.701532    1.020426
# ...           ...         ...         ...
# 882967   0.001547   18.129268   21.277108
# 882968   0.026478    0.350035    0.949576
# 882969  24.123371   24.498663   29.188589
# 882970   0.002468   25.900727   26.119184
# 882971   0.005418   40.083628   41.441230
#
# [882957 rows x 19 columns]
