# %% [markdown]
# # Chronicle Flood Database Intersection with MERIT Hydro dataset
#
# This notebook provides a comprehensive analysis of the Chronicle urban flood dataset, containing over 880,000 flood events worldwide from 2000-2025.

# %% [markdown]
# ## Hydro-merit upa index:

# %%
# ============================================
# 0) IMPORTS
# ============================================
import os
import glob
import math
import pandas as pd
import geopandas as gpd
from shapely import wkt

import ee
import geemap


# ============================================
# 1) CONFIGURATION
# ============================================
PKL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl"
GEOM_WKT_COL = "geometry_wkt"

# Earth Engine dataset
MERIT_IMAGE_ID = "MERIT/Hydro/v1_0_1"
UPA_BAND = "upa"  # upstream drainage area (km^2)

# Batch settings
BATCH_SIZE = 2000
N_BATCHES_TO_RUN = 20  # Will run 20 NEW batches starting from the last saved one

# Zonal stats settings
SCALE_M = 90

# Output settings
OUT_DIR = r"D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs"
# The final output filenames
OUT_STATS_CSV_ALL = os.path.join(OUT_DIR, "pfdi_stats_ALL_batches.csv")
OUT_ENRICHED_PKL = os.path.join(OUT_DIR, "chronicle_urban_df_with_pfdi_FULL.pkl")

# Map preview (set to False to speed up processing if map is not needed)
SHOW_MAP_PREVIEW = False 
MAP_CENTER = (20, 0)
MAP_ZOOM = 2


# ============================================
# 2) HELPERS
# ============================================
def ensure_out_dir(path):
    """Create output directory if it doesn't exist."""
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)


def fix_geometry_safe(geom):
    """Fix minor geometry issues; returns original geometry if fix fails."""
    try:
        if geom is None:
            return None
        return geom.buffer(0)
    except Exception:
        return geom


def add_event_id(df_in):
    """Add stable integer event_id based on the DataFrame index."""
    df_out = df_in.copy()
    df_out["event_id"] = df_out.index.astype(int)
    return df_out


def compute_area_km2(gdf_wgs84):
    """Compute polygon area in km^2 using an equal-area CRS."""
    gdf_area = gdf_wgs84.to_crs("EPSG:6933").copy()
    return (gdf_area.geometry.area / 1_000_000.0).astype(float)


def ee_fc_to_df(fc):
    """Convert an EE FeatureCollection to a pandas DataFrame with robust fallbacks."""
    if hasattr(geemap, "ee_to_df"):
        return geemap.ee_to_df(fc)

    if hasattr(geemap, "ee_to_pandas"):
        return geemap.ee_to_pandas(fc)

    # Fallback: pull features client-side (slower, but robust for small batches)
    features = fc.getInfo().get("features", [])
    rows = [f.get("properties", {}) for f in features]
    return pd.DataFrame(rows)


def initialize_ee():
    """Initialize Earth Engine; authenticate interactively if needed."""
    try:
        ee.Initialize()
        print("Earth Engine initialized.")
    except Exception:
        print("Earth Engine not initialized. Running authentication...")
        ee.Authenticate()
        ee.Initialize()
        print("Earth Engine authenticated and initialized.")


def pick_stat_column(columns, preferred, fallback):
    """Pick a column name from EE output (supports with/without band prefix)."""
    if preferred in columns:
        return preferred
    if fallback in columns:
        return fallback
    return None


def get_next_batch_index(out_dir):
    """
    Scans the output directory for existing batch CSV files,
    finds the highest batch number, and returns (highest + 1).
    Returns 0 if no files are found.
    """
    if not os.path.exists(out_dir):
        return 0
    
    # Pattern to match: pfdi_stats_batch_XXXX.csv
    pattern = os.path.join(out_dir, "pfdi_stats_batch_*.csv")
    files = glob.glob(pattern)
    
    if not files:
        return 0
    
    max_batch = -1
    for f in files:
        try:
            # Filename example: ".../pfdi_stats_batch_0004.csv"
            filename = os.path.basename(f)
            # Extract number: split by '_' then by '.'
            num_part = filename.split('_')[-1].split('.')[0]
            batch_num = int(num_part)
            
            if batch_num > max_batch:
                max_batch = batch_num
        except ValueError:
            continue 
            
    return max_batch + 1


# ============================================
# 3) AUTHENTICATE & INITIALIZE EARTH ENGINE
# ============================================
initialize_ee()


# ============================================
# 4) LOAD PKL AND PREPARE GEODATAFRAME
# ============================================
ensure_out_dir(OUT_DIR)

df = pd.read_pickle(PKL_PATH)
df = add_event_id(df)

if GEOM_WKT_COL not in df.columns:
    raise ValueError(f"Column '{GEOM_WKT_COL}' not found. Available columns: {list(df.columns)}")

gdf = gpd.GeoDataFrame(
    df,
    geometry=df[GEOM_WKT_COL].apply(wkt.loads),
    crs="EPSG:4326"
)

gdf["geometry"] = gdf["geometry"].apply(fix_geometry_safe)
gdf = gdf[gdf.geometry.notnull()].copy()

gdf_min = gdf[["event_id", "geometry"]].copy()
gdf_min["poly_area_km2"] = compute_area_km2(gdf_min)

print("Chronicle GeoDataFrame loaded.")
print("Total Rows in Dataset:", len(gdf_min))


# ============================================
# 5) LOAD MERIT HYDRO
# ============================================
merit = ee.Image(MERIT_IMAGE_ID)
upa = merit.select(UPA_BAND)

# ============================================
# 6) DEFINE REDUCER
# ============================================
reducer = ee.Reducer.max().combine(
    ee.Reducer.percentile([95, 99]),
    sharedInputs=True
)


# ============================================
# 7) RUN NEW BATCHES (INCREMENTAL)
# ============================================
# Auto-detect where to start based on existing files
start_batch_index = get_next_batch_index(OUT_DIR)
n_rows = len(gdf_min)

print(f"--- AUTO-DETECT ---")
print(f"Starting from Batch Index: {start_batch_index}")
print(f"Planning to run {N_BATCHES_TO_RUN} new batches.")

batch_outputs = []

for batch_i in range(start_batch_index, start_batch_index + N_BATCHES_TO_RUN):
    i0 = batch_i * BATCH_SIZE
    i1 = min((batch_i + 1) * BATCH_SIZE, n_rows)

    # Stop if we have exceeded the dataset size
    if i0 >= n_rows:
        print("Reached end of dataset. Stopping.")
        break

    print(f"Processing Batch {batch_i} (Rows {i0} - {i1})...")

    gdf_batch = gdf_min.iloc[i0:i1].copy()

    # Convert batch polygons to EE FeatureCollection
    fc = geemap.geopandas_to_ee(gdf_batch[["event_id", "geometry"]])

    # Compute zonal stats
    stats_fc = upa.reduceRegions(
        collection=fc,
        reducer=reducer,
        scale=SCALE_M
    )

    df_stats = ee_fc_to_df(stats_fc)

    # Merge local area
    df_area = gdf_batch[["event_id", "poly_area_km2"]].copy()
    out = df_stats.merge(df_area, on="event_id", how="left")

    # Handle EE output column naming differences
    max_col = pick_stat_column(out.columns, "upa_max", "max")
    p95_col = pick_stat_column(out.columns, "upa_p95", "p95")
    p99_col = pick_stat_column(out.columns, "upa_p99", "p99")

    if p95_col is None:
        # If empty batch or error, skip
        print(f"Warning: Batch {batch_i} returned empty or invalid stats.")
        continue

    # Compute PFDI
    out["PFDI"] = out[p95_col] / out["poly_area_km2"]

    # Standardize column names
    rename_map = {}
    if max_col is not None:
        rename_map[max_col] = "upa_max"
    if p95_col is not None:
        rename_map[p95_col] = "upa_p95"
    if p99_col is not None:
        rename_map[p99_col] = "upa_p99"
    out = out.rename(columns=rename_map)

    # Keep a clean set of columns
    keep_cols = ["event_id", "poly_area_km2", "upa_max", "upa_p95", "upa_p99", "PFDI"]
    keep_cols = [c for c in keep_cols if c in out.columns]
    out = out[keep_cols].copy()

    # Save partial result immediately
    partial_path = os.path.join(OUT_DIR, f"pfdi_stats_batch_{batch_i:04d}.csv")
    out.to_csv(partial_path, index=False)

    batch_outputs.append(out)

    print(f"Finished batch {batch_i}. Saved: {os.path.basename(partial_path)}")


# ============================================
# 8) CONCAT ALL BATCH RESULTS (OLD AND NEW)
# ============================================
print("\n--- FINALIZING ---")
print("Merging all CSV files found in output directory (previous + current)...")

# Find all batch files in the directory
csv_pattern = os.path.join(OUT_DIR, "pfdi_stats_batch_*.csv")
all_csv_files = glob.glob(csv_pattern)

if not all_csv_files:
    print("No CSV files found. Nothing to merge.")
else:
    print(f"Found {len(all_csv_files)} batch files to merge.")

    # Read and concatenate
    df_pfdi_stats = pd.concat((pd.read_csv(f) for f in all_csv_files), ignore_index=True)

    # Remove duplicates (safety check)
    df_pfdi_stats = df_pfdi_stats.drop_duplicates(subset=["event_id"])

    # Save the combined stats CSV
    df_pfdi_stats.to_csv(OUT_STATS_CSV_ALL, index=False)
    print("Saved combined stats table:", OUT_STATS_CSV_ALL)
    print(f"Total unique events processed so far: {len(df_pfdi_stats)}")


    # ============================================
    # 9) MERGE PFDI BACK INTO THE ORIGINAL PKL
    # ============================================
    print("Merging with original DataFrame...")

    # Reload original to ensure clean state
    df_orig = pd.read_pickle(PKL_PATH)
    df_orig = add_event_id(df_orig)

    # Merge the accumulated stats
    df_enriched = df_orig.merge(df_pfdi_stats, on="event_id", how="left")

    # Save the final PKL
    df_enriched.to_pickle(OUT_ENRICHED_PKL)

    print("Saved FINAL enriched PKL:", OUT_ENRICHED_PKL)
    
    # Validation print
    count_valid = df_enriched["PFDI"].count()
    print(f"Enriched PKL contains {count_valid} events with valid PFDI data.")
# Out:
# Earth Engine initialized.
# Chronicle GeoDataFrame loaded.
# Total Rows in Dataset: 882972
# --- AUTO-DETECT ---
# Starting from Batch Index: 5
# Planning to run 20 new batches.
# Processing Batch 5 (Rows 10000 - 12000)...
# Finished batch 5. Saved: pfdi_stats_batch_0005.csv
# Processing Batch 6 (Rows 12000 - 14000)...
# Finished batch 6. Saved: pfdi_stats_batch_0006.csv
# Processing Batch 7 (Rows 14000 - 16000)...
# Finished batch 7. Saved: pfdi_stats_batch_0007.csv
# Processing Batch 8 (Rows 16000 - 18000)...
# Finished batch 8. Saved: pfdi_stats_batch_0008.csv
# Processing Batch 9 (Rows 18000 - 20000)...
# Finished batch 9. Saved: pfdi_stats_batch_0009.csv
# Processing Batch 10 (Rows 20000 - 22000)...
# Finished batch 10. Saved: pfdi_stats_batch_0010.csv
# Processing Batch 11 (Rows 22000 - 24000)...
# Finished batch 11. Saved: pfdi_stats_batch_0011.csv
# Processing Batch 12 (Rows 24000 - 26000)...
# Finished batch 12. Saved: pfdi_stats_batch_0012.csv
# Processing Batch 13 (Rows 26000 - 28000)...
# Finished batch 13. Saved: pfdi_stats_batch_0013.csv
# Processing Batch 14 (Rows 28000 - 30000)...
# Finished batch 14. Saved: pfdi_stats_batch_0014.csv
# Processing Batch 15 (Rows 30000 - 32000)...
# Finished batch 15. Saved: pfdi_stats_batch_0015.csv
# Processing Batch 16 (Rows 32000 - 34000)...
# Finished batch 16. Saved: pfdi_stats_batch_0016.csv
# Processing Batch 17 (Rows 34000 - 36000)...
# Finished batch 17. Saved: pfdi_stats_batch_0017.csv
# Processing Batch 18 (Rows 36000 - 38000)...
# Finished batch 18. Saved: pfdi_stats_batch_0018.csv
# Processing Batch 19 (Rows 38000 - 40000)...
# Finished batch 19. Saved: pfdi_stats_batch_0019.csv
# Processing Batch 20 (Rows 40000 - 42000)...
# Finished batch 20. Saved: pfdi_stats_batch_0020.csv
# Processing Batch 21 (Rows 42000 - 44000)...
# Finished batch 21. Saved: pfdi_stats_batch_0021.csv
# Processing Batch 22 (Rows 44000 - 46000)...
# Finished batch 22. Saved: pfdi_stats_batch_0022.csv
# Processing Batch 23 (Rows 46000 - 48000)...
# Finished batch 23. Saved: pfdi_stats_batch_0023.csv
# Processing Batch 24 (Rows 48000 - 50000)...
# Finished batch 24. Saved: pfdi_stats_batch_0024.csv
#
# --- FINALIZING ---
# Merging all CSV files found in output directory (previous + current)...
# Found 25 batch files to merge.
# Saved combined stats table: D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\pfdi_stats_ALL_batches.csv
# Total unique events processed so far: 50000
# Merging with original DataFrame...
# Saved FINAL enriched PKL: D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl
# Enriched PKL contains 50000 events with valid PFDI data.

# %%
import pandas as pd
import numpy as np

ENRICHED_PKL = r"D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl"

df_pfdi_clean = pd.read_pickle(ENRICHED_PKL)

df_pfdi_clean = df_pfdi_clean.replace([np.inf, -np.inf], np.nan)
df_pfdi_clean = df_pfdi_clean.dropna(subset=["PFDI", "poly_area_km2"]).copy()
df_pfdi_clean = df_pfdi_clean[(df_pfdi_clean["PFDI"] > 0) & (df_pfdi_clean["poly_area_km2"] > 0)].copy()

df_pfdi_clean
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        Unnamed: 0                              uuid     area_km2 version  \
# 0               0  93e48341dbaa4be29a38b856d94206c5   191.436317    v3.1
# 1               1  939149831ea34c3e94712cc42c17c46a    14.208894    v3.1
# 2               2  931831f75479454cb3938811e64ce882    28.562733    v3.1
# 3               3  91bc68dde43646289c9e75b7d59e1711   108.562378    v3.1
# 4               4  8b849511de80423f98918f55af323e7e     0.104375    v3.1
# ...           ...                               ...          ...     ...
# 49995       49995  0ef2b7fb7a5749cc99087e318be87a02  1290.947674    v3.1
# 49996       49996  12833ebb8c4f4710a050d58019ca2d15     2.377345    v3.1
# 49997       49997  11ce718dfa9f47c39920851015c19b1b    16.183768    v3.1
# 49998       49998  09ce1f2b6e1f42f4bfe68948a1007d85    48.463882    v3.1
# 49999       49999  62c8d1b9357d475b8334081f399cc3ec  2719.068665    v3.1
#
#          start_time      end_time  duration_days  \
# 0      9.466848e+08  9.466848e+08              1
# 1      9.466848e+08  9.466848e+08              1
# 2      9.466848e+08  9.466848e+08              1
# 3      9.466848e+08  9.466848e+08              1
# 4      9.466848e+08  9.466848e+08              1
# ...             ...           ...            ...
# 49995  1.315354e+09  1.315526e+09              3
# 49996  1.315354e+09  1.315354e+09              1
# 49997  1.315354e+09  1.315440e+09              2
# 49998  1.315354e+09  1.315354e+09              1
# 49999  1.315354e+09  1.315354e+09              1
#
#                                             geometry_wkt  \
# 0      POLYGON ((-7.6844751 33.499789, -7.5516781 33....
# 1      POLYGON ((-7.9863739 29.745153, -7.9965878 29....
# 2      POLYGON ((-98.97432499999999 19.337026, -98.93...
# 3      POLYGON ((30.936502 -29.872152, 30.928104 -29....
# 4      POLYGON ((16.547385 38.687964, 16.549982 38.68...
# ...                                                  ...
# 49995  POLYGON ((-77.08639100000001 38.706227, -76.90...
# 49996  POLYGON ((-77.06259900000001 38.806513, -77.03...
# 49997  POLYGON ((-74.222114 42.953833, -74.17101 42.9...
# 49998  POLYGON ((68.71056400000001 27.527444, 68.7675...
# 49999  POLYGON ((-78.650881 33.945111, -78.544977 34....
#
#        urban_built_up_area_m2  polygon_total_area_m2  urban_percentage  \
# 0                   4608358.0           1.531473e+08          3.009102
# 1                    751304.0           9.880934e+06          7.603573
# 2                   3757833.0           1.180029e+07         31.845253
# 3                  26634641.0           1.273836e+08         20.908999
# 4                     49138.0           1.051849e+05         46.715826
# ...                       ...                    ...               ...
# 49995             103821055.0           1.317200e+09          7.881952
# 49996                488299.0           1.583991e+06         30.827141
# 49997               2011635.0           1.556504e+07         12.924062
# 49998               4383259.0           3.632110e+07         12.068078
# 49999              40910501.0           2.813277e+09          1.454194
#
#        event_id  poly_area_km2       upa_max    upa_p95      upa_p99      PFDI
# 0             0     152.737360   2144.798828   0.231797   506.047577  0.001518
# 1             1       9.846162   1930.907593  24.820149  1929.830884  2.520794
# 2             2      11.730829   8171.314453   0.613581     0.613581  0.052305
# 3             3     126.937144   4441.062012   0.377705   243.834593  0.002976
# 4             4       0.105030      0.107175   0.073682     0.073682  0.701532
# ...         ...            ...           ...        ...          ...       ...
# 49995     49995    1313.608842  31238.613281   0.633544     0.633544  0.000482
# 49996     49996       1.581620      5.215271   0.203568     0.824458  0.128709
# 49997     49997      15.556599   8305.956055  95.613975  8294.133199  6.146200
# 49998     49998      36.182636     37.626846   1.097725     8.316367  0.030338
# 49999     49999    2804.540715  23619.748047   0.697776     0.697776  0.000249
#
# [50000 rows x 17 columns]

# %%
# =========================
# Plotting
# =========================
plt.figure(figsize=(10, 8))

# Define X axis data
x = df_pfdi_clean["poly_area_km2"]

# Plot UPA Max (Red) - Plotted first as it is likely the largest value
plt.scatter(
    x, 
    df_pfdi_clean["upa_max"], 
    color='red', 
    alpha=0.5, 
    label='UPA Max', 
    s=15
)

# Plot UPA p99 (Orange)
plt.scatter(
    x, 
    df_pfdi_clean["upa_p99"], 
    color='orange', 
    alpha=0.5, 
    label='UPA p99', 
    s=15
)

# Plot UPA p95 (Blue) - Plotted last to be on top
plt.scatter(
    x, 
    df_pfdi_clean["upa_p95"], 
    color='blue', 
    alpha=0.5, 
    label='UPA p95', 
    s=15
)

# =========================
# Formatting
# =========================
plt.xlabel("Polygon Area (km²)")
plt.ylabel("Upstream Drainage Area (UPA) [km²]")
plt.title("Polygon Area vs. UPA Statistics (Max, p99, p95)")
plt.legend()
plt.grid(True, which="both", linestyle="--", alpha=0.6)

# Log-log scale is essential for hydrological area data
plt.xscale("log")
plt.yscale("log")

# Optional: Add a 1:1 identity line for reference
# Points below this line have UPA < Area (Local rain / Pluvial)
# Points above this line have UPA > Area (River flow / Fluvial)
limit_min = min(df_pfdi_clean["poly_area_km2"].min(), df_pfdi_clean["upa_p95"].min())
limit_max = max(df_pfdi_clean["poly_area_km2"].max(), df_pfdi_clean["upa_max"].max())
plt.plot([limit_min, limit_max], [limit_min, limit_max], color='black', linestyle='--', linewidth=1, label="1:1 Line")

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import numpy as np
import matplotlib.pyplot as plt

# =========================
# 1. Filter Data
# =========================
# Filter for polygons smaller than or equal to 500 km^2
df_subset = df_pfdi_clean[df_pfdi_clean["poly_area_km2"] <= 500].copy()
# df_subset = df_pfdi_clean
print(f"Subset size (Area <= 500 km^2): {len(df_subset)} events")

# =========================
# 2. Calculate Indices
# =========================
# Calculate the ratio (Index) for each metric
# Index = UPA_metric / Polygon_Area
df_subset["idx_max"] = df_subset["upa_max"] / df_subset["poly_area_km2"]
df_subset["idx_p99"] = df_subset["upa_p99"] / df_subset["poly_area_km2"]
df_subset["idx_p95"] = df_subset["upa_p95"] / df_subset["poly_area_km2"]

# =========================
# 3. Plot Histograms
# =========================
plt.figure(figsize=(12, 7))

# Create log-spaced bins for better visualization of the distribution
# Spanning from the smallest index value to the largest
min_val = min(df_subset["idx_p95"].min(), df_subset["idx_max"].min())
max_val = max(df_subset["idx_p95"].max(), df_subset["idx_max"].max())

# Avoid log(0) issues if min_val is 0 (though we cleaned zeros earlier)
if min_val <= 0: min_val = 0.001 

bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# Plot Histogram: Max (Red)
plt.hist(
    df_subset["idx_max"], 
    bins=bins, 
    alpha=0.4, 
    color='red', 
    label='Index (Max)', 
    edgecolor='black'
)

# Plot Histogram: P99 (Orange)
plt.hist(
    df_subset["idx_p99"], 
    bins=bins, 
    alpha=0.4, 
    color='orange', 
    label='Index (P99)', 
    edgecolor='black'
)

# Plot Histogram: P95 (Blue)
plt.hist(
    df_subset["idx_p95"], 
    bins=bins, 
    alpha=0.4, 
    color='blue', 
    label='Index (P95)', 
    edgecolor='black'
)

# =========================
# 4. Formatting
# =========================
plt.xscale("log")
plt.xlabel("Index Value (UPA / Area) [Log Scale]")
plt.ylabel("Count of Events")
plt.title("Distribution of Flood Indices (Polygons <= 500 km²)")
plt.legend()
plt.grid(True, which="both", linestyle="--", alpha=0.5)

# Add a vertical line at Index = 1 (Threshold for Pluvial/Fluvial)
plt.axvline(x=1, color='black', linestyle='--', linewidth=2, label="Index = 1")

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Subset size (Area <= 500 km^2): 42779 events

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# =========================
# 1. Filter Data & Calc Indices
# =========================
# Filter: Area <= 500 km^2
df_subset = df_pfdi_clean[df_pfdi_clean["poly_area_km2"] <= 500].copy()

# Calculate Indices (UPA / Area)
idx_p95 = (df_subset["upa_p95"] / df_subset["poly_area_km2"]).dropna()
idx_p99 = (df_subset["upa_p99"] / df_subset["poly_area_km2"]).dropna()
idx_max = (df_subset["upa_max"] / df_subset["poly_area_km2"]).dropna()

# Organize data in the requested order: P95 (Left) -> P99 (Middle) -> Max (Right)
data_to_plot = [idx_p95, idx_p99, idx_max]

# =========================
# 2. Calculate Percentages (<= 1)
# =========================
def get_pct_below_one(series):
    count_below = (series <= 1).sum()
    total = len(series)
    return (count_below / total) * 100

pct_p95 = get_pct_below_one(idx_p95)
pct_p99 = get_pct_below_one(idx_p99)
pct_max = get_pct_below_one(idx_max)

# Print to Console
print("--- Percentage of Pluvial Events (Index <= 1) ---")
print(f"Based on P95 UPA: {pct_p95:.2f}%")
print(f"Based on P99 UPA: {pct_p99:.2f}%")
print(f"Based on Max UPA: {pct_max:.2f}%")

# Create labels in the correct order
labels = [
    f'Index (P95)\n({pct_p95:.1f}% $\leq$ 1)', 
    f'Index (P99)\n({pct_p99:.1f}% $\leq$ 1)', 
    f'Index (Max)\n({pct_max:.1f}% $\leq$ 1)'
]

# =========================
# 3. Create Boxplot
# =========================
plt.figure(figsize=(11, 8))

# Define style properties
median_props = dict(linestyle='-', linewidth=2, color='orange')
mean_props = dict(marker='D', markeredgecolor='black', markerfacecolor='green', markersize=8)
box_props = dict(linestyle='-', linewidth=1.5)

bplot = plt.boxplot(
    data_to_plot,
    labels=labels,
    patch_artist=True,
    showmeans=True,
    meanprops=mean_props,
    medianprops=median_props,
    boxprops=box_props
)

# Custom Colors: Blue (P95) -> Orange (P99) -> Red (Max)
colors = ['lightblue', 'bisque', 'mistyrose']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

# Reference Line (Index = 1)
plt.axhline(y=1, color='black', linestyle='--', linewidth=1.5, alpha=0.7, label='1:1 Ratio')

# =========================
# 4. Formatting
# =========================
plt.yscale("log")
plt.ylabel("Index Value (UPA / Area) [Log Scale]", fontsize=12)
plt.title("Flood Index Distribution & Pluvial Share\n(Polygons <= 500 km²)", fontsize=14)

# Custom Legend
legend_elements = [
    Line2D([0], [0], color='orange', lw=2, label='Median'),
    Line2D([0], [0], marker='D', color='w', markerfacecolor='green', markeredgecolor='black', markersize=8, label='Mean'),
    Line2D([0], [0], color='black', linestyle='--', label='1:1 Ratio (Threshold)')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.grid(True, which="both", axis="y", linestyle="--", alpha=0.4)
plt.tight_layout()

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --- Percentage of Pluvial Events (Index <= 1) ---
# Based on P95 UPA: 41.80%
# Based on P99 UPA: 24.16%
# Based on Max UPA: 16.95%

# %%
# ... (שאר הקוד אותו דבר)

folium.GeoJson(
    gdf_vis,
    style_function=style_fn,
    tooltip=folium.GeoJsonTooltip(
        # שיניתי כאן מ-upa_max ל-upa_p95
        fields=["PFDI", "poly_area_km2", "upa_p95"], 
        aliases=["Index (Ratio):", "Poly Area:", "River Area (P95):"], # עדכון הכותרת
        localize=True
    )
).add_to(m)

m.add_child(cmap)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbd3885cc810a73c84ffe7bbef22baed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbd3885cc810a73c84ffe7bbef22baed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbd3885cc810a73c84ffe7bbef22baed = L.map(
#                 &quot;map_cbd3885cc810a73c84ffe7bbef22baed&quot;,
#                 {
#                     center: [31.34751928630914, 28.11921340296704],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c16d3e3fceb25d4f880e60edad46f706 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c16d3e3fceb25d4f880e60edad46f706.addTo(map_cbd3885cc810a73c84ffe7bbef22baed);
#
#
#         function geo_json_b43ea468650aafe093979552b720cbfe_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0000ffff&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc75eff&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc65eff&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#                 case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc75fff&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#                 case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#                 case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: ca

# %%
# ============================================
# 0) IMPORTS
# ============================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# ============================================
# 1) LOAD DATA
# ============================================
PKL_FULL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl"
print(f"Loading data from: {PKL_FULL_PATH}")

df = pd.read_pickle(PKL_FULL_PATH)

# ============================================
# 2) FILTER DATA
# ============================================
# Clean invalid values
df_clean = df.dropna(subset=["PFDI", "poly_area_km2"]).copy()
df_clean = df_clean[(df_clean["PFDI"] > 0) & (df_clean["poly_area_km2"] > 0)].copy()

# Limit to 500 km^2 as decided
df_clean = df_clean[df_clean["poly_area_km2"] <= 500].copy()

print(f"Data points for analysis: {len(df_clean)}")

# ============================================
# 3) CREATE BINS FOR BOXPLOT
# ============================================
# Define area ranges (bins) to inspect distribution per size group
bins = [0, 10, 50, 100, 250, 500]
labels = ['< 10', '10 - 50', '50 - 100', '100 - 250', '250 - 500']

df_clean['Area_Bin'] = pd.cut(
    df_clean['poly_area_km2'], 
    bins=bins, 
    labels=labels
)

# ============================================
# 4) PLOTTING
# ============================================
fig, axes = plt.subplots(2, 1, figsize=(12, 12))

# --- PLOT A: Hexbin Density Plot (Area vs PFDI) ---
# Use log scales for both axes
x = df_clean["poly_area_km2"]
y = df_clean["PFDI"]

# Hexbin plot handles dense data better than scatter
hb = axes[0].hexbin(
    x, y, 
    gridsize=50, 
    xscale='log', 
    yscale='log', 
    cmap='inferno_r', 
    mincnt=1
)

# Add colorbar
cb = fig.colorbar(hb, ax=axes[0])
cb.set_label('Count of Events')

# Add threshold line at PFDI = 1
axes[0].axhline(y=1, color='cyan', linestyle='--', linewidth=2, label='PFDI=1 (Pluvial/Fluvial Threshold)')

axes[0].set_title("Hexbin Density: Polygon Area vs. PFDI", fontsize=14)
axes[0].set_xlabel("Polygon Area [km²] (Log Scale)", fontsize=12)
axes[0].set_ylabel("PFDI (Ratio) [Log Scale]", fontsize=12)
axes[0].legend()
axes[0].grid(True, which="both", linestyle="--", alpha=0.3)


# --- PLOT B: Boxplots by Area Bin ---
# Shows the statistical distribution within each size group
sns.boxplot(
    data=df_clean, 
    x='Area_Bin', 
    y='PFDI', 
    ax=axes[1], 
    palette="coolwarm",
    showfliers=False  # Hide outliers to keep the box readable
)

# Add threshold line
axes[1].axhline(y=1, color='black', linestyle='--', linewidth=2, label='PFDI=1')

# Set Y axis to log scale to match the data range
axes[1].set_yscale("log")

axes[1].set_title("PFDI Distribution by Area Group", fontsize=14)
axes[1].set_xlabel("Area Range [km²]", fontsize=12)
axes[1].set_ylabel("PFDI (Log Scale)", fontsize=12)
axes[1].grid(True, axis='y', linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loading data from: D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl
# Data points for analysis: 42779

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# טעינת הנתונים (מניח שהם כבר טעונים ב-df_clean מהקוד הקודם)
# אם לא, תריץ את שורות הטעינה מהבלוק הקודם
# df_clean = ...

plt.figure(figsize=(10, 10))

# נתונים
x = df_clean["poly_area_km2"]
y = df_clean["upa_max"]  # משתמשים ב-Max כדי לתפוס את הנהר הכי גדול שנכנס

# שימוש ב-Hexbin כדי לראות צפיפות (כי יש המון נקודות)
hb = plt.hexbin(
    x, y,
    gridsize=50,
    xscale='log',
    yscale='log',
    cmap='Spectral_r', # אדום = אזורים "חמים" (הרבה אירועים), כחול = מעט
    mincnt=1,
    bins='log' # צביעה לוגריתמית כדי לראות גם אזורים דלילים
)

# הוספת קו ה-1:1
# כל מה שמעל הקו הזה -> הנחל המנקז גדול יותר מהעיר עצמה (Fluvial Dominance)
# כל מה שמתחת לקו הזה -> העיר גדולה יותר מהנחל שנכנס אליה (Pluvial Dominance)
limit_min = min(x.min(), y.min())
limit_max = max(x.max(), y.max())
plt.plot([limit_min, limit_max], [limit_min, limit_max], 'k--', linewidth=2, label="1:1 Line (Area = UPA)")

# הוספת קו עזר לנהרות משמעותיים (למשל, נהר שמנקז 1000 קמ"ר)
plt.axhline(y=1000, color='blue', linestyle=':', alpha=0.6, label="Major River Threshold (1,000 km²)")

# עיצוב
plt.xlabel("Local Area (Polygon Size) [km²]", fontsize=12)
plt.ylabel("Upstream Drainage Area (River Size) [km²]", fontsize=12)
plt.title("Fluvial vs. Pluvial Potential\n(Points above dashed line are River-Dominated)", fontsize=14)
plt.legend()
plt.grid(True, which="both", linestyle="--", alpha=0.3)

# הוספת Colorbar
cb = plt.colorbar(hb)
cb.set_label('Log10(Count of Events)')

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ============================================
# 0) IMPORTS
# ============================================
import pandas as pd
import geopandas as gpd
import folium
import branca.colormap as cm
from shapely import wkt
import numpy as np

# ============================================
# 1) CONFIGURATION & PATHS
# ============================================
PKL_FULL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl"

# ============================================
# 2) LOAD DATA
# ============================================
print(f"Loading data from: {PKL_FULL_PATH}")
df = pd.read_pickle(PKL_FULL_PATH)

# ============================================
# 3) PREPARE GEODATAFRAME
# ============================================
# Convert WKT to geometry objects if needed
if "geometry" not in df.columns and "geometry_wkt" in df.columns:
    df["geometry"] = df["geometry_wkt"].apply(wkt.loads)

gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

# Filter logic:
# 1. Valid PFDI and Area
# 2. Positive values only
# 3. Limit area to 500 km^2 (as defined in our analysis)
gdf = gdf.dropna(subset=["PFDI", "poly_area_km2", "upa_p95"]).copy()
gdf = gdf[(gdf["PFDI"] > 0) & (gdf["poly_area_km2"] > 0)].copy()
gdf = gdf[gdf["poly_area_km2"] <= 500].copy()

# Log transform for the color scale (Log10(1) = 0)
gdf["logPFDI"] = np.log10(gdf["PFDI"])

# ============================================
# 4) STRATIFIED SAMPLING
#    We sample Low/Mid/High PFDI from Small/Medium/Large polygons
#    to verify the metric across all scales.
# ============================================
def get_strata_sample(df_subset, n=10):
    """Returns a balanced sample of low, median, and high PFDI values."""
    if len(df_subset) < (n * 3): 
        return df_subset
    
    high = df_subset.nlargest(n, "PFDI")
    low = df_subset.nsmallest(n, "PFDI")
    
    # Select median values
    mid = df_subset.iloc[
        (df_subset["PFDI"] - df_subset["PFDI"].median())
        .abs()
        .argsort()[:n]
    ]
    return pd.concat([high, mid, low])

# Define size bins
subset_small = gdf[gdf["poly_area_km2"] < 10]
subset_med = gdf[(gdf["poly_area_km2"] >= 10) & (gdf["poly_area_km2"] < 100)]
subset_large = gdf[gdf["poly_area_km2"] >= 100]

# Collect samples
samples = []
samples.append(get_strata_sample(subset_small, n=10))
samples.append(get_strata_sample(subset_med, n=10))
samples.append(get_strata_sample(subset_large, n=10))

gdf_vis = pd.concat(samples, ignore_index=True)
gdf_vis = gdf_vis.drop_duplicates(subset="event_id")

print(f"Displaying {len(gdf_vis)} representative events on map...")

# ============================================
# 5) CREATE COLORMAP
#    Center logic: 
#    - log10(1) = 0 -> WHITE
#    - Values > 0 -> BLUE (Fluvial)
#    - Values < 0 -> RED (Pluvial)
# ============================================
vmin, vmax = -2, 2

cmap = cm.LinearColormap(
    colors=['red', 'orange', 'white', 'lightblue', 'blue'],
    index=[vmin, -0.5, 0, 0.5, vmax], # 0 is explicitly the center anchor
    vmin=vmin,
    vmax=vmax
)
cmap.caption = "Fluvial (Blue) vs Pluvial (Red) | Threshold: Index=1"

# ============================================
# 6) BUILD MAP
# ============================================
if len(gdf_vis) > 0:
    center_geom = gdf_vis.geometry.centroid.unary_union.centroid
    m = folium.Map(
        location=[center_geom.y, center_geom.x], 
        zoom_start=4, 
        tiles="OpenStreetMap"
    )

    def style_fn(feature):
        val = feature["properties"]["logPFDI"]
        # Clamp values to the colormap range to avoid errors
        val = max(min(val, vmax), vmin)
        return {
            "fillColor": cmap(val),
            "color": "black",       # Border color
            "weight": 1,            # Border thickness
            "fillOpacity": 0.5      # Transparency to see background map
        }

    # Add polygons with detailed tooltip for verification
    folium.GeoJson(
        gdf_vis,
        style_function=style_fn,
        tooltip=folium.GeoJsonTooltip(
            fields=["event_id", "PFDI", "poly_area_km2", "upa_p95"],
            aliases=["ID:", "Index (Ratio):", "Poly Area (km²):", "River Area P95 (km²):"],
            localize=True
        )
    ).add_to(m)

    m.add_child(cmap)
else:
    print("No data available to plot.")
    m = None

# ============================================
# 7) DISPLAY
# ============================================
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loading data from: D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\chronicle_urban_df_with_pfdi_FULL.pkl
# Displaying 90 representative events on map...
# C:\Users\raznu\AppData\Local\Temp\ipykernel_48612\1511145739.py:100: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_geom = gdf_vis.geometry.centroid.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1ac9f41b8b6308d1e0c41ccb786e0b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1ac9f41b8b6308d1e0c41ccb786e0b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1ac9f41b8b6308d1e0c41ccb786e0b1 = L.map(
#                 &quot;map_e1ac9f41b8b6308d1e0c41ccb786e0b1&quot;,
#                 {
#                     center: [31.34751928630914, 28.11921340296704],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0361181b75eacb3a1440b873d08df401 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0361181b75eacb3a1440b873d08df401.addTo(map_e1ac9f41b8b6308d1e0c41ccb786e0b1);
#
#
#         function geo_json_65e86f1ad53d8eabdb290010da27bf52_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0000ffff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc75eff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc65eff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffc75fff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff1b00ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;60&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff9700ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff7100ff&q

# %%
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#       Unnamed: 0                              uuid    area_km2 version  \
# 0              0  93e48341dbaa4be29a38b856d94206c5  191.436317    v3.1
# 1              1  939149831ea34c3e94712cc42c17c46a   14.208894    v3.1
# 2              2  931831f75479454cb3938811e64ce882   28.562733    v3.1
# 3              3  91bc68dde43646289c9e75b7d59e1711  108.562378    v3.1
# 4              4  8b849511de80423f98918f55af323e7e    0.104375    v3.1
# ...          ...                               ...         ...     ...
# 1995        1995  bc9db259939b4e7bbd733cddc75fd4ae    6.064658    v3.1
# 1996        1996  cc7de4222d284f44875f88ec1c9e4886   39.465225    v3.1
# 1997        1997  ce5d434568224af895ac108113de7ca0   14.710346    v3.1
# 1998        1998  d4a1d64ccdc34b68b91d97921689b305   15.122304    v3.1
# 1999        1999  89a06d9c9a014cd1a7654702542811ce    8.372793    v3.1
#
#        start_time     end_time  duration_days  \
# 0     946684800.0  946684800.0              1
# 1     946684800.0  946684800.0              1
# 2     946684800.0  946684800.0              1
# 3     946684800.0  946684800.0              1
# 4     946684800.0  946684800.0              1
# ...           ...          ...            ...
# 1995  988675200.0  988675200.0              1
# 1996  988675200.0  988675200.0              1
# 1997  988675200.0  988675200.0              1
# 1998  988675200.0  988675200.0              1
# 1999  988675200.0  988675200.0              1
#
#                                            geometry_wkt  \
# 0     POLYGON ((-7.6844751 33.499789, -7.5516781 33....
# 1     POLYGON ((-7.9863739 29.745153, -7.9965878 29....
# 2     POLYGON ((-98.97432499999999 19.337026, -98.93...
# 3     POLYGON ((30.936502 -29.872152, 30.928104 -29....
# 4     POLYGON ((16.547385 38.687964, 16.549982 38.68...
# ...                                                 ...
# 1995  POLYGON ((30.422276 50.489059, 30.451731 50.50...
# 1996  POLYGON ((37.71646 44.735583, 37.727298 44.768...
# 1997  POLYGON ((39.048374 44.12004, 39.087667 44.128...
# 1998  POLYGON ((37.34507 45.276124, 37.363655 45.297...
# 1999  POLYGON ((116.99595 52.50843, 117.00899 52.544...
#
#       urban_built_up_area_m2  polygon_total_area_m2  urban_percentage  \
# 0                  4608358.0           1.531473e+08          3.009102
# 1                   751304.0           9.880934e+06          7.603573
# 2                  3757833.0           1.180029e+07         31.845253
# 3                 26634641.0           1.273836e+08         20.908999
# 4                    49138.0           1.051849e+05         46.715826
# ...                      ...                    ...               ...
# 1995                986878.0           4.863141e+06         20.293018
# 1996               9056884.0           3.537692e+07         25.601112
# 1997               2577571.0           1.484113e+07         17.367751
# 1998               4094533.0           2.473481e+07         16.553727
# 1999               1457627.0           8.729297e+06         16.698102
#
#       event_id  poly_area_km2      upa_max    upa_p95      upa_p99      PFDI
# 0            0     152.737360  2144.798828   0.231797   506.047577  0.001518
# 1            1       9.846162  1930.907593  24.820149  1929.830884  2.520794
# 2            2      11.730829  8171.314453   0.613581     0.613581  0.052305
# 3            3     126.937144  4441.062012   0.377705   243.834593  0.002976
# 4            4       0.105030     0.107175   0.073682     0.073682  0.701532
# ...        ...            ...          ...        ...          ...       ...
# 1995      1995       4.869447    12.263927   0.671918    11.538102  0.137987
# 1996      1996      35.369374    84.639458   1.729812    37.736286  0.048907
# 1997      1997      14.839106   352.425598   0.082846   345.308260  0.005583
# 1998      1998      24.727607  3562.722168   0.075580  3561.036632  0.003056
# 1999      1999       8.745480  1314.568481   0.134530  1307.202701  0.015383
#
# [2000 rows x 17 columns]

# %%
# ============================================
# 0) IMPORTS
# ============================================
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

import folium
import branca.colormap as cm
from shapely import wkt


# ============================================
# 1) PATHS
# ============================================
CSV_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\pfdi_merit_outputs\pfdi_stats_batch_0000.csv"
PKL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl"


# ============================================
# 2) LOAD + MERGE
#    - CSV: has upa_p95 / upa_p99 / upa_max (and PFDI)
#    - PKL: has geometry_wkt, urban_percentage, etc.
# ============================================
df_stats = pd.read_csv(CSV_PATH)

df_orig = pd.read_pickle(PKL_PATH)
df_orig["event_id"] = df_orig.index.astype(int)

df = df_orig.merge(df_stats, on="event_id", how="inner").copy()

# Basic cleanup
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(subset=["poly_area_km2", "upa_p95", "upa_p99"]).copy()

# Guard against zeros for ratios/logs
df = df[(df["poly_area_km2"] > 0) & (df["upa_p95"] > 0) & (df["upa_p99"] > 0)].copy()

print("Rows after merge/clean:", len(df))
print("Columns available:", [c for c in ["upa_p95", "upa_p99", "upa_max", "PFDI", "poly_area_km2", "urban_percentage"] if c in df.columns])


# ============================================
# 3) DEFINE NEW NORMALIZED INDEX (NO AREA)
#    Dominance_99_95: tail sharpness / dominance proxy
# ============================================
df["Dominance_99_95"] = df["upa_p99"] / df["upa_p95"]

# Optional log for visualization
df["logDominance_99_95"] = np.log10(df["Dominance_99_95"])

print(df[["Dominance_99_95", "poly_area_km2"]].describe())


# ============================================
# 4) SCATTER: Dominance_99_95 vs Area (log-log)
# ============================================
plt.figure(figsize=(10, 7))
plt.scatter(df["poly_area_km2"].values, df["Dominance_99_95"].values, alpha=0.25, s=12)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Flood polygon area (km²)")
plt.ylabel("Dominance_99_95 = UPA_p99 / UPA_p95")
plt.title("Dominance_99_95 vs Flood Polygon Area (log–log)")
plt.grid(True, which="both", alpha=0.3)
plt.show()

# Optional: Dominance vs Urban %
if "urban_percentage" in df.columns:
    df_u = df.dropna(subset=["urban_percentage"]).copy()
    plt.figure(figsize=(10, 7))
    plt.scatter(df_u["urban_percentage"].values, df_u["Dominance_99_95"].values, alpha=0.25, s=12)
    plt.yscale("log")
    plt.xlabel("Urban percentage (%)")
    plt.ylabel("Dominance_99_95 = UPA_p99 / UPA_p95")
    plt.title("Dominance_99_95 vs Urban Percentage")
    plt.grid(True, which="both", alpha=0.3)
    plt.show()


# ============================================
# 5) MAP: diagnostic subset (low / mid / high)
#    - single interactive map, ~60 polygons total
# ============================================
gdf = gpd.GeoDataFrame(
    df,
    geometry=df["geometry_wkt"].apply(wkt.loads),
    crs="EPSG:4326"
)

gdf = gdf.dropna(subset=["Dominance_99_95"]).copy()

N_PER_GROUP = 20

low = gdf.nsmallest(N_PER_GROUP, "Dominance_99_95")
high = gdf.nlargest(N_PER_GROUP, "Dominance_99_95")

mid = gdf.iloc[
    (gdf["Dominance_99_95"] - gdf["Dominance_99_95"].median())
    .abs()
    .argsort()[:N_PER_GROUP]
]

gdf_vis = pd.concat([low, mid, high], ignore_index=True).copy()
gdf_vis["logDominance_99_95"] = np.log10(gdf_vis["Dominance_99_95"])

print("Map subset size:", len(gdf_vis))

# Build map (centered on the subset)
center_geom = gdf_vis.geometry.centroid.unary_union.centroid
m = folium.Map(
    location=[center_geom.y, center_geom.x],
    zoom_start=11,
    tiles="OpenStreetMap"
)

# Color scale on log10 values (more stable visually)
cmap = cm.linear.RdYlBu_11.scale(
    gdf_vis["logDominance_99_95"].min(),
    gdf_vis["logDominance_99_95"].max()
)

def style_fn(feature):
    val = feature["properties"]["logDominance_99_95"]
    return {
        "fillColor": cmap(val),
        "color": "black",
        "weight": 1,
        "fillOpacity": 0.6
    }

tooltip_fields = ["Dominance_99_95", "poly_area_km2"]
tooltip_aliases = ["Dominance_99_95 (p99/p95)", "Area (km²)"]

# Add urban % if present
if "urban_percentage" in gdf_vis.columns:
    tooltip_fields.append("urban_percentage")
    tooltip_aliases.append("Urban (%)")

folium.GeoJson(
    gdf_vis,
    style_function=style_fn,
    tooltip=folium.GeoJsonTooltip(
        fields=tooltip_fields,
        aliases=tooltip_aliases,
        localize=True
    )
).add_to(m)

cmap.caption = "log10(Dominance_99_95)  —  lower = more diffuse, higher = more channel-dominant"
cmap.add_to(m)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Rows after merge/clean: 2000
# Columns available: ['upa_p95', 'upa_p99', 'upa_max', 'PFDI', 'poly_area_km2', 'urban_percentage']
#        Dominance_99_95  poly_area_km2
# count     2.000000e+03    2000.000000
# mean      5.995916e+03     145.883876
# std       7.775282e+04     541.371351
# min       1.000000e+00       0.014797
# 25%       1.253789e+00       1.195031
# 50%       9.704718e+00       6.939893
# 75%       2.783736e+02      33.559510
# max       3.345939e+06    4795.628839
# Map subset size: 60
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c3f51ace613fb008140112768419a45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c3f51ace613fb008140112768419a45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c3f51ace613fb008140112768419a45 = L.map(
#                 &quot;map_6c3f51ace613fb008140112768419a45&quot;,
#                 {
#                     center: [36.15019751277781, 7.633287517793504],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d14a56e91218550bfd61edef46bc534 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d14a56e91218550bfd61edef46bc534.addTo(map_6c3f51ace613fb008140112768419a45);
#
#
#         function geo_json_6a6f4661a2b9fda33d16af72ac5a99ca_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50026ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e64f35ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e65035ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;27&quot;: case &quot;30&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e64e35ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;28&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e75036ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e75136ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e54d34ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#313695ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;41&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5a8ec1ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5b90c2ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;43&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6298c6ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 1};
#                 case &quot;45&quot;: case &quot;46&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;

# %%
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=YG-Vkqwax7eFOQgXKF6EsidQtuBOjg4eR3T9pu9-OZU&tc=docloOrbqlsXAafon22vDQas7hSaZJVMNnUz0o-9mUU&cc=_ista_yz9xquTU4BLlOgbxL4mAqqC9iSiRr-fWOQ7C0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=YG-Vkqwax7eFOQgXKF6EsidQtuBOjg4eR3T9pu9-OZU&tc=docloOrbqlsXAafon22vDQas7hSaZJVMNnUz0o-9mUU&cc=_ista_yz9xquTU4BLlOgbxL4mAqqC9iSiRr-fWOQ7C0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1ATX87lPBfGwuUE9Ma9Rmdm_UAQqhLe-fsA-vQvhHYHs3Uh80IvVJM-y7hj0
#
# Successfully saved authorization token.

# %%
# ============================================
# 0) IMPORTS
# ============================================
import pandas as pd
import geopandas as gpd
from shapely import wkt

import ee
import geemap


# ============================================
# 1) CONFIGURATION
# ============================================
PKL_PATH = r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl"

# Column name in your PKL containing WKT geometry.
GEOM_WKT_COL = "geometry_wkt"

# A small sample size for testing the end-to-end pipeline before scaling up
SAMPLE_SIZE = 200

# MERIT Hydro dataset ID and band
MERIT_IMAGE_ID = "MERIT/Hydro/v1_0_1"
UPA_BAND = "upa"  # upstream drainage area (km^2)


# ============================================
# 2) LOAD & PREPARE YOUR CHRONICLE DATA
# ============================================
df = pd.read_pickle(PKL_PATH)

# Ensure geometry column exists
if GEOM_WKT_COL not in df.columns:
    raise ValueError(
        f"Column '{GEOM_WKT_COL}' not found. Available columns: {list(df.columns)}"
    )

# Build GeoDataFrame
gdf = gpd.GeoDataFrame(
    df.copy(),
    geometry=df[GEOM_WKT_COL].apply(wkt.loads),
    crs="EPSG:4326"
)

# Create a stable event_id (use index)
gdf["event_id"] = gdf.index.astype(int)

# Basic geometry cleanup
# buffer(0) can fix minor self-intersections; it may fail for some geometries, so we do it safely.
def _fix_geom(geom):
    try:
        if geom is None:
            return None
        return geom.buffer(0)
    except Exception:
        return geom

gdf["geometry"] = gdf["geometry"].apply(_fix_geom)
gdf = gdf[gdf.geometry.notnull()].copy()

print("Chronicle GeoDataFrame loaded.")
print("Rows:", len(gdf))
print("CRS:", gdf.crs)
print(gdf[["event_id"]].head())


# ============================================
# 3) AUTHENTICATE & INITIALIZE EARTH ENGINE
# ============================================
try:
    ee.Initialize()
    print("Earth Engine initialized.")
except Exception:
    print("Earth Engine not initialized. Running authentication...")
    ee.Authenticate()
    ee.Initialize()
    print("Earth Engine authenticated and initialized.")


# ============================================
# 4) LOAD MERIT HYDRO (UPA) AND DISPLAY ON A MAP (ONCE)
# ============================================
merit = ee.Image(MERIT_IMAGE_ID)
upa = merit.select(UPA_BAND)

# Create a map for quick intuition
m = geemap.Map(center=(20, 0), zoom=2)

# Visualization parameters
# UPA can span many orders of magnitude; log helps visualization.
upa_log = upa.log10()

vis_params = {
    "min": 0,
    "max": 5,  # log10 scale: 10^0 to 10^5 km^2
}

m.addLayer(upa_log, vis_params, "MERIT Hydro - log10(UPA)")
m.addLayerControl()
m


# ============================================
# 5) RUN A SMALL TEST BATCH (RECOMMENDED)
# ============================================
gdf_sample = gdf.sample(SAMPLE_SIZE, random_state=42).copy()

# Keep only the minimal columns needed for upload to EE
gdf_sample_min = gdf_sample[["event_id", "geometry"]].copy()

print(f"Using a sample of {len(gdf_sample_min)} polygons for a test run.")


# ============================================
# 6) CONVERT SAMPLE POLYGONS TO EE FEATURECOLLECTION
# ============================================
fc = geemap.geopandas_to_ee(gdf_sample_min)

# Quick sanity check
print("EE FeatureCollection size:", fc.size().getInfo())


# ============================================
# 7) COMPUTE ZONAL STATS (MAX, P95, P99) OF UPA WITHIN EACH POLYGON
# ============================================
reducer = ee.Reducer.max().combine(
    ee.Reducer.percentile([95, 99]),
    sharedInputs=True
)

# MERIT Hydro is ~3 arc-sec (~90m). Use 90m scale.
stats_fc = upa.reduceRegions(
    collection=fc,
    reducer=reducer,
    scale=90
)

# Convert results back to a pandas DataFrame
# Some geemap versions do not have ee_to_pandas; use ee_to_df instead.
if hasattr(geemap, "ee_to_df"):
    df_stats = geemap.ee_to_df(stats_fc)
elif hasattr(geemap, "ee_to_pandas"):
    df_stats = geemap.ee_to_pandas(stats_fc)
else:
    # Fallback: use Earth Engine API (slower, but robust)
    features = stats_fc.getInfo().get("features", [])
    df_stats = pd.DataFrame([f.get("properties", {}) for f in features])

print("Returned stats columns:", list(df_stats.columns))
display(df_stats.head())


# ============================================
# 8) ADD POLYGON AREA AND DERIVED RATIO
# ============================================
gdf_area = gdf_sample_min.to_crs("EPSG:6933").copy()
gdf_area["poly_area_km2"] = gdf_area.geometry.area / 1_000_000.0
df_area = gdf_area[["event_id", "poly_area_km2"]].copy()

# Merge stats + area
out = df_stats.merge(df_area, on="event_id", how="left")

# MERIT UPA stats fields are expected like "upa_max", "upa_p95", "upa_p99".
# If naming differs, inspect df_stats.columns and adjust here.
if "upa_max" in out.columns:
    out["upa_max_to_area_ratio"] = out["upa_max"] / out["poly_area_km2"]
else:
    print("Warning: 'upa_max' not found in output columns. Check column names above.")

display(out.head())


# ============================================
# 9) MERGE BACK INTO YOUR ORIGINAL DATAFRAME (FOR THE SAMPLE)
# ============================================
df_sample_enriched = gdf_sample.drop(columns=["geometry"]).merge(out, on="event_id", how="left")

print("Enriched sample:")
display(df_sample_enriched.head())


# ============================================
# 10) NEXT STEP (SCALING UP)
# ============================================
print(
    "\nNext step:\n"
    "- If the sample run works, do NOT convert the full 882,972 polygons via geemap in one shot.\n"
    "- Either upload polygons to GEE as an Asset OR process in batches (e.g., 2,000-10,000 at a time).\n"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Chronicle GeoDataFrame loaded.
# Rows: 882972
# CRS: EPSG:4326
#    event_id
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# Earth Engine initialized.
# Using a sample of 200 polygons for a test run.
# EE FeatureCollection size: 200
# Returned stats columns: ['event_id', 'max', 'p95', 'p99']
#    event_id           max        p95        p99
# 0    817395      0.775346   0.350160   0.733661
# 1    214476     51.656307  36.687677  39.553326
# 2    145026      5.370650   0.511030   2.123826
# 3    517053  45543.605469   0.505570   0.505570
# 4    605645    241.660202   1.402649  31.462908
# Warning: 'upa_max' not found in output columns. Check column names above.
#    event_id           max        p95        p99  poly_area_km2
# 0    817395      0.775346   0.350160   0.733661       0.722302
# 1    214476     51.656307  36.687677  39.553326       8.273045
# 2    145026      5.370650   0.511030   2.123826      14.435320
# 3    517053  45543.605469   0.505570   0.505570     204.951064
# 4    605645    241.660202   1.402649  31.462908     461.085999
# Enriched sample:
#    Unnamed: 0                              uuid    area_km2 version  \
# 0      817395  c9a3bf5d24ed402aa23b106d807dab5f    0.826844    v3.1
# 1      214476  06b210e7be344d4c8ded499e7a24ca5f    9.094827    v3.1
# 2      145026  f13346a19f0148758b7f6e90fa12fe52   10.018100    v3.1
# 3      517053  6296e56a9a7e4a55b34aaf02e3441906  200.028078    v3.1
# 4      605645  9cc2f50ec6cb407fba765137e661d89d  425.966194    v3.1
#
#      start_time      end_time  duration_days  \
# 0  1.747526e+09  1.747786e+09              4
# 1  1.501373e+09  1.501459e+09              2
# 2  1.444954e+09  1.445386e+09              6
# 3  1.655251e+09  1.655251e+09              1
# 4  1.687738e+09  1.687738e+09              1
#
#                                         geometry_wkt  urban_built_up_area_m2  \
# 0  POLYGON ((77.617199 12.880569, 77.619275 12.88...                309237.0
# 1  POLYGON ((-84.21356900000001 10.00181, -84.226...               2269496.0
# 2  POLYGON ((-94.697504 18.002704, -94.670743 18....               1482286.0
# 3  MULTIPOLYGON (((38.865091 45.037124, 38.985043...              46790769.0
# 4  MULTIPOLYGON (((-85.27982 9.921947100000001, -...                983860.0
#
#    polygon_total_area_m2  urban_percentage  event_id           max        p95  \
# 0           7.266732e+05         42.555168    817395      0.775346   0.350160
# 1           8.325536e+06         27.259459    214476     51.656307  36.687677
# 2           1.451547e+07         10.211769    145026      5.370650   0.511030
# 3           2.049897e+08         22.825908    517053  45543.605469   0.505570
# 4           4.639786e+08          0.212049    605645    241.660202   1.402649
#
#          p99  poly_area_km2
# 0   0.733661       0.722302
# 1  39.553326       8.273045
# 2   2.123826      14.435320
# 3   0.505570     204.951064
# 4  31.462908     461.085999
# Next step:
# - If the sample run works, do NOT convert the full 882,972 polygons via geemap in one shot.
# - Either upload polygons to GEE as an Asset OR process in batches (e.g., 2,000-10,000 at a time).

# %% [markdown]
# # Imports & Configuration

# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt, geometry
from shapely.geometry import box
import rasterio
from rasterstats import zonal_stats
import numpy as np
import folium
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import math
# --- CONFIGURATION ---

# File Paths
chronicle_ds_csv_path = r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_preliminary_huji.csv"
ghs_urban_raster_path = r"D:\Development\RESEARCH\Raanana\data\esa_worldcover\GHS_BUILT_S_E2020_GLOBE_R2023A_54009_100_V1_0.tif"

# Processing Settings
# Set to an integer (e.g., 10000) for testing, or None for full dataset
SAMPLE_SIZE = None

# %% [markdown]
# # Data Loading & Processing

# %%
if SAMPLE_SIZE:
    chronicle_raw_df = pd.read_csv(chronicle_ds_csv_path, nrows=SAMPLE_SIZE)
else:
    chronicle_raw_df = pd.read_csv(chronicle_ds_csv_path)

# 2. Parse Geometries
print("Parsing WKT geometries...")
chronicle_raw_df['geometry'] = chronicle_raw_df['geometry_wkt'].apply(wkt.loads)

# 3. Create GeoDataFrame
chronicle_gdf = gpd.GeoDataFrame(chronicle_raw_df, geometry='geometry')
chronicle_gdf.set_crs(epsg=4326, inplace=True)

# 4. Reproject
with rasterio.open(ghs_urban_raster_path) as src:
    ghs_raster_crs = src.crs
    ghs_nodata_value = src.nodata
    print(f"Raster CRS: {ghs_raster_crs}")
    
    print("Reprojecting polygons...")
    chronicle_projected_gdf = chronicle_gdf.to_crs(ghs_raster_crs)

# 5. Calculate Zonal Statistics (WITH PROGRESS TRACKING)
print("Calculating zonal stats in chunks...")

# -- PROGRESS LOGIC START --
total_rows = len(chronicle_projected_gdf)
# We want 10 updates, so we divide total rows by 10
chunk_size = math.ceil(total_rows / 10) 
all_stats = []

# Iterate through the DataFrame in chunks
for i in range(0, total_rows, chunk_size):
    # Slice the dataframe
    subset = chronicle_projected_gdf.iloc[i : i + chunk_size]
    
    # Run stats just for this chunk
    chunk_stats = zonal_stats(
        subset,
        ghs_urban_raster_path,
        stats=['sum'],
        nodata=ghs_nodata_value
    )
    
    # Accumulate results
    all_stats.extend(chunk_stats)
    
    # Calculate and print progress
    current_row = min(i + chunk_size, total_rows)
    percent_complete = int((current_row / total_rows) * 100)
    print(f"{percent_complete}% complete... ({current_row}/{total_rows})")

# Convert accumulated list to DataFrame
urban_stats_df = pd.DataFrame(all_stats)
# -- PROGRESS LOGIC END --

# 6. Calculate Urban Percentage
print("Calculating percentages...")
chronicle_projected_gdf['urban_built_up_area_m2'] = urban_stats_df['sum'].fillna(0)
chronicle_projected_gdf['polygon_total_area_m2'] = chronicle_projected_gdf.area

chronicle_projected_gdf['urban_percentage'] = np.where(
    chronicle_projected_gdf['polygon_total_area_m2'] > 0,
    (chronicle_projected_gdf['urban_built_up_area_m2'] / chronicle_projected_gdf['polygon_total_area_m2']) * 100,
    0
)

# 7. Final Clean DataFrame
chronicle_urban_df = pd.DataFrame(chronicle_projected_gdf.drop(columns='geometry'))

print(f"--- Done! Processed {len(chronicle_urban_df)} records. ---")

# %% [markdown]
# ## Save as a pickle

# %%
# Save the DataFrame to a pickle file at the specified path
# chronicle_urban_df.to_pickle(r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl")

# %%
# Load the DataFrame from the specified path
chronicle_urban_df = pd.read_pickle(r"D:\Development\RESEARCH\urban_flood_database\chronicle\chronicle_urban_df.pkl")

# %%
# 1. Filter rows with percentage > 100
anomalies = thresh_chronicle_urban_df[thresh_chronicle_urban_df['urban_percentage'] > 100]
count = len(anomalies)


print(f"Total events checked: {len(thresh_chronicle_urban_df)}")
print(f"Events with > 100% urban area: {count}")

if count > 0:
    max_val = anomalies['urban_percentage'].max()
    print(f"Highest value found: {max_val:.2f}%")
    
    print("\nTop 5 Anomalies (Preview):")
    # Show UUID, Percentage, and Total Area (often happens in very small polygons)
    print(anomalies[['uuid', 'urban_percentage', 'polygon_total_area_m2']].head())
else:
    print("Status: OK. No values above 100% found.")
# Out:
# --- Data Integrity Check ---
# Total events checked: 214204
# Events with > 100% urban area: 0
# Status: OK. No values above 100% found.

# %%
# 1. Create a copy and convert area to km² for better readability
# (1 km² = 1,000,000 m²)
df_plot = thresh_chronicle_urban_df.copy()
df_plot['area_km2'] = df_plot['polygon_total_area_m2'] / 1_000_000

# 2. Setup the figure
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 7))

# 3. Create Scatter Plot
sns.scatterplot(
    data=df_plot,
    x='area_km2',
    y='urban_percentage',
    alpha=0.4,       # Transparency helps visualize overlapping points
    edgecolor=None,  # Removes borders from dots for a cleaner look
    s=15,            # Dot size
    color='royalblue'
)

# 4. Set Log Scale for X-axis (Crucial for Area distribution)
plt.xscale('log')

# 5. Set limits and styling
plt.ylim(0, 120)
plt.xlim(left=df_plot['area_km2'].min()) # Start from the smallest polygon

plt.title('Urban Percentage vs. Total Area', fontsize=16, fontweight='bold')
plt.xlabel('Total Area ($km^2$) [Log Scale]', fontsize=12)
plt.ylabel('Urban Percentage (%)', fontsize=12)

# 6. Add a visual helper line (e.g., median urban percentage)
median_val = df_plot['urban_percentage'].median()
plt.axhline(median_val, color='red', linestyle='--', alpha=0.5, label=f'Median Urban % ({median_val:.1f}%)')
plt.legend()

sns.despine()
plt.show()
