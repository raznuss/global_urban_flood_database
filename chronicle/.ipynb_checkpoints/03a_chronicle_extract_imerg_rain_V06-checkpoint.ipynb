# %%
# # ============================================
# # 0) IMPORTS
# # ============================================
# import os
# import glob
# import pandas as pd
# import numpy as np
# import shapely.wkt
# import shapely.geometry
# import geopandas as gpd
# from affine import Affine
# import rasterio.features
# from tqdm import tqdm  # Progress bar
# import gc  # Garbage Collector for memory management

# import ee

# # ============================================
# # 1) CONFIGURATION
# # ============================================

# # --- INPUT: The consolidated PKL from step 02a ---
# INPUT_PKL = r"D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\chronicle_df_with_pfdi_FULL.pkl"

# # --- OUTPUT: Where rain data will be saved ---
# OUT_DIR = r"D:\Development\RESEARCH\urban_flood_database\chronicle\imerg_rain_outputs"
# OUT_FINAL_PKL = os.path.join(OUT_DIR, "chronicle_urban_df_with_IMERG_FULL.pkl")

# # IMERG Constants
# # Data available from June 2000
# IMERG_START_DATE = pd.Timestamp("2000-06-01") 
# SCALE = 0.1  # 0.1 Degree resolution
# CRS = 'EPSG:4326'

# # Batch Settings
# # Keeping it safe at 100 to avoid memory overflow with 3D arrays
# BATCH_SIZE = 1000 
# N_BATCHES_TO_RUN = 350  # Limit execution to 30 batches (3000 events)

# # ============================================
# # 2) HELPERS
# # ============================================

# def ensure_out_dir(path):
#     """Create output directory if it doesn't exist."""
#     if not os.path.exists(path):
#         os.makedirs(path, exist_ok=True)

# def initialize_ee():
#     """Initialize Earth Engine."""
#     try:
#         ee.Initialize()
#         print("Earth Engine initialized.")
#     except Exception:
#         print("Authenticating Earth Engine...")
#         ee.Authenticate()
#         ee.Initialize()
#         print("Earth Engine initialized after auth.")

# def get_next_batch_index(out_dir):
#     """
#     Scans output directory for 'imerg_batch_XXXX.pkl' to determine 
#     the next batch number for file naming.
#     """
#     if not os.path.exists(out_dir):
#         return 0
    
#     pattern = os.path.join(out_dir, "imerg_batch_*.pkl")
#     files = glob.glob(pattern)
    
#     if not files:
#         return 0
    
#     max_batch = -1
#     for f in files:
#         try:
#             filename = os.path.basename(f)
#             # filename format: imerg_batch_0001.pkl
#             num_part = filename.split('_')[-1].split('.')[0]
#             batch_num = int(num_part)
#             if batch_num > max_batch:
#                 max_batch = batch_num
#         except ValueError:
#             continue
            
#     return max_batch + 1

# def extract_rain_data(event_row):
#     """
#     Extracts IMERG rain matrix, metadata, and mask for a single event.
    
#     Time Window Logic:
#     - Start: 72 hours BEFORE event start.
#     - End: 24 hours AFTER event end.
    
#     Returns: (rain_matrix, rain_mask, rain_meta)
#     """
#     # 1. Geometry Setup
#     try:
#         # Load geometry from WKT
#         if isinstance(event_row['geometry_wkt'], str):
#             poly_geom = shapely.wkt.loads(event_row['geometry_wkt'])
#         else:
#             # Fallback if it's already a geometry object
#             poly_geom = event_row['geometry_wkt']
            
#         bounds = poly_geom.bounds # (minx, miny, maxx, maxy)
#         roi = ee.Geometry.BBox(*bounds)
        
#         # 2. Time Window Calculation
#         # UPDATED: Taking 72 hours prior to the start time
#         start_t = event_row['start_time'] - pd.Timedelta(hours=72)
#         # We keep a buffer after the end time as well (e.g., 24 hours)
#         end_t = event_row['end_time'] + pd.Timedelta(hours=24) 
        
#         # 3. GEE Request
#         imerg_coll = ee.ImageCollection("NASA/GPM_L3/IMERG_V06") \
#             .select('precipitationCal') \
#             .filterBounds(roi) \
#             .filterDate(start_t, end_t)
        
#         # Check if collection is empty
#         if imerg_coll.size().getInfo() == 0:
#             return None, None, None

#         # 4. Download Data (sampleRectangle)
#         # Convert collection to a multi-band image (each band is a time step)
#         stack = imerg_coll.toBands()
        
#         # sampleRectangle downloads the raw pixels within the BBox
#         pixel_dict = stack.sampleRectangle(region=roi).getInfo()
#         properties = pixel_dict['properties']
        
#         # 5. Parse & Stack Arrays
#         # Keys are like '20000604120000_precipitationCal'
#         band_keys = sorted(list(properties.keys()))
        
#         arrays_list = []
#         for b in band_keys:
#             # Convert list to numpy array (float32 to save memory)
#             arr = np.array(properties[b], dtype=np.float32)
#             arrays_list.append(arr)
            
#         # Stack into 3D Array: (Time, Height, Width)
#         rain_matrix = np.stack(arrays_list)
        
#         # 6. Create Metadata (Anchor)
#         height, width = rain_matrix.shape[1], rain_matrix.shape[2]
#         min_lon, min_lat, max_lon, max_lat = bounds
        
#         # Transform for Rasterio (Lat/Lon)
#         # Note: We align to the BBox top-left
#         transform = Affine(SCALE, 0, min_lon, 0, -SCALE, max_lat)
        
#         meta = {
#             'origin_top_left': (max_lat, min_lon), # (Lat, Lon)
#             'scale': SCALE,
#             'shape': (height, width),
#             'timestamps': band_keys # Store timestamp keys to map matrix layers to time
#         }

#         # 7. Create Binary Mask (Polygon shape on grid)
#         # 1 = Inside Polygon, 0 = Outside
#         mask = rasterio.features.rasterize(
#             [(poly_geom, 1)],
#             out_shape=(height, width),
#             transform=transform,
#             fill=0,
#             all_touched=True,
#             dtype=np.uint8
#         )
        
#         return rain_matrix, mask, meta

#     except Exception as e:
#         # If extraction fails (e.g., GEE timeout), return None
#         return None, None, None

# %%
# # ============================================
# # 3) INITIALIZATION
# # ============================================
# initialize_ee()
# ensure_out_dir(OUT_DIR)

# # Load Input Data (The consolidated file from 02a)
# print(f"Loading full dataset: {INPUT_PKL}")
# if not os.path.exists(INPUT_PKL):
#     raise FileNotFoundError(f"Input file not found: {INPUT_PKL}. Please run 02a first.")

# df = pd.read_pickle(INPUT_PKL)

# # Basic cleaning
# df = df.replace([np.inf, -np.inf], np.nan)
# df['start_time'] = pd.to_datetime(df['start_time'], unit='s')
# df['end_time'] = pd.to_datetime(df['end_time'], unit='s')

# # Filter for IMERG Era (Post June 2000)
# # Events before this date will not have IMERG data
# df_valid = df[df['start_time'] >= IMERG_START_DATE].copy()

# print(f"Total events in input: {len(df)}")
# print(f"Events valid for IMERG (post-2000): {len(df_valid)}")

# # ============================================
# # 4) SMART BATCH PROCESSING (ID-BASED)
# # ============================================

# print(f"--- PREPARING WORK PLAN ---")

# # 1. Identify what is already done
# # We scan the output directory for existing RAIN batches to avoid re-processing
# processed_ids = set()
# pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
# existing_files = glob.glob(pkl_pattern)

# if existing_files:
#     print(f"Found {len(existing_files)} existing batch files. Scanning for processed IDs...")
#     for f in tqdm(existing_files, desc="Indexing existing data"):
#         try:
#             # Only read columns needed for ID check to save memory
#             df_temp = pd.read_pickle(f)
#             if 'event_id' in df_temp.columns:
#                 processed_ids.update(df_temp['event_id'].tolist())
#             del df_temp
#         except Exception as e:
#             print(f"Skipping corrupted file {f}: {e}")

# print(f"Total events already processed: {len(processed_ids)}")

# # 2. Filter the Main DataFrame
# # We keep only rows whose ID is NOT in the processed set
# df_todo = df_valid[~df_valid['event_id'].isin(processed_ids)].copy()

# print(f"Events remaining to process: {len(df_todo)}")

# if len(df_todo) == 0:
#     print("All events are already processed! Nothing to do.")
# else:
#     # 3. Process the remaining rows in new batches
#     start_batch_num = get_next_batch_index(OUT_DIR)
#     n_remaining = len(df_todo)
    
#     # Calculate stop limit based on N_BATCHES_TO_RUN
#     max_rows_limit = N_BATCHES_TO_RUN * BATCH_SIZE
#     stop_at_row = min(n_remaining, max_rows_limit)

#     print(f"Plan: Processing {min(N_BATCHES_TO_RUN, n_remaining // BATCH_SIZE + 1)} batches.")
    
#     # Iterate in chunks up to stop_at_row
#     for batch_i in range(0, stop_at_row, BATCH_SIZE):
        
#         # Determine actual batch number for filename
#         current_file_num = start_batch_num + (batch_i // BATCH_SIZE)
        
#         # Slice the TODO dataframe
#         batch_df = df_todo.iloc[batch_i : batch_i + BATCH_SIZE].copy()
        
#         print(f"\nProcessing Batch {current_file_num} ({len(batch_df)} events)...")
        
#         matrices = []
#         masks = []
#         metas = []
        
#         # Inner loop: iterate rows in current batch
#         for idx, row in tqdm(batch_df.iterrows(), total=len(batch_df), desc=f"Batch {current_file_num}"):
#             mat, msk, mt = extract_rain_data(row)
#             matrices.append(mat)
#             masks.append(msk)
#             metas.append(mt)
        
#         # Assign results to columns
#         batch_df['imerg_matrix'] = matrices
#         batch_df['imerg_mask'] = masks
#         batch_df['imerg_meta'] = metas
        
#         # Save batch to disk (Pickle)
#         out_path = os.path.join(OUT_DIR, f"imerg_batch_{current_file_num:04d}.pkl")
#         batch_df.to_pickle(out_path)
#         print(f"Saved: {out_path}")
        
#         # === MEMORY CLEANUP ===
#         # Explicitly delete large objects to free RAM for next iteration
#         del batch_df
#         del matrices
#         del masks
#         del metas
#         gc.collect() # Force garbage collection
#         # ======================

#     print("\n--- BATCH LIMIT REACHED ---")
#     print(f"Stopped execution after {N_BATCHES_TO_RUN} batches as requested.")

# %%
# # ============================================
# # 5) FINAL MERGE & CLEANUP
# # ============================================
# print("\n--- FINALIZING ---")
# print("Merging all batch files...")

# pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
# all_pkl_files = glob.glob(pkl_pattern)

# if not all_pkl_files:
#     print("No output files found.")
# else:
#     # Concatenate all batches
#     df_list = []
#     for f in tqdm(all_pkl_files, desc="Loading Batches"):
#         try:
#             df_list.append(pd.read_pickle(f))
#         except Exception as e:
#             print(f"Error loading {f}: {e}")
            
#     if df_list:
#         # This DataFrame contains ONLY the processed events with rain data
#         df_results = pd.concat(df_list, ignore_index=True)
        
#         print(f"Loaded {len(df_results)} processed rain events (raw count).")
#         print("Merging results back to main dataset structure...")
        
#         # Reload the original input again to ensure we have the clean base columns
#         df_base = pd.read_pickle(INPUT_PKL)
        
#         # Merge: 'inner' keeps only keys that appear in BOTH DataFrames
#         df_final = df_base.merge(
#             df_results[['event_id', 'imerg_matrix', 'imerg_mask', 'imerg_meta']], 
#             on='event_id', 
#             how='inner' 
#         )
        
#         # --- NEW: FILTER OUT NULL RAIN DATA ---
        
#         # 1. Ensure start_time is datetime format for readable printing
#         if 'start_time' in df_final.columns:
#             df_final['start_time'] = pd.to_datetime(df_final['start_time'], unit='s')

#         # 2. Identify rows where 'imerg_matrix' is Null/None (Values of 0 are NOT null, so they stay)
#         missing_rain_mask = df_final['imerg_matrix'].isnull()
#         missing_events = df_final[missing_rain_mask]
        
#         # 3. Print dates of dropped events
#         if not missing_events.empty:
#             print(f"\n[WARNING] Found {len(missing_events)} events with NULL rain data. Removing them...")
#             print("--- Dropped Events Log ---")
#             for idx, row in missing_events.iterrows():
#                 try:
#                     d_str = row['start_time'].strftime('%d-%m-%Y %H:%M')
#                 except:
#                     d_str = str(row['start_time'])
#                 print(f"Removing ID: {row['event_id']} | Date: {d_str}")
            
#             # 4. Perform the drop
#             df_final = df_final[~missing_rain_mask].copy()
#             print(f"--- Cleaned. Remaining events: {len(df_final)} ---")
#         else:
#             print("No NULL rain events found. All processed events are valid.")

#         # --------------------------------------

#         # Save Final PKL (Cleaned subset)
#         df_final.to_pickle(OUT_FINAL_PKL)
        
#         print(f"SUCCESS! Final dataset saved to: {OUT_FINAL_PKL}")
        
#         # Final Verification
#         if 'imerg_matrix' in df_final.columns:
#             count = df_final['imerg_matrix'].notnull().sum()
#             print(f"Verified valid Rain Data events: {count}")
#     else:
#         print("Failed to load any batch files.")

# %%
# ============================================
# 0) IMPORTS
# ============================================
import os
import glob
import pandas as pd
import numpy as np
import shapely.wkt
import shapely.geometry
import geopandas as gpd
from affine import Affine
import rasterio.features
from tqdm import tqdm  # Progress bar
import gc  # Garbage Collector for memory management

import ee

# ============================================
# 1) CONFIGURATION
# ============================================

# --- INPUT: The consolidated PKL from step 02a ---
INPUT_PKL = r"D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\chronicle_df_with_pfdi_FULL.pkl"

# --- OUTPUT: Where rain data will be saved ---
OUT_DIR = r"D:\Development\RESEARCH\urban_flood_database\chronicle\imerg_rain_outputs"
OUT_FINAL_PKL = os.path.join(OUT_DIR, "chronicle_urban_df_with_IMERG_FULL.pkl")

# IMERG Constants
# Data available from June 2000
IMERG_START_DATE = pd.Timestamp("2000-06-01") 
SCALE = 0.1  # 0.1 Degree resolution
CRS = 'EPSG:4326'

# Batch Settings
BATCH_SIZE = 1000 
N_BATCHES_TO_RUN = 350  

# ============================================
# 2) HELPERS
# ============================================

def ensure_out_dir(path):
    """Create output directory if it doesn't exist."""
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

def initialize_ee():
    """Initialize Earth Engine."""
    try:
        ee.Initialize()
        print("Earth Engine initialized.")
    except Exception:
        print("Authenticating Earth Engine...")
        ee.Authenticate()
        ee.Initialize()
        print("Earth Engine initialized after auth.")

def get_next_batch_index(out_dir):
    """
    Scans output directory for 'imerg_batch_XXXX.pkl' to determine 
    the next batch number for file naming.
    """
    if not os.path.exists(out_dir):
        return 0
    
    pattern = os.path.join(out_dir, "imerg_batch_*.pkl")
    files = glob.glob(pattern)
    
    if not files:
        return 0
    
    max_batch = -1
    for f in files:
        try:
            filename = os.path.basename(f)
            num_part = filename.split('_')[-1].split('.')[0]
            batch_num = int(num_part)
            if batch_num > max_batch:
                max_batch = batch_num
        except ValueError:
            continue
            
    return max_batch + 1

def extract_rain_data(event_row):
    """
    Extracts IMERG rain matrix, metadata, and mask for a single event.
    Attempts to use FINAL (V06) collection first.
    Falls back to LATE collection if FINAL is unavailable.
    
    Returns: (rain_matrix, rain_mask, rain_meta, imerg_type)
    """
    try:
        # 1. Geometry Setup
        if isinstance(event_row['geometry_wkt'], str):
            poly_geom = shapely.wkt.loads(event_row['geometry_wkt'])
        else:
            poly_geom = event_row['geometry_wkt']
            
        bounds = poly_geom.bounds # (minx, miny, maxx, maxy)
        roi = ee.Geometry.BBox(*bounds)
        
        # 2. Time Window Calculation
        start_t = event_row['start_time'] - pd.Timedelta(hours=72)
        end_t = event_row['end_time'] + pd.Timedelta(hours=24) 
        
        # 3. GEE Request with Fallback Logic
        imerg_type = 'final'
        imerg_coll = ee.ImageCollection("NASA/GPM_L3/IMERG_V06") \
            .select('precipitationCal') \
            .filterBounds(roi) \
            .filterDate(start_t, end_t)
        
        # Fallback to LATE collection if FINAL run is empty (common for recent dates)
        if imerg_coll.size().getInfo() == 0:
            imerg_type = 'late'
            imerg_coll = ee.ImageCollection("NASA/GPM_L3/IMERG_V06_LATE") \
                .select('precipitationCal') \
                .filterBounds(roi) \
                .filterDate(start_t, end_t)

        # Check if data exists in either collection
        if imerg_coll.size().getInfo() == 0:
            return None, None, None, 'missing'

        # 4. Download Data
        stack = imerg_coll.toBands()
        pixel_dict = stack.sampleRectangle(region=roi).getInfo()
        properties = pixel_dict['properties']
        
        # 5. Parse & Stack Arrays
        band_keys = sorted(list(properties.keys()))
        arrays_list = [np.array(properties[b], dtype=np.float32) for b in band_keys]
        rain_matrix = np.stack(arrays_list)
        
        # 6. Create Metadata
        height, width = rain_matrix.shape[1], rain_matrix.shape[2]
        min_lon, min_lat, max_lon, max_lat = bounds
        transform = Affine(SCALE, 0, min_lon, 0, -SCALE, max_lat)
        
        meta = {
            'origin_top_left': (max_lat, min_lon),
            'scale': SCALE,
            'shape': (height, width),
            'timestamps': band_keys
        }

        # 7. Create Binary Mask
        mask = rasterio.features.rasterize(
            [(poly_geom, 1)],
            out_shape=(height, width),
            transform=transform,
            fill=0,
            all_touched=True,
            dtype=np.uint8
        )
        
        return rain_matrix, mask, meta, imerg_type

    except Exception as e:
        # Return error status to avoid breaking the batch
        print(f"Error processing ID {event_row.get('event_id')}: {e}")
        return None, None, None, 'error'

# %%
# ============================================
# 3) INITIALIZATION
# ============================================
initialize_ee()
ensure_out_dir(OUT_DIR)

print(f"Loading full dataset: {INPUT_PKL}")
if not os.path.exists(INPUT_PKL):
    raise FileNotFoundError(f"Input file not found: {INPUT_PKL}.")

df = pd.read_pickle(INPUT_PKL)
df = df.replace([np.inf, -np.inf], np.nan)
df['start_time'] = pd.to_datetime(df['start_time'], unit='s')
df['end_time'] = pd.to_datetime(df['end_time'], unit='s')

# Filter for IMERG Era
df_valid = df[df['start_time'] >= IMERG_START_DATE].copy()

print(f"Total events in input: {len(df)}")
print(f"Events valid for IMERG (post-2000): {len(df_valid)}")

# ============================================
# 4) SMART BATCH PROCESSING (ID-BASED)
# ============================================

print(f"--- PREPARING WORK PLAN ---")

processed_ids = set()
pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
existing_files = glob.glob(pkl_pattern)

if existing_files:
    print(f"Found {len(existing_files)} existing batch files. Scanning for processed IDs...")
    for f in tqdm(existing_files, desc="Indexing existing data"):
        try:
            df_temp = pd.read_pickle(f)
            if 'event_id' in df_temp.columns:
                processed_ids.update(df_temp['event_id'].tolist())
            del df_temp
        except Exception as e:
            print(f"Skipping corrupted file {f}: {e}")

print(f"Total events already processed: {len(processed_ids)}")

df_todo = df_valid[~df_valid['event_id'].isin(processed_ids)].copy()
print(f"Events remaining to process: {len(df_todo)}")

if len(df_todo) == 0:
    print("All events are already processed! Nothing to do.")
else:
    start_batch_num = get_next_batch_index(OUT_DIR)
    n_remaining = len(df_todo)
    max_rows_limit = N_BATCHES_TO_RUN * BATCH_SIZE
    stop_at_row = min(n_remaining, max_rows_limit)

    print(f"Plan: Processing {min(N_BATCHES_TO_RUN, n_remaining // BATCH_SIZE + 1)} batches.")
    
    for batch_i in range(0, stop_at_row, BATCH_SIZE):
        current_file_num = start_batch_num + (batch_i // BATCH_SIZE)
        batch_df = df_todo.iloc[batch_i : batch_i + BATCH_SIZE].copy()
        
        print(f"\nProcessing Batch {current_file_num} ({len(batch_df)} events)...")
        
        matrices, masks, metas, types = [], [], [], []
        
        for idx, row in tqdm(batch_df.iterrows(), total=len(batch_df), desc=f"Batch {current_file_num}"):
            mat, msk, mt, itype = extract_rain_data(row)
            matrices.append(mat)
            masks.append(msk)
            metas.append(mt)
            types.append(itype)
        
        # Assign results including the new source type column
        batch_df['imerg_matrix'] = matrices
        batch_df['imerg_mask'] = masks
        batch_df['imerg_meta'] = metas
        batch_df['imerg_type'] = types
        
        out_path = os.path.join(OUT_DIR, f"imerg_batch_{current_file_num:04d}.pkl")
        batch_df.to_pickle(out_path)
        print(f"Saved: {out_path}")
        
        del batch_df, matrices, masks, metas, types
        gc.collect()

    print("\n--- BATCH LIMIT REACHED ---")

# %%
# ============================================
# 5) FINAL MERGE & CLEANUP
# ============================================
print("\n--- FINALIZING ---")
print("Merging all batch files...")

pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
all_pkl_files = glob.glob(pkl_pattern)

if not all_pkl_files:
    print("No output files found.")
else:
    # Concatenate all batches
    df_list = []
    for f in tqdm(all_pkl_files, desc="Loading Batches"):
        try:
            df_list.append(pd.read_pickle(f))
        except Exception as e:
            print(f"Error loading {f}: {e}")
            
    if df_list:
        # Create results dataframe from all batches
        df_results = pd.concat(df_list, ignore_index=True)
        
        # Determine columns to merge
        merge_cols = ['event_id', 'imerg_matrix', 'imerg_mask', 'imerg_meta']
        if 'imerg_type' in df_results.columns:
            merge_cols.append('imerg_type')
        
        print(f"Loaded {len(df_results)} processed rain events.")
        print("Merging results back to main dataset structure...")
        
        # Reload the original input to ensure clean base columns
        df_base = pd.read_pickle(INPUT_PKL)
        
        # Merge: 'inner' keeps only keys that appear in BOTH DataFrames
        df_final = df_base.merge(
            df_results[merge_cols], 
            on='event_id', 
            how='inner' 
        )
        
        # --- HANDLING OLD BATCHES (Backfilling) ---
        if 'imerg_type' in df_final.columns:
            df_final['imerg_type'] = df_final['imerg_type'].fillna('final')
        else:
            df_final['imerg_type'] = 'final'

        # Ensure start_time is datetime for readable printing
        if 'start_time' in df_final.columns:
            if not pd.api.types.is_datetime64_any_dtype(df_final['start_time']):
                df_final['start_time'] = pd.to_datetime(df_final['start_time'], unit='s')

        # --- FILTER OUT NULL RAIN DATA & LOG DROPPED EVENTS ---
        
        # Identify rows where 'imerg_matrix' is Null (due to GEE masked pixels or errors)
        missing_rain_mask = df_final['imerg_matrix'].isnull()
        missing_events = df_final[missing_rain_mask].copy()
        
        if not missing_events.empty:
            print(f"\n[!] Found {len(missing_events)} events with NULL rain data. These will be removed.")
            print("--- List of Dropped Events ---")
            
            # Print each dropped event with its ID, date and type (if available)
            for idx, row in missing_events.iterrows():
                try:
                    date_str = row['start_time'].strftime('%Y-%m-%d %H:%M')
                except:
                    date_str = str(row['start_time'])
                
                # Check for error type if it was logged during extraction
                e_type = row.get('imerg_type', 'unknown')
                print(f"ID: {row['event_id']} | Date: {date_str} | Status: {e_type}")
            
            print("------------------------------")
            
            # Perform the drop
            df_final = df_final[~missing_rain_mask].copy()
            print(f"--- Cleaned. Remaining events: {len(df_final)} ---")
        else:
            print("No NULL rain events found. All processed events are valid.")

        # Save Final PKL
        df_final.to_pickle(OUT_FINAL_PKL)
        print(f"\nSUCCESS! Final dataset saved to: {OUT_FINAL_PKL}")
        
        # --- FINAL SUMMARY STATISTICS ---
        print("\n--- IMERG Data Quality Summary ---")
        if 'imerg_type' in df_final.columns:
            stats = df_final['imerg_type'].value_counts()
            for label, count in stats.items():
                print(f" - {label.upper()}: {count} events")
        
        # Final Verification
        count = df_final['imerg_matrix'].notnull().sum()
        print(f"Total verified valid Rain Data events: {count}")
    else:
        print("Failed to load any batch files.")
# Out:
# --- FINALIZING ---
# Merging all batch files...
# Loading Batches: 100%|███████████████████████████████████████████████████████████████| 793/793 [00:37<00:00, 21.15it/s]
# Loaded 752500 processed rain events.
# Merging results back to main dataset structure...
#
# [!] Found 51588 events with NULL rain data. These will be removed.
# --- List of Dropped Events ---
# ID: 1134 | Date: 2000-11-01 00:00 | Status: final
# ID: 1546 | Date: 2000-12-06 00:00 | Status: final
# ID: 1639 | Date: 2000-12-13 00:00 | Status: final
# ID: 1668 | Date: 2001-01-01 00:00 | Status: final
# ID: 1724 | Date: 2001-01-01 00:00 | Status: final
# ID: 1788 | Date: 2001-01-01 00:00 | Status: final
# ID: 1984 | Date: 2001-05-01 00:00 | Status: final
# ID: 2697 | Date: 2002-01-01 00:00 | Status: final
# ID: 4777 | Date: 2003-09-02 00:00 | Status: final
# ID: 4778 | Date: 2003-09-02 00:00 | Status: final
# ID: 4779 | Date: 2003-09-02 00:00 | Status: final
# ID: 4780 | Date: 2003-09-02 00:00 | Status: final
# ID: 4783 | Date: 2003-09-02 00:00 | Status: final
# ID: 4784 | Date: 2003-09-02 00:00 | Status: final
# ID: 4785 | Date: 2003-09-02 00:00 | Status: final
# ID: 4786 | Date: 2003-09-02 00:00 | Status: final
# ID: 4788 | Date: 2003-09-02 00:00 | Status: final
# ID: 4789 | Date: 2003-09-02 00:00 | Status: final
# ID: 4790 | Date: 2003-09-02 00:00 | Status: final
# ID: 4791 | Date: 2003-09-02 00:00 | Status: final
# ID: 4792 | Date: 2003-09-05 00:00 | Status: final
# ID: 4793 | Date: 2003-09-05 00:00 | Status: final
# ID: 4794 | Date: 2003-09-05 00:00 | Status: final
# ID: 4795 | Date: 2003-09-05 00:00 | Status: final
# ID: 5324 | Date: 2004-01-01 00:00 | Status: final
# ID: 5372 | Date: 2004-01-01 00:00 | Status: final
# ID: 5556 | Date: 2004-04-01 00:00 | Status: final
# ID: 5568 | Date: 2004-04-01 00:00 | Status: final
# ID: 7275 | Date: 2004-12-26 00:00 | Status: final
# ID: 7284 | Date: 2004-12-26 00:00 | Status: final
# ID: 7415 | Date: 2005-01-01 00:00 | Status: final
# ID: 7467 | Date: 2005-01-01 00:00 | Status: final
# ID: 7546 | Date: 2005-01-01 00:00 | Status: final
# ID: 7605 | Date: 2005-01-08 00:00 | Status: final
# ID: 7609 | Date: 2005-01-08 00:00 | Status: final
# ID: 9589 | Date: 2006-01-01 00:00 | Status: final
# ID: 9637 | Date: 2006-01-01 00:00 | Status: final
# ID: 9816 | Date: 2006-02-18 00:00 | Status: final
# ID: 12345 | Date: 2007-01-01 00:00 | Status: final
# ID: 12393 | Date: 2007-01-01 00:00 | Status: final
# ID: 12466 | Date: 2007-01-01 00:00 | Status: final
# ID: 12522 | Date: 2007-01-09 00:00 | Status: final
# ID: 12523 | Date: 2007-01-10 00:00 | Status: final
# ID: 12555 | Date: 2007-01-16 00:00 | Status: final
# ID: 12558 | Date: 2007-01-18 00:00 | Status: final
# ID: 12941 | Date: 2007-05-01 00:00 | Status: final
# ID: 13599 | Date: 2007-07-05 00:00 | Status: final
# ID: 15982 | Date: 2008-01-01 00:00 | Status: final
# ID: 15996 | Date: 2008-01-01 00:00 | Status: final
# ID: 16252 | Date: 2008-01-15 00:00 | Status: final
# ID: 16256 | Date: 2008-01-15 00:00 | Status: final
# ID: 16314 | Date: 2008-02-03 00:00 | Status: final
# ID: 16377 | Date: 2008-02-25 00:00 | Status: final
# ID: 19802 | Date: 2008-11-16 00:00 | Status: final
# ID: 19948 | Date: 2008-11-27 00:00 | Status: final
# ID: 20307 | Date: 2009-01-01 00:00 | Status: final
# ID: 20476 | Date: 2009-01-11 00:00 | Status: final
# ID: 21279 | Date: 2009-05-01 00:00 | Status: final
# ID: 27695 | Date: 2010-02-22 00:00 | Status: final
# ID: 27698 | Date: 2010-02-22 00:00 | Status: final
# ID: 28228 | Date: 2010-03-07 00:00 | Status: final
# ID: 28231 | Date: 2010-03-07 00:00 | Status: final
# ID: 28250 | Date: 2010-03-09 00:00 | Status: final
# ID: 28255 | Date: 2010-03-09 00:00 | Status: final
# ID: 28261 | Date: 2010-03-09 00:00 | Status: final
# ID: 28262 | Date: 2010-03-09 00:00 | Status: final
# ID: 28266 | Date: 2010-03-09 00:00 | Status: final
# ID: 28273 | Date: 2010-03-11 00:00 | Status: final
# ID: 28274 | Date: 2010-03-11 00:00 | Status: final
# ID: 28278 | Date: 2010-03-11 00:00 | Status: final
# ID: 28279 | Date: 2010-03-11 00:00 | Status: final
# ID: 28281 | Date: 2010-03-11 00:00 | Status: final
# ID: 28492 | Date: 2010-03-28 00:00 | Status: final
# ID: 28677 | Date: 2010-04-04 00:00 | Status: final
# ID: 28772 | Date: 2010-04-12 00:00 | Status: final
# ID: 28775 | Date: 2010-04-12 00:00 | Status: final
# ID: 28787 | Date: 2010-04-14 00:00 | Status: final
# ID: 28798 | Date: 2010-04-14 00:00 | Status: final
# ID: 28802 | Date: 2010-04-14 00:00 | Status: final
# ID: 28957 | Date: 2010-04-27 00:00 | Status: final
# ID: 28964 | Date: 2010-04-27 00:00 | Status: final
# ID: 28974 | Date: 2010-04-28 00:00 | Status: final
# ID: 29524 | Date: 2010-05-15 00:00 | Status: final
# ID: 29531 | Date: 2010-05-15 00:00 | Status: final
# ID: 29533 | Date: 2010-05-15 00:00 | Status: final
# ID: 29560 | Date: 2010-05-15 00:00 | Status: final
# ID: 29571 | Date: 2010-05-15 00:00 | Status: final
# ID: 29585 | Date: 2010-05-15 00:00 | Status: final
# ID: 29610 | Date: 2010-05-15 00:00 | Status: final
# ID: 29751 | Date: 2010-05-16 00:00 | Status: final
# ID: 29821 | Date: 2010-05-16 00:00 | Status: final
# ID: 29876 | Date: 2010-05-17 00:00 | Status: final
# ID: 29913 | Date: 2010-05-17 00:00 | Status: final
# ID: 29995 | Date: 2010-05-18 00:00 | Status: final
# ID: 30115 | Date: 2010-05-20 00:00 | Status: final
# ID: 30123 | Date: 2010-05-20 00:00 | Status: final
# ID: 30129 | Date: 2010-05-20 00:00 | Status: final
# ID: 30139 | Date: 2010-05-20 00:00 | Status: final
# ID: 32496 | Date: 2010-06-18 00:00 | Status: final
# ID: 36769 | Date: 2010-09-15 00:00 | Status: final
# ID: 36780 | Date: 2010-09-15 00:00 | Status: final
# ID: 38351 | Date: 2010-10-16 00:00 | Status: final
# ID: 41551 | Date: 2011-01-01 00:00 | Status: final
# ID: 41738 | Date: 2011-01-01 00:00 | Status: final
# ID: 41762 | Date: 2011-01-01 00:00 | Status: final
# ID: 41850 | Date: 2011-01-01 00:00 | Status: final
# ID: 41877 | Date: 2011-01-01 00:00 | Status: final
# ID: 41918 | Date: 2011-01-01 00:00 | Status: final
# ID: 41936 | Date: 2011-01-01 00:00 | Status: final
# ID: 43769 | Date: 2011-02-26 00:00 | Status: final
# ID: 44491 | Date: 2011-03-21 00:00 | Status: final
# ID: 44497 | Date: 2011-03-22 00:00 | Status: final
# ID: 44498 | Date: 2011-03-22 00:00 | Status: final
# ID: 44500 | Date: 2011-03-22 00:00 | Status: final
# ID: 44541 | Date: 2011-03-23 00:00 | Status: final
# ID: 44550 | Date: 2011-03-23 00:00 | Status: final
# ID: 44560 | Date: 2011-03-23 00:00 | Status: final
# ID: 44577 | Date: 2011-03-23 00:00 | Status: final
# ID: 44585 | Date: 2011-03-23 00:00 | Status: final
# ID: 44587 | Date: 2011-03-23 00:00 | Status: final
# ID: 44887 | Date: 2011-04-12 00:00 | Status: final
# ID: 44894 | Date: 2011-04-12 00:00 | Status: final
# ID: 44902 | Date: 2011-04-12 00:00 | Status: final
# ID: 46264 | Date: 2011-06-09 00:00 | Status: final
# ID: 46292 | Date: 2011-06-10 00:00 | Status: final
# ID: 46294 | Date: 2011-06-10 00:00 | Status: final
# ID: 47917 | Date: 2011-07-19 00:00 | Status: final
# ID: 47971 | Date: 2011-07-20 00:00 | Status: final
# ID: 52728 | Date: 2011-11-08 00:00 | Status: final
# ID: 52870 | Date: 2011-11-15 00:00 | Status: final
# ID: 53345 | Date: 2011-11-25 00:00 | Status: final
# ID: 53351 | Date: 2011-11-25 00:00 | Status: final
# ID: 53356 | Date: 2011-11-25 00:00 | Status: final
# ID: 53365 | Date: 2011-11-25 00:00 | Status: final
# ID: 53443 | Date: 2011-11-28 00:00 | Status: final
# ID: 53995 | Date: 2011-12-26 00:00 | Status: final
# ID: 54091 | Date: 2011-12-28 00:00 | Status: final
# ID: 54164 | Date: 2012-01-01 00:00 | Status: final
# ID: 54206 | Date: 2012-01-01 00:00 | Status: final
# ID: 55684 | Date: 2012-02-22 00:00 | Status: final
# ID: 56047 | Date: 2012-03-11 00:00 | Status: final
# ID: 56134 | Date: 2012-03-22 00:00 | Status: final
# ID: 56139 | Date: 2012-03-22 00:00 | Status: final
# ID: 56141 | Date: 2012-03-22 00:00 | Status: final
# ID: 56146 | Date: 2012-03-22 00:00 | Status: final
# ID: 56151 | Date: 2012-03-22 00:00 | Status: final
# ID: 56152 | Date: 2012-03-22 00:00 | Status: final
# ID: 56153 | Date: 2012-03-22 00:00 | Status: final
# ID: 56154 | Date: 2012-03-22 00:00 | Status: final
# ID: 56155 | Date: 2012-03-22 00:00 | Status: final
# ID: 56160 | Date: 2012-03-22 00:00 | Status: final
# ID: 56161 | Date: 2012-03-22 00:00 | Status: final
# ID: 56162 | Date: 2012-03-22 00:00 | Status: final
# ID: 56221 | Date: 2012-03-28 00:00 | Status: final
# ID: 56285 | Date: 2012-04-01 00:00 | Status: final
# ID: 56302 | Date: 2012-04-02 00:00 | Status: final
# ID: 56306 | Date: 2012-04-02 00:00 | Status: final
# ID: 56314 | Date: 2012-04-02 00:00 | Status: final
# ID: 56319 | Date: 2012-04-02 00:00 | Status: final
# ID: 56332 | Date: 2012-04-02 00:00 | Status: final
# ID: 56432 | Date: 2012-04-09 00:00 | Status: final
# ID: 56434 | Date: 2012-04-09 00:00 | Status: final
# ID: 56446 | Date: 2012-04-09 00:00 | Status: final
# ID: 56450 | Date: 2012-04-09 00:00 | Status: final
# ID: 56454 | Date: 2012-04-09 00:00 | Status: final
# ID: 56537 | Date: 2012-04-16 00:00 | Status: final
# ID: 56539 | Date: 2012-04-16 00:00 | Status: final
# ID: 56560 | Date: 2012-04-16 00:00 | Status: final
# ID: 56562 | Date: 2012-04-16 00:00 | Status: final
# ID: 56564 | Date: 2012-04-16 00:00 | Status: final
# ID: 56593 | Date: 2012-04-18 00:00 | Status: final
# ID: 56594 | Date: 2012-04-18 00:00 | Status: final
# ID: 56600 | Date: 2012-04-18 00:00 | Status: final
# ID: 56607 | Date: 2012-04-18 00:00 | Status: final
# ID: 56623 | Date: 2012-04-18 00:00 | Status: final
# ID: 56647 | Date: 2012-04-21 00:00 | Status: final
# ID: 56662 | Date: 2012-04-21 00:00 | Status: final
# ID: 56679 | Date: 2012-04-21 00:00 | Status: final
# ID: 56681 | Date: 2012-04-21 00:00 | Status: final
# ID: 56686 | Date: 2012-04-21 00:00 | Status: final
# ID: 56712 | Date: 2012-04-24 00:00 | Status: final
# ID: 56717 | Date: 2012-04-24 00:00 | Status: final
# ID: 56737 | Date: 2012-04-24 00:00 | Status: final
# ID: 56743 | Date: 2012-04-24 00:00 | Status: final
# ID: 56778 | Date: 2012-04-27 00:00 | Status: final
# ID: 56779 | Date: 2012-04-27 00:00 | Status: final
# ID: 56794 | Date: 2012-04-27 00:00 | Status: final
# ID: 56813 | Date: 2012-04-27 00:00 | Status: final
# ID: 56819 | Date: 2012-04-27 00:00 | Status: final
# ID: 56881 | Date: 2012-05-01 00:00 | Status: final
# ID: 57168 | Date: 2012-05-20 00:00 | Status: final
# ID: 57348 | Date: 2012-05-23 00:00 | Status: final
# ID: 57502 | Date: 2012-05-28 00:00 | Status: final
# ID: 57720 | Date: 2012-06-05 00:00 | Status: final
# ID: 59298 | Date: 2012-07-13 00:00 | Status: final
# ID: 59317 | Date: 2012-07-14 00:00 | Status: final
# ID: 59325 | Date: 2012-07-14 00:00 | Status: final
# ID: 62257 | Date: 2012-09-19 00:00 | Status: final
# ID: 63059 | Date: 2012-10-06 00:00 | Status: final
# ID: 63060 | Date: 2012-10-06 00:00 | Status: final
# ID: 63136 | Date: 2012-10-10 00:00 | Status: final
# ID: 64291 | Date: 2012-10-30 00:00 | Status: final
# ID: 66994 | Date: 2013-01-01 00:00 | Status: final
# ID: 67088 | Date: 2013-01-01 00:00 | Status: final
# ID: 67151 | Date: 2013-01-01 00:00 | Status: final
# ID: 67220 | Date: 2013-01-01 00:00 | Status: final
# ID: 67279 | Date: 2013-01-01 00:00 | Status: final
# ID: 67287 | Date: 2013-01-01 00:00 | Status: final
# ID: 67288 | Date: 2013-01-01 00:00 | Status: final
# ID: 67372 | Date: 2013-01-01 00:00 | Status: final
# ID: 67396 | Date: 2013-01-01 00:00 | Status: final
# ID: 67437 | Date: 2013-01-01 00:00 | Status: final
# ID: 68996 | Date: 2013-02-01 00:00 | Status: final
# ID: 69724 | Date: 2013-02-23 00:00 | Status: final
# ID: 69726 | Date: 2013-02-23 00:00 | Status: final
# ID: 69812 | Date: 2013-02-26 00:00 | Status: final
# ID: 69819 | Date: 2013-02-26 00:00 | Status: final
# ID: 69854 | Date: 2013-02-26 00:00 | Status: final
# ID: 69902 | Date: 2013-03-01 00:00 | Status: final
# ID: 70589 | Date: 2013-03-22 00:00 | Status: final
# ID: 71131 | Date: 2013-04-01 00:00 | Status: final
# ID: 71528 | Date: 2013-04-04 00:00 | Status: final
# ID: 71995 | Date: 2013-04-15 00:00 | Status: final
# ID: 72006 | Date: 2013-04-15 00:00 | Status: final
# ID: 72007 | Date: 2013-04-15 00:00 | Status: final
# ID: 72009 | Date: 2013-04-15 00:00 | Status: final
# ID: 72013 | Date: 2013-04-15 00:00 | Status: final
# ID: 72024 | Date: 2013-04-15 00:00 | Status: final
# ID: 72031 | Date: 2013-04-16 00:00 | Status: final
# ID: 72152 | Date: 2013-04-18 00:00 | Status: final
# ID: 72277 | Date: 2013-04-19 00:00 | Status: final
# ID: 72280 | Date: 2013-04-19 00:00 | Status: final
# ID: 72298 | Date: 2013-04-19 00:00 | Status: final
# ID: 72335 | Date: 2013-04-20 00:00 | Status: final
# ID: 72336 | Date: 2013-04-20 00:00 | Status: final
# ID: 72338 | Date: 2013-04-20 00:00 | Status: final
# ID: 72350 | Date: 2013-04-20 00:00 | Status: final
# ID: 72371 | Date: 2013-04-21 00:00 | Status: final
# ID: 72673 | Date: 2013-05-01 00:00 | Status: final
# ID: 72905 | Date: 2013-05-04 00:00 | Status: final
# ID: 72916 | Date: 2013-05-04 00:00 | Status: final
# ID: 72918 | Date: 2013-05-04 00:00 | Status: final
# ID: 73121 | Date: 2013-05-09 00:00 | Status: final
# ID: 73309 | Date: 2013-05-15 00:00 | Status: final
# ID: 73349 | Date: 2013-05-16 00:00 | Status: final
# ID: 73400 | Date: 2013-05-16 00:00 | Status: final
# ID: 73401 | Date: 2013-05-16 00:00 | Status: final
# ID: 73548 | Date: 2013-05-18 00:00 | Status: final
# ID: 73603 | Date: 2013-05-18 00:00 | Status: final
# ID: 73607 | Date: 2013-05-18 00:00 | Status: final
# ID: 73628 | Date: 2013-05-18 00:00 | Status: final
# ID: 73633 | Date: 2013-05-18 00:00 | Status: final
# ID: 73640 | Date: 2013-05-18 00:00 | Status: final
# ID: 73738 | Date: 2013-05-22 00:00 | Status: final
# ID: 73740 | Date: 2013-05-22 00:00 | Status: final
# ID: 73742 | Date: 2013-05-22 00:00 | Status: final
# ID: 73745 | Date: 2013-05-22 00:00 | Status: final
# ID: 73748 | Date: 2013-05-22 00:00 | Status: final
# ID: 73749 | Date: 2013-05-22 00:00 | Status: final
# ID: 73754 | Date: 2013-05-22 00:00 | Status: final
# ID: 73756 | Date: 2013-05-22 00:00 | Status: final
# ID: 73758 | Date: 2013-05-22 00:00 | Status: final
# ID: 73795 | Date: 2013-05-22 00:00 | Status: final
# ID: 73797 | Date: 2013-05-22 00:00 | Status: final
# ID: 73818 | Date: 2013-05-23 00:00 | Status: final
# ID: 73825 | Date: 2013-05-23 00:00 | Status: final
# ID: 73830 | Date: 2013-05-23 00:00 | Status: final
# ID: 73835 | Date: 2013-05-23 00:00 | Status: final
# ID: 73838 | Date: 2013-05-23 00:00 | Status: final
# ID: 73842 | Date: 2013-05-23 00:00 | Status: final
# ID: 73909 | Date: 2013-05-26 00:00 | Status: final
# ID: 75345 | Date: 2013-06-02 00:00 | Status: final
# ID: 76737 | Date: 2013-06-10 00:00 | Status: final
# ID: 89269 | Date: 2013-10-28 00:00 | Status: final
# ID: 89272 | Date: 2013-10-28 00:00 | Status: final
# ID: 89280 | Date: 2013-10-28 00:00 | Status: final
# ID: 89856 | Date: 2013-11-10 00:00 | Status: final
# ID: 90320 | Date: 2013-11-15 00:00 | Status: final
# ID: 90322 | Date: 2013-11-15 00:00 | Status: final
# ID: 90332 | Date: 2013-11-15 00:00 | Status: final
# ID: 91322 | Date: 2013-11-27 00:00 | Status: final
# ID: 91327 | Date: 2013-11-27 00:00 | Status: final
# ID: 91956 | Date: 2013-12-10 00:00 | Status: final
# ID: 91964 | Date: 2013-12-10 00:00 | Status: final
# ID: 91989 | Date: 2013-12-10 00:00 | Status: final
# ID: 92009 | Date: 2013-12-11 00:00 | Status: final
# ID: 92023 | Date: 2013-12-11 00:00 | Status: final
# ID: 92117 | Date: 2013-12-13 00:00 | Status: final
# ID: 93171 | Date: 2013-12-29 00:00 | Status: final
# ID: 93180 | Date: 2013-12-29 00:00 | Status: final
# ID: 93450 | Date: 2014-01-01 00:00 | Status: final
# ID: 93698 | Date: 2014-01-01 00:00 | Status: final
# ID: 93699 | Date: 2014-01-01 00:00 | Status: final
# ID: 93702 | Date: 2014-01-01 00:00 | Status: final
# ID: 98578 | Date: 2014-02-28 00:00 | Status: final
# ID: 101815 | Date: 2014-05-12 00:00 | Status: final
# ID: 102849 | Date: 2014-05-18 00:00 | Status: final
# ID: 102854 | Date: 2014-05-18 00:00 | Status: final
# ID: 103352 | Date: 2014-05-25 00:00 | Status: final
# ID: 103380 | Date: 2014-05-25 00:00 | Status: final
# ID: 103455 | Date: 2014-05-26 00:00 | Status: final
# ID: 107261 | Date: 2014-07-11 00:00 | Status: final
# ID: 118846 | Date: 2014-10-26 00:00 | Status: final
# ID: 118855 | Date: 2014-10-27 00:00 | Status: final
# ID: 118866 | Date: 2014-10-27 00:00 | Status: final
# ID: 118868 | Date: 2014-10-27 00:00 | Status: final
# ID: 118875 | Date: 2014-10-27 00:00 | Status: final
# ID: 118880 | Date: 2014-10-27 00:00 | Status: final
# ID: 118896 | Date: 2014-10-28 00:00 | Status: final
# ID: 118897 | Date: 2014-10-28 00:00 | Status: final
# ID: 118899 | Date: 2014-10-28 00:00 | Status: final
# ID: 118905 | Date: 2014-10-28 00:00 | Status: final
# ID: 118911 | Date: 2014-10-28 00:00 | Status: final
# ID: 118913 | Date: 2014-10-28 00:00 | Status: final
# ID: 118914 | Date: 2014-10-28 00:00 | Status: final
# ID: 118918 | Date: 2014-10-28 00:00 | Status: final
# ID: 118921 | Date: 2014-10-28 00:00 | Status: final
# ID: 118929 | Date: 2014-10-28 00:00 | Status: final
# ID: 118931 | Date: 2014-10-28 00:00 | Status: final
# ID: 118937 | Date: 2014-10-28 00:00 | Status: final
# ID: 118938 | Date: 2014-10-28 00:00 | Status: final
# ID: 118940 | Date: 2014-10-28 00:00 | Status: final
# ID: 118945 | Date: 2014-10-28 00:00 | Status: final
# ID: 118946 | Date: 2014-10-28 00:00 | Status: final
# ID: 119408 | Date: 2014-11-03 00:00 | Status: final
# ID: 121355 | Date: 2014-11-25 00:00 | Status: final
# ID: 124053 | Date: 2014-12-30 00:00 | Status: final
# ID: 124192 | Date: 2015-01-01 00:00 | Status: final
# ID: 124261 | Date: 2015-01-01 00:00 | Status: final
# ID: 124449 | Date: 2015-01-01 00:00 | Status: final
# ID: 124458 | Date: 2015-01-02 00:00 | Status: final
# ID: 124939 | Date: 2015-01-13 00:00 | Status: final
# ID: 125060 | Date: 2015-01-15 00:00 | Status: final
# ID: 125080 | Date: 2015-01-16 00:00 | Status: final
# ID: 125227 | Date: 2015-01-20 00:00 | Status: final
# ID: 126922 | Date: 2015-02-11 00:00 | Status: final
# ID: 126932 | Date: 2015-02-11 00:00 | Status: final
# ID: 126940 | Date: 2015-02-11 00:00 | Status: final
# ID: 126944 | Date: 2015-02-11 00:00 | Status: final
# ID: 126958 | Date: 2015-02-11 00:00 | Status: final
# ID: 127028 | Date: 2015-02-12 00:00 | Status: final
# ID: 127235 | Date: 2015-02-16 00:00 | Status: final
# ID: 131452 | Date: 2015-05-13 00:00 | Status: final
# ID: 131828 | Date: 2015-05-22 00:00 | Status: final
# ID: 135212 | Date: 2015-07-03 00:00 | Status: final
# ID: 136004 | Date: 2015-07-16 00:00 | Status: final
# ID: 143473 | Date: 2015-10-01 00:00 | Status: final
# ID: 143563 | Date: 2015-10-02 00:00 | Status: final
# ID: 143619 | Date: 2015-10-02 00:00 | Status: final
# ID: 143629 | Date: 2015-10-02 00:00 | Status: final
# ID: 146457 | Date: 2015-11-01 00:00 | Status: final
# ID: 148338 | Date: 2015-11-27 00:00 | Status: final
# ID: 148401 | Date: 2015-11-27 00:00 | Status: final
# ID: 148410 | Date: 2015-11-27 00:00 | Status: final
# ID: 148416 | Date: 2015-11-27 00:00 | Status: final
# ID: 148772 | Date: 2015-12-01 00:00 | Status: final
# ID: 148951 | Date: 2015-12-04 00:00 | Status: final
# ID: 149010 | Date: 2015-12-04 00:00 | Status: final
# ID: 149092 | Date: 2015-12-05 00:00 | Status: final
# ID: 149112 | Date: 2015-12-05 00:00 | Status: final
# ID: 149943 | Date: 2015-12-19 00:00 | Status: final
# ID: 149949 | Date: 2015-12-20 00:00 | Status: final
# ID: 149959 | Date: 2015-12-20 00:00 | Status: final
# ID: 149962 | Date: 2015-12-20 00:00 | Status: final
# ID: 150109 | Date: 2015-12-25 00:00 | Status: final
# ID: 150884 | Date: 2016-01-01 00:00 | Status: final
# ID: 151517 | Date: 2016-01-05 00:00 | Status: final
# ID: 154452 | Date: 2016-02-11 00:00 | Status: final
# ID: 156066 | Date: 2016-03-03 00:00 | Status: final
# ID: 157129 | Date: 2016-03-14 00:00 | Status: final
# ID: 157131 | Date: 2016-03-14 00:00 | Status: final
# ID: 158358 | Date: 2016-04-11 00:00 | Status: final
# ID: 158552 | Date: 2016-04-14 00:00 | Status: final
# ID: 158571 | Date: 2016-04-14 00:00 | Status: final
# ID: 158671 | Date: 2016-04-15 00:00 | Status: final
# ID: 158717 | Date: 2016-04-16 00:00 | Status: final
# ID: 158741 | Date: 2016-04-16 00:00 | Status: final
# ID: 158936 | Date: 2016-04-18 00:00 | Status: final
# ID: 159022 | Date: 2016-04-18 00:00 | Status: final
# ID: 159044 | Date: 2016-04-19 00:00 | Status: final
# ID: 159045 | Date: 2016-04-19 00:00 | Status: final
# ID: 159069 | Date: 2016-04-19 00:00 | Status: final
# ID: 159157 | Date: 2016-04-20 00:00 | Status: final
# ID: 159159 | Date: 2016-04-20 00:00 | Status: final
# ID: 159267 | Date: 2016-04-21 00:00 | Status: final
# ID: 159518 | Date: 2016-04-25 00:00 | Status: final
# ID: 161448 | Date: 2016-05-22 00:00 | Status: final
# ID: 161499 | Date: 2016-05-23 00:00 | Status: final
# ID: 161512 | Date: 2016-05-23 00:00 | Status: final
# ID: 165570 | Date: 2016-06-06 00:00 | Status: final
# ID: 169723 | Date: 2016-06-29 00:00 | Status: final
# ID: 169882 | Date: 2016-07-01 00:00 | Status: final
# ID: 170379 | Date: 2016-07-04 00:00 | Status: final
# ID: 170660 | Date: 2016-07-06 00:00 | Status: final
# ID: 171256 | Date: 2016-07-12 00:00 | Status: final
# ID: 180630 | Date: 2016-10-01 00:00 | Status: final
# ID: 182620 | Date: 2016-10-15 00:00 | Status: final
# ID: 183206 | Date: 2016-10-21 00:00 | Status: final
# ID: 183214 | Date: 2016-10-21 00:00 | Status: final
# ID: 184163 | Date: 2016-11-02 00:00 | Status: final
# ID: 188368 | Date: 2016-12-05 00:00 | Status: final
# ID: 188381 | Date: 2016-12-05 00:00 | Status: final
# ID: 188385 | Date: 2016-12-05 00:00 | Status: final
# ID: 188445 | Date: 2016-12-05 00:00 | Status: final
# ID: 188736 | Date: 2016-12-11 00:00 | Status: final
# ID: 189169 | Date: 2016-12-15 00:00 | Status: final
# ID: 189701 | Date: 2016-12-20 00:00 | Status: final
# ID: 190541 | Date: 2017-01-01 00:00 | Status: final
# ID: 190683 | Date: 2017-01-01 00:00 | Status: final
# ID: 191066 | Date: 2017-01-04 00:00 | Status: final
# ID: 191670 | Date: 2017-01-12 00:00 | Status: final
# ID: 191724 | Date: 2017-01-12 00:00 | Status: final
# ID: 192318 | Date: 2017-01-19 00:00 | Status: final
# ID: 192348 | Date: 2017-01-19 00:00 | Status: final
# ID: 192483 | Date: 2017-01-20 00:00 | Status: final
# ID: 192576 | Date: 2017-01-20 00:00 | Status: final
# ID: 192594 | Date: 2017-01-20 00:00 | Status: final
# ID: 193408 | Date: 2017-01-25 00:00 | Status: final
# ID: 193536 | Date: 2017-01-26 00:00 | Status: final
# ID: 194556 | Date: 2017-02-06 00:00 | Status: final
# ID: 195388 | Date: 2017-02-14 00:00 | Status: final
# ID: 201605 | Date: 2017-05-01 00:00 | Status: final
# ID: 203314 | Date: 2017-05-17 00:00 | Status: final
# ID: 203354 | Date: 2017-05-18 00:00 | Status: final
# ID: 203357 | Date: 2017-05-18 00:00 | Status: final
# ID: 203364 | Date: 2017-05-18 00:00 | Status: final
# ID: 203371 | Date: 2017-05-18 00:00 | Status: final
# ID: 203378 | Date: 2017-05-18 00:00 | Status: final
# ID: 203384 | Date: 2017-05-18 00:00 | Status: final
# ID: 203392 | Date: 2017-05-18 00:00 | Status: final
# ID: 203403 | Date: 2017-05-18 00:00 | Status: final
# ID: 203405 | Date: 2017-05-18 00:00 | Status: final
# ID: 203493 | Date: 2017-05-19 00:00 | Status: final
# ID: 203626 | Date: 2017-05-20 00:00 | Status: final
# ID: 205079 | Date: 2017-06-01 00:00 | Status: final
# ID: 205098 | Date: 2017-06-01 00:00 | Status: final
# ID: 205166 | Date: 2017-06-01 00:00 | Status: final
# ID: 205235 | Date: 2017-06-01 00:00 | Status: final
# ID: 206189 | Date: 2017-06-07 00:00 | Status: final
# ID: 206401 | Date: 2017-06-08 00:00 | Status: final
# ID: 206429 | Date: 2017-06-08 00:00 | Status: final
# ID: 206447 | Date: 2017-06-08 00:00 | Status: final
# ID: 211277 | Date: 2017-07-13 00:00 | Status: final
# ID: 213218 | Date: 2017-07-23 00:00 | Status: final
# ID: 223527 | Date: 2017-09-27 00:00 | Status: final
# ID: 223613 | Date: 2017-09-29 00:00 | Status: final
# ID: 224013 | Date: 2017-10-02 00:00 | Status: final
# ID: 227625 | Date: 2017-11-03 00:00 | Status: final
# ID: 229647 | Date: 2017-11-22 00:00 | Status: final
# ID: 229649 | Date: 2017-11-22 00:00 | Status: final
# ID: 231509 | Date: 2017-12-05 00:00 | Status: final
# ID: 231691 | Date: 2017-12-07 00:00 | Status: final
# ID: 231718 | Date: 2017-12-07 00:00 | Status: final
# ID: 231729 | Date: 2017-12-07 00:00 | Status: final
# ID: 232980 | Date: 2017-12-22 00:00 | Status: final
# ID: 233057 | Date: 2017-12-23 00:00 | Status: final
# ID: 233058 | Date: 2017-12-23 00:00 | Status: final
# ID: 233072 | Date: 2017-12-23 00:00 | Status: final
# ID: 233075 | Date: 2017-12-23 00:00 | Status: final
# ID: 233092 | Date: 2017-12-24 00:00 | Status: final
# ID: 233140 | Date: 2017-12-25 00:00 | Status: final
# ID: 233254 | Date: 2017-12-28 00:00 | Status: final
# ID: 233382 | Date: 2017-12-31 00:00 | Status: final
# ID: 233492 | Date: 2018-01-01 00:00 | Status: final
# ID: 233555 | Date: 2018-01-01 00:00 | Status: final
# ID: 233584 | Date: 2018-01-01 00:00 | Status: final
# ID: 233697 | Date: 2018-01-01 00:00 | Status: final
# ID: 233783 | Date: 2018-01-01 00:00 | Status: final
# ID: 233894 | Date: 2018-01-01 00:00 | Status: final
# ID: 233898 | Date: 2018-01-01 00:00 | Status: final
# ID: 235858 | Date: 2018-01-08 00:00 | Status: final
# ID: 236622 | Date: 2018-01-17 00:00 | Status: final
# ID: 238192 | Date: 2018-01-27 00:00 | Status: final
# ID: 238402 | Date: 2018-01-31 00:00 | Status: final
# ID: 238811 | Date: 2018-02-04 00:00 | Status: final
# ID: 238867 | Date: 2018-02-05 00:00 | Status: final
# ID: 239032 | Date: 2018-02-06 00:00 | Status: final
# ID: 240404 | Date: 2018-02-21 00:00 | Status: final
# ID: 240608 | Date: 2018-02-21 00:00 | Status: final
# ID: 240871 | Date: 2018-02-22 00:00 | Status: final
# ID: 241454 | Date: 2018-02-27 00:00 | Status: final
# ID: 241799 | Date: 2018-03-01 00:00 | Status: final
# ID: 243587 | Date: 2018-03-13 00:00 | Status: final
# ID: 244569 | Date: 2018-03-22 00:00 | Status: final
# ID: 245370 | Date: 2018-04-01 00:00 | Status: final
# ID: 245421 | Date: 2018-04-01 00:00 | Status: final
# ID: 245776 | Date: 2018-04-05 00:00 | Status: final
# ID: 245784 | Date: 2018-04-05 00:00 | Status: final
# ID: 245791 | Date: 2018-04-05 00:00 | Status: final
# ID: 245803 | Date: 2018-04-05 00:00 | Status: final
# ID: 246005 | Date: 2018-04-08 00:00 | Status: final
# ID: 246007 | Date: 2018-04-08 00:00 | Status: final
# ID: 246431 | Date: 2018-04-12 00:00 | Status: final
# ID: 246845 | Date: 2018-04-15 00:00 | Status: final
# ID: 246857 | Date: 2018-04-15 00:00 | Status: final
# ID: 246913 | Date: 2018-04-15 00:00 | Status: final
# ID: 247197 | Date: 2018-04-18 00:00 | Status: final
# ID: 247259 | Date: 2018-04-19 00:00 | Status: final
# ID: 247274 | Date: 2018-04-19 00:00 | Status: final
# ID: 247314 | Date: 2018-04-20 00:00 | Status: final
# ID: 247351 | Date: 2018-04-20 00:00 | Status: final
# ID: 247372 | Date: 2018-04-21 00:00 | Status: final
# ID: 247382 | Date: 2018-04-21 00:00 | Status: final
# ID: 247425 | Date: 2018-04-21 00:00 | Status: final
# ID: 247472 | Date: 2018-04-21 00:00 | Status: final
# ID: 247482 | Date: 2018-04-21 00:00 | Status: final
# ID: 247498 | Date: 2018-04-22 00:00 | Status: final
# ID: 247499 | Date: 2018-04-22 00:00 | Status: final
# ID: 247507 | Date: 2018-04-22 00:00 | Status: final
# ID: 247515 | Date: 2018-04-22 00:00 | Status: final
# ID: 247523 | Date: 2018-04-22 00:00 | Status: final
# ID: 247594 | Date: 2018-04-22 00:00 | Status: final
# ID: 247606 | Date: 2018-04-22 00:00 | Status: final
# ID: 247653 | Date: 2018-04-23 00:00 | Status: final
# ID: 247756 | Date: 2018-04-24 00:00 | Status: final
# ID: 248732 | Date: 2018-05-01 00:00 | Status: final
# ID: 248847 | Date: 2018-05-01 00:00 | Status: final
# ID: 248962 | Date: 2018-05-02 00:00 | Status: final
# ID: 249212 | Date: 2018-05-05 00:00 | Status: final
# ID: 249399 | Date: 2018-05-06 00:00 | Status: final
# ID: 249456 | Date: 2018-05-07 00:00 | Status: final
# ID: 249598 | Date: 2018-05-07 00:00 | Status: final
# ID: 249830 | Date: 2018-05-09 00:00 | Status: final
# ID: 249869 | Date: 2018-05-09 00:00 | Status: final
# ID: 250005 | Date: 2018-05-10 00:00 | Status: final
# ID: 250013 | Date: 2018-05-10 00:00 | Status: final
# ID: 250020 | Date: 2018-05-10 00:00 | Status: final
# ID: 250066 | Date: 2018-05-10 00:00 | Status: final
# ID: 250119 | Date: 2018-05-10 00:00 | Status: final
# ID: 250121 | Date: 2018-05-10 00:00 | Status: final
# ID: 250207 | Date: 2018-05-11 00:00 | Status: final
# ID: 250208 | Date: 2018-05-11 00:00 | Status: final
# ID: 250211 | Date: 2018-05-11 00:00 | Status: final
# ID: 250216 | Date: 2018-05-11 00:00 | Status: final
# ID: 250222 | Date: 2018-05-11 00:00 | Status: final
# ID: 250223 | Date: 2018-05-11 00:00 | Status: final
# ID: 250230 | Date: 2018-05-11 00:00 | Status: final
# ID: 250231 | Date: 2018-05-11 00:00 | Status: final
# ID: 250243 | Date: 2018-05-11 00:00 | Status: final
# ID: 250251 | Date: 2018-05-11 00:00 | Status: final
# ID: 250252 | Date: 2018-05-11 00:00 | Status: final
# ID: 250356 | Date: 2018-05-12 00:00 | Status: final
# ID: 250365 | Date: 2018-05-12 00:00 | Status: final
# ID: 250484 | Date: 2018-05-13 00:00 | Status: final
# ID: 250512 | Date: 2018-05-14 00:00 | Status: final
# ID: 250622 | Date: 2018-05-15 00:00 | Status: final
# ID: 250972 | Date: 2018-05-18 00:00 | Status: final
# ID: 251275 | Date: 2018-05-20 00:00 | Status: final
# ID: 252088 | Date: 2018-05-24 00:00 | Status: final
# ID: 255086 | Date: 2018-05-31 00:00 | Status: final
# ID: 255505 | Date: 2018-06-01 00:00 | Status: final
# ID: 256364 | Date: 2018-06-03 00:00 | Status: final
# ID: 273667 | Date: 2018-08-10 00:00 | Status: final
# ID: 276142 | Date: 2018-08-18 00:00 | Status: final
# ID: 283138 | Date: 2018-09-24 00:00 | Status: final
# ID: 283165 | Date: 2018-09-24 00:00 | Status: final
# ID: 283170 | Date: 2018-09-24 00:00 | Status: final
# ID: 283204 | Date: 2018-09-24 00:00 | Status: final
# ID: 283240 | Date: 2018-09-25 00:00 | Status: final
# ID: 283247 | Date: 2018-09-25 00:00 | Status: final
# ID: 283372 | Date: 2018-09-25 00:00 | Status: final
# ID: 283414 | Date: 2018-09-26 00:00 | Status: final
# ID: 283526 | Date: 2018-09-26 00:00 | Status: final
# ID: 284181 | Date: 2018-10-01 00:00 | Status: final
# ID: 284288 | Date: 2018-10-01 00:00 | Status: final
# ID: 286233 | Date: 2018-10-13 00:00 | Status: final
# ID: 286252 | Date: 2018-10-13 00:00 | Status: final
# ID: 286267 | Date: 2018-10-13 00:00 | Status: final
# ID: 286275 | Date: 2018-10-13 00:00 | Status: final
# ID: 286298 | Date: 2018-10-13 00:00 | Status: final
# ID: 286375 | Date: 2018-10-14 00:00 | Status: final
# ID: 286419 | Date: 2018-10-14 00:00 | Status: final
# ID: 286436 | Date: 2018-10-14 00:00 | Status: final
# ID: 286442 | Date: 2018-10-14 00:00 | Status: final
# ID: 286488 | Date: 2018-10-14 00:00 | Status: final
# ID: 286492 | Date: 2018-10-14 00:00 | Status: final
# ID: 286512 | Date: 2018-10-14 00:00 | Status: final
# ID: 286518 | Date: 2018-10-14 00:00 | Status: final
# ID: 286569 | Date: 2018-10-14 00:00 | Status: final
# ID: 286634 | Date: 2018-10-14 00:00 | Status: final
# ID: 286681 | Date: 2018-10-14 00:00 | Status: final
# ID: 286753 | Date: 2018-10-15 00:00 | Status: final
# ID: 287025 | Date: 2018-10-16 00:00 | Status: final
# ID: 287032 | Date: 2018-10-16 00:00 | Status: final
# ID: 287085 | Date: 2018-10-16 00:00 | Status: final
# ID: 289322 | Date: 2018-10-29 00:00 | Status: final
# ID: 289469 | Date: 2018-10-30 00:00 | Status: final
# ID: 289522 | Date: 2018-10-30 00:00 | Status: final
# ID: 291130 | Date: 2018-11-11 00:00 | Status: final
# ID: 295582 | Date: 2018-12-22 00:00 | Status: final
# ID: 295789 | Date: 2018-12-25 00:00 | Status: final
# ID: 296351 | Date: 2019-01-01 00:00 | Status: final
# ID: 296426 | Date: 2019-01-01 00:00 | Status: final
# ID: 296471 | Date: 2019-01-01 00:00 | Status: final
# ID: 296899 | Date: 2019-01-04 00:00 | Status: final
# ID: 298109 | Date: 2019-01-18 00:00 | Status: final
# ID: 299150 | Date: 2019-01-25 00:00 | Status: final
# ID: 300447 | Date: 2019-02-04 00:00 | Status: final
# ID: 301467 | Date: 2019-02-14 00:00 | Status: final
# ID: 301502 | Date: 2019-02-14 00:00 | Status: final
# ID: 301557 | Date: 2019-02-15 00:00 | Status: final
# ID: 303748 | Date: 2019-03-07 00:00 | Status: final
# ID: 303896 | Date: 2019-03-09 00:00 | Status: final
# ID: 305346 | Date: 2019-03-22 00:00 | Status: final
# ID: 305401 | Date: 2019-03-23 00:00 | Status: final
# ID: 305448 | Date: 2019-03-23 00:00 | Status: final
# ID: 312281 | Date: 2019-05-22 00:00 | Status: final
# ID: 324590 | Date: 2019-07-30 00:00 | Status: final
# ID: 324616 | Date: 2019-07-30 00:00 | Status: final
# ID: 324732 | Date: 2019-07-30 00:00 | Status: final
# ID: 327986 | Date: 2019-08-12 00:00 | Status: final
# ID: 333743 | Date: 2019-09-14 00:00 | Status: final
# ID: 333855 | Date: 2019-09-15 00:00 | Status: final
# ID: 333903 | Date: 2019-09-15 00:00 | Status: final
# ID: 333946 | Date: 2019-09-15 00:00 | Status: final
# ID: 334026 | Date: 2019-09-16 00:00 | Status: final
# ID: 338705 | Date: 2019-10-16 00:00 | Status: final
# ID: 341056 | Date: 2019-10-28 00:00 | Status: final
# ID: 342004 | Date: 2019-11-04 00:00 | Status: final
# ID: 342515 | Date: 2019-11-08 00:00 | Status: final
# ID: 343341 | Date: 2019-11-14 00:00 | Status: final
# ID: 343387 | Date: 2019-11-14 00:00 | Status: final
# ID: 345710 | Date: 2019-11-26 00:00 | Status: final
# ID: 345934 | Date: 2019-11-28 00:00 | Status: final
# ID: 346855 | Date: 2019-12-04 00:00 | Status: final
# ID: 349075 | Date: 2019-12-18 00:00 | Status: final
# ID: 349113 | Date: 2019-12-18 00:00 | Status: final
# ID: 349173 | Date: 2019-12-18 00:00 | Status: final
# ID: 349256 | Date: 2019-12-19 00:00 | Status: final
# ID: 350156 | Date: 2019-12-21 00:00 | Status: final
# ID: 351205 | Date: 2019-12-30 00:00 | Status: final
# ID: 351721 | Date: 2020-01-01 00:00 | Status: final
# ID: 352540 | Date: 2020-01-02 00:00 | Status: final
# ID: 352620 | Date: 2020-01-03 00:00 | Status: final
# ID: 352641 | Date: 2020-01-03 00:00 | Status: final
# ID: 352806 | Date: 2020-01-05 00:00 | Status: final
# ID: 354032 | Date: 2020-01-13 00:00 | Status: final
# ID: 354164 | Date: 2020-01-14 00:00 | Status: final
# ID: 354170 | Date: 2020-01-14 00:00 | Status: final
# ID: 354211 | Date: 2020-01-14 00:00 | Status: final
# ID: 354227 | Date: 2020-01-14 00:00 | Status: final
# ID: 354242 | Date: 2020-01-14 00:00 | Status: final
# ID: 354246 | Date: 2020-01-14 00:00 | Status: final
# ID: 354342 | Date: 2020-01-15 00:00 | Status: final
# ID: 355388 | Date: 2020-01-21 00:00 | Status: final
# ID: 356909 | Date: 2020-02-01 00:00 | Status: final
# ID: 356916 | Date: 2020-02-01 00:00 | Status: final
# ID: 357926 | Date: 2020-02-05 00:00 | Status: final
# ID: 357967 | Date: 2020-02-05 00:00 | Status: final
# ID: 358725 | Date: 2020-02-08 00:00 | Status: final
# ID: 358901 | Date: 2020-02-09 00:00 | Status: final
# ID: 358931 | Date: 2020-02-09 00:00 | Status: final
# ID: 359017 | Date: 2020-02-09 00:00 | Status: final
# ID: 359079 | Date: 2020-02-09 00:00 | Status: final
# ID: 359130 | Date: 2020-02-09 00:00 | Status: final
# ID: 359170 | Date: 2020-02-10 00:00 | Status: final
# ID: 360014 | Date: 2020-02-16 00:00 | Status: final
# ID: 360051 | Date: 2020-02-16 00:00 | Status: final
# ID: 360053 | Date: 2020-02-16 00:00 | Status: final
# ID: 360198 | Date: 2020-02-17 00:00 | Status: final
# ID: 360208 | Date: 2020-02-17 00:00 | Status: final
# ID: 360217 | Date: 2020-02-17 00:00 | Status: final
# ID: 360308 | Date: 2020-02-17 00:00 | Status: final
# ID: 360669 | Date: 2020-02-19 00:00 | Status: final
# ID: 361102 | Date: 2020-02-22 00:00 | Status: final
# ID: 361124 | Date: 2020-02-22 00:00 | Status: final
# ID: 361134 | Date: 2020-02-22 00:00 | Status: final
# ID: 361224 | Date: 2020-02-22 00:00 | Status: final
# ID: 361236 | Date: 2020-02-22 00:00 | Status: final
# ID: 361244 | Date: 2020-02-22 00:00 | Status: final
# ID: 361973 | Date: 2020-02-25 00:00 | Status: final
# ID: 366217 | Date: 2020-04-15 00:00 | Status: final
# ID: 366899 | Date: 2020-04-22 00:00 | Status: final
# ID: 366940 | Date: 2020-04-23 00:00 | Status: final
# ID: 367366 | Date: 2020-04-28 00:00 | Status: final
# ID: 367379 | Date: 2020-04-28 00:00 | Status: final
# ID: 367384 | Date: 2020-04-28 00:00 | Status: final
# ID: 367392 | Date: 2020-04-28 00:00 | Status: final
# ID: 367393 | Date: 2020-04-28 00:00 | Status: final
# ID: 367413 | Date: 2020-04-28 00:00 | Status: final
# ID: 367417 | Date: 2020-04-28 00:00 | Status: final
# ID: 367457 | Date: 2020-04-29 00:00 | Status: final
# ID: 367609 | Date: 2020-04-30 00:00 | Status: final
# ID: 367695 | Date: 2020-04-30 00:00 | Status: final
# ID: 368207 | Date: 2020-05-05 00:00 | Status: final
# ID: 368379 | Date: 2020-05-07 00:00 | Status: final
# ID: 368411 | Date: 2020-05-07 00:00 | Status: final
# ID: 368420 | Date: 2020-05-07 00:00 | Status: final
# ID: 368424 | Date: 2020-05-07 00:00 | Status: final
# ID: 368429 | Date: 2020-05-07 00:00 | Status: final
# ID: 368440 | Date: 2020-05-07 00:00 | Status: final
# ID: 368460 | Date: 2020-05-07 00:00 | Status: final
# ID: 368463 | Date: 2020-05-07 00:00 | Status: final
# ID: 368471 | Date: 2020-05-07 00:00 | Status: final
# ID: 369124 | Date: 2020-05-10 00:00 | Status: final
# ID: 369194 | Date: 2020-05-10 00:00 | Status: final
# ID: 369255 | Date: 2020-05-10 00:00 | Status: final
# ID: 369421 | Date: 2020-05-11 00:00 | Status: final
# ID: 370011 | Date: 2020-05-16 00:00 | Status: final
# ID: 370846 | Date: 2020-05-21 00:00 | Status: final
# ID: 371100 | Date: 2020-05-22 00:00 | Status: final
# ID: 371110 | Date: 2020-05-22 00:00 | Status: final
# ID: 371147 | Date: 2020-05-23 00:00 | Status: final
# ID: 371168 | Date: 2020-05-23 00:00 | Status: final
# ID: 371178 | Date: 2020-05-23 00:00 | Status: final
# ID: 371181 | Date: 2020-05-23 00:00 | Status: final
# ID: 371490 | Date: 2020-05-27 00:00 | Status: final
# ID: 371525 | Date: 2020-05-27 00:00 | Status: final
# ID: 371690 | Date: 2020-05-29 00:00 | Status: final
# ID: 371732 | Date: 2020-05-29 00:00 | Status: final
# ID: 372043 | Date: 2020-06-01 00:00 | Status: final
# ID: 372165 | Date: 2020-06-01 00:00 | Status: final
# ID: 372441 | Date: 2020-06-03 00:00 | Status: final
# ID: 372509 | Date: 2020-06-03 00:00 | Status: final
# ID: 372736 | Date: 2020-06-04 00:00 | Status: final
# ID: 372762 | Date: 2020-06-04 00:00 | Status: final
# ID: 373163 | Date: 2020-06-07 00:00 | Status: final
# ID: 373201 | Date: 2020-06-07 00:00 | Status: final
# ID: 373244 | Date: 2020-06-07 00:00 | Status: final
# ID: 373300 | Date: 2020-06-07 00:00 | Status: final
# ID: 374275 | Date: 2020-06-12 00:00 | Status: final
# ID: 377103 | Date: 2020-06-21 00:00 | Status: final
# ID: 377127 | Date: 2020-06-21 00:00 | Status: final
# ID: 400213 | Date: 2020-09-21 00:00 | Status: final
# ID: 400370 | Date: 2020-09-21 00:00 | Status: final
# ID: 400372 | Date: 2020-09-21 00:00 | Status: final
# ID: 400408 | Date: 2020-09-21 00:00 | Status: final
# ID: 400451 | Date: 2020-09-21 00:00 | Status: final
# ID: 400455 | Date: 2020-09-21 00:00 | Status: final
# ID: 402577 | Date: 2020-10-02 00:00 | Status: final
# ID: 408191 | Date: 2020-11-01 00:00 | Status: final
# ID: 408217 | Date: 2020-11-01 00:00 | Status: final
# ID: 408349 | Date: 2020-11-02 00:00 | Status: final
# ID: 408371 | Date: 2020-11-02 00:00 | Status: final
# ID: 408379 | Date: 2020-11-02 00:00 | Status: final
# ID: 411272 | Date: 2020-11-19 00:00 | Status: final
# ID: 415735 | Date: 2020-12-14 00:00 | Status: final
# ID: 416611 | Date: 2020-12-23 00:00 | Status: final
# ID: 417659 | Date: 2021-01-01 00:00 | Status: final
# ID: 417750 | Date: 2021-01-01 00:00 | Status: final
# ID: 417989 | Date: 2021-01-01 00:00 | Status: final
# ID: 420871 | Date: 2021-01-12 00:00 | Status: final
# ID: 421766 | Date: 2021-01-15 00:00 | Status: final
# ID: 422542 | Date: 2021-01-19 00:00 | Status: final
# ID: 425690 | Date: 2021-02-02 00:00 | Status: final
# ID: 426067 | Date: 2021-02-03 00:00 | Status: final
# ID: 427326 | Date: 2021-02-07 00:00 | Status: final
# ID: 428790 | Date: 2021-02-17 00:00 | Status: final
# ID: 428814 | Date: 2021-02-18 00:00 | Status: final
# ID: 429277 | Date: 2021-02-20 00:00 | Status: final
# ID: 430189 | Date: 2021-02-28 00:00 | Status: final
# ID: 430211 | Date: 2021-02-28 00:00 | Status: final
# ID: 430223 | Date: 2021-02-28 00:00 | Status: final
# ID: 431326 | Date: 2021-03-15 00:00 | Status: final
# ID: 431402 | Date: 2021-03-16 00:00 | Status: final
# ID: 431946 | Date: 2021-03-24 00:00 | Status: final
# ID: 432169 | Date: 2021-03-26 00:00 | Status: final
# ID: 432406 | Date: 2021-03-29 00:00 | Status: final
# ID: 432689 | Date: 2021-04-01 00:00 | Status: final
# ID: 433225 | Date: 2021-04-06 00:00 | Status: final
# ID: 433227 | Date: 2021-04-06 00:00 | Status: final
# ID: 433269 | Date: 2021-04-06 00:00 | Status: final
# ID: 433310 | Date: 2021-04-07 00:00 | Status: final
# ID: 433488 | Date: 2021-04-09 00:00 | Status: final
# ID: 433621 | Date: 2021-04-11 00:00 | Status: final
# ID: 435329 | Date: 2021-05-06 00:00 | Status: final
# ID: 437409 | Date: 2021-05-19 00:00 | Status: final
# ID: 437454 | Date: 2021-05-19 00:00 | Status: final
# ID: 441129 | Date: 2021-06-12 00:00 | Status: final
# ID: 441158 | Date: 2021-06-12 00:00 | Status: final
# ID: 441196 | Date: 2021-06-12 00:00 | Status: final
# ID: 441256 | Date: 2021-06-13 00:00 | Status: final
# ID: 445906 | Date: 2021-06-30 00:00 | Status: final
# ID: 463450 | Date: 2021-08-24 00:00 | Status: final
# ID: 470064 | Date: 2021-09-13 00:00 | Status: final
# ID: 479902 | Date: 2021-10-28 00:00 | Status: final
# ID: 480297 | Date: 2021-10-31 00:00 | Status: final
# ID: 485772 | Date: 2021-11-23 00:00 | Status: final
# ID: 490292 | Date: 2021-12-11 00:00 | Status: final
# ID: 490622 | Date: 2021-12-12 00:00 | Status: final
# ID: 491114 | Date: 2021-12-16 00:00 | Status: final
# ID: 491655 | Date: 2021-12-18 00:00 | Status: final
# ID: 491669 | Date: 2021-12-18 00:00 | Status: final
# ID: 491670 | Date: 2021-12-18 00:00 | Status: final
# ID: 491686 | Date: 2021-12-18 00:00 | Status: final
# ID: 491691 | Date: 2021-12-18 00:00 | Status: final
# ID: 491715 | Date: 2021-12-18 00:00 | Status: final
# ID: 491720 | Date: 2021-12-18 00:00 | Status: final
# ID: 491742 | Date: 2021-12-18 00:00 | Status: final
# ID: 491744 | Date: 2021-12-18 00:00 | Status: final
# ID: 491747 | Date: 2021-12-18 00:00 | Status: final
# ID: 491750 | Date: 2021-12-18 00:00 | Status: final
# ID: 491755 | Date: 2021-12-18 00:00 | Status: final
# ID: 491799 | Date: 2021-12-18 00:00 | Status: final
# ID: 491841 | Date: 2021-12-19 00:00 | Status: final
# ID: 491864 | Date: 2021-12-19 00:00 | Status: final
# ID: 491948 | Date: 2021-12-20 00:00 | Status: final
# ID: 491995 | Date: 2021-12-20 00:00 | Status: final
# ID: 491997 | Date: 2021-12-20 00:00 | Status: final
# ID: 492001 | Date: 2021-12-20 00:00 | Status: final
# ID: 492857 | Date: 2021-12-27 00:00 | Status: final
# ID: 493037 | Date: 2021-12-28 00:00 | Status: final
# ID: 493806 | Date: 2022-01-01 00:00 | Status: final
# ID: 494187 | Date: 2022-01-01 00:00 | Status: final
# ID: 494341 | Date: 2022-01-01 00:00 | Status: final
# ID: 494611 | Date: 2022-01-03 00:00 | Status: final
# ID: 494693 | Date: 2022-01-03 00:00 | Status: final
# ID: 494699 | Date: 2022-01-03 00:00 | Status: final
# ID: 494821 | Date: 2022-01-04 00:00 | Status: final
# ID: 494832 | Date: 2022-01-04 00:00 | Status: final
# ID: 494833 | Date: 2022-01-04 00:00 | Status: final
# ID: 494835 | Date: 2022-01-04 00:00 | Status: final
# ID: 494840 | Date: 2022-01-04 00:00 | Status: final
# ID: 494860 | Date: 2022-01-04 00:00 | Status: final
# ID: 494877 | Date: 2022-01-04 00:00 | Status: final
# ID: 494878 | Date: 2022-01-04 00:00 | Status: final
# ID: 494882 | Date: 2022-01-04 00:00 | Status: final
# ID: 494905 | Date: 2022-01-04 00:00 | Status: final
# ID: 494907 | Date: 2022-01-04 00:00 | Status: final
# ID: 494915 | Date: 2022-01-04 00:00 | Status: final
# ID: 494924 | Date: 2022-01-04 00:00 | Status: final
# ID: 494929 | Date: 2022-01-04 00:00 | Status: final
# ID: 494985 | Date: 2022-01-04 00:00 | Status: final
# ID: 495006 | Date: 2022-01-04 00:00 | Status: final
# ID: 495041 | Date: 2022-01-04 00:00 | Status: final
# ID: 495049 | Date: 2022-01-04 00:00 | Status: final
# ID: 495058 | Date: 2022-01-04 00:00 | Status: final
# ID: 495073 | Date: 2022-01-04 00:00 | Status: final
# ID: 495078 | Date: 2022-01-05 00:00 | Status: final
# ID: 495087 | Date: 2022-01-05 00:00 | Status: final
# ID: 495091 | Date: 2022-01-05 00:00 | Status: final
# ID: 495095 | Date: 2022-01-05 00:00 | Status: final
# ID: 495101 | Date: 2022-01-05 00:00 | Status: final
# ID: 495109 | Date: 2022-01-05 00:00 | Status: final
# ID: 495119 | Date: 2022-01-05 00:00 | Status: final
# ID: 495125 | Date: 2022-01-05 00:00 | Status: final
# ID: 495141 | Date: 2022-01-05 00:00 | Status: final
# ID: 495144 | Date: 2022-01-05 00:00 | Status: final
# ID: 495148 | Date: 2022-01-05 00:00 | Status: final
# ID: 495149 | Date: 2022-01-05 00:00 | Status: final
# ID: 495152 | Date: 2022-01-05 00:00 | Status: final
# ID: 495156 | Date: 2022-01-05 00:00 | Status: final
# ID: 495158 | Date: 2022-01-05 00:00 | Status: final
# ID: 495172 | Date: 2022-01-05 00:00 | Status: final
# ID: 495173 | Date: 2022-01-05 00:00 | Status: final
# ID: 495179 | Date: 2022-01-05 00:00 | Status: final
# ID: 495185 | Date: 2022-01-05 00:00 | Status: final
# ID: 495189 | Date: 2022-01-05 00:00 | Status: final
# ID: 495204 | Date: 2022-01-05 00:00 | Status: final
# ID: 495214 | Date: 2022-01-06 00:00 | Status: final
# ID: 495228 | Date: 2022-01-06 00:00 | Status: final
# ID: 495249 | Date: 2022-01-06 00:00 | Status: final
# ID: 495253 | Date: 2022-01-06 00:00 | Status: final
# ID: 495254 | Date: 2022-01-06 00:00 | Status: final
# ID: 495293 | Date: 2022-01-06 00:00 | Status: final
# ID: 495319 | Date: 2022-01-06 00:00 | Status: final
# ID: 495327 | Date: 2022-01-06 00:00 | Status: final
# ID: 495336 | Date: 2022-01-06 00:00 | Status: final
# ID: 495340 | Date: 2022-01-06 00:00 | Status: final
# ID: 495350 | Date: 2022-01-06 00:00 | Status: final
# ID: 495361 | Date: 2022-01-06 00:00 | Status: final
# ID: 495373 | Date: 2022-01-07 00:00 | Status: final
# ID: 495374 | Date: 2022-01-07 00:00 | Status: final
# ID: 495384 | Date: 2022-01-07 00:00 | Status: final
# ID: 495393 | Date: 2022-01-07 00:00 | Status: final
# ID: 495399 | Date: 2022-01-07 00:00 | Status: final
# ID: 495405 | Date: 2022-01-07 00:00 | Status: final
# ID: 495462 | Date: 2022-01-07 00:00 | Status: final
# ID: 495469 | Date: 2022-01-07 00:00 | Status: final
# ID: 495476 | Date: 2022-01-07 00:00 | Status: final
# ID: 495482 | Date: 2022-01-07 00:00 | Status: final
# ID: 495493 | Date: 2022-01-07 00:00 | Status: final
# ID: 495502 | Date: 2022-01-07 00:00 | Status: final
# ID: 495510 | Date: 2022-01-07 00:00 | Status: final
# ID: 495512 | Date: 2022-01-07 00:00 | Status: final
# ID: 495517 | Date: 2022-01-07 00:00 | Status: final
# ID: 495532 | Date: 2022-01-07 00:00 | Status: final
# ID: 495533 | Date: 2022-01-07 00:00 | Status: final
# ID: 495547 | Date: 2022-01-07 00:00 | Status: final
# ID: 495552 | Date: 2022-01-07 00:00 | Status: final
# ID: 495562 | Date: 2022-01-07 00:00 | Status: final
# ID: 495569 | Date: 2022-01-07 00:00 | Status: final
# ID: 495596 | Date: 2022-01-08 00:00 | Status: final
# ID: 495616 | Date: 2022-01-08 00:00 | Status: final
# ID: 495633 | Date: 2022-01-08 00:00 | Status: final
# ID: 495634 | Date: 2022-01-08 00:00 | Status: final
# ID: 495639 | Date: 2022-01-08 00:00 | Status: final
# ID: 495641 | Date: 2022-01-08 00:00 | Status: final
# ID: 495645 | Date: 2022-01-08 00:00 | Status: final
# ID: 495648 | Date: 2022-01-08 00:00 | Status: final
# ID: 495671 | Date: 2022-01-08 00:00 | Status: final
# ID: 495674 | Date: 2022-01-08 00:00 | Status: final
# ID: 495683 | Date: 2022-01-08 00:00 | Status: final
# ID: 495700 | Date: 2022-01-08 00:00 | Status: final
# ID: 495714 | Date: 2022-01-08 00:00 | Status: final
# ID: 495725 | Date: 2022-01-08 00:00 | Status: final
# ID: 495726 | Date: 2022-01-08 00:00 | Status: final
# ID: 495727 | Date: 2022-01-08 00:00 | Status: final
# ID: 495754 | Date: 2022-01-08 00:00 | Status: final
# ID: 495756 | Date: 2022-01-08 00:00 | Status: final
# ID: 495758 | Date: 2022-01-08 00:00 | Status: final
# ID: 495782 | Date: 2022-01-08 00:00 | Status: final
# ID: 495792 | Date: 2022-01-08 00:00 | Status: final
# ID: 495794 | Date: 2022-01-08 00:00 | Status: final
# ID: 495796 | Date: 2022-01-08 00:00 | Status: final
# ID: 495820 | Date: 2022-01-08 00:00 | Status: final
# ID: 495831 | Date: 2022-01-08 00:00 | Status: final
# ID: 495836 | Date: 2022-01-08 00:00 | Status: final
# ID: 495838 | Date: 2022-01-09 00:00 | Status: final
# ID: 495841 | Date: 2022-01-09 00:00 | Status: final
# ID: 495849 | Date: 2022-01-09 00:00 | Status: final
# ID: 495850 | Date: 2022-01-09 00:00 | Status: final
# ID: 495851 | Date: 2022-01-09 00:00 | Status: final
# ID: 495853 | Date: 2022-01-09 00:00 | Status: final
# ID: 495855 | Date: 2022-01-09 00:00 | Status: final
# ID: 495863 | Date: 2022-01-09 00:00 | Status: final
# ID: 495866 | Date: 2022-01-09 00:00 | Status: final
# ID: 495884 | Date: 2022-01-09 00:00 | Status: final
# ID: 495887 | Date: 2022-01-09 00:00 | Status: final
# ID: 495891 | Date: 2022-01-09 00:00 | Status: final
# ID: 495897 | Date: 2022-01-09 00:00 | Status: final
# ID: 495911 | Date: 2022-01-09 00:00 | Status: final
# ...
# ID: 752508 | Date: 2024-09-21 00:00 | Status: error
# ID: 752509 | Date: 2024-09-21 00:00 | Status: error
# ID: 752510 | Date: 2024-09-21 00:00 | Status: error
# ID: 752511 | Date: 2024-09-21 00:00 | Status: error
# ID: 752512 | Date: 2024-09-21 00:00 | Status: error
# ID: 752513 | Date: 2024-09-21 00:00 | Status: error
# ID: 752514 | Date: 2024-09-21 00:00 | Status: error
# ID: 752515 | Date: 2024-09-21 00:00 | Status: error
# ID: 752516 | Date: 2024-09-21 00:00 | Status: error
# ID: 752517 | Date: 2024-09-21 00:00 | Status: error
# ID: 752518 | Date: 2024-09-21 00:00 | Status: error
# ID: 752519 | Date: 2024-09-21 00:00 | Status: error
# ID: 752520 | Date: 2024-09-21 00:00 | Status: error
# ID: 752521 | Date: 2024-09-21 00:00 | Status: error
# ID: 752522 | Date: 2024-09-21 00:00 | Status: error
# ID: 752523 | Date: 2024-09-21 00:00 | Status: error
# ID: 752524 | Date: 2024-09-21 00:00 | Status: error
# ID: 752525 | Date: 2024-09-21 00:00 | Status: error
# ID: 752526 | Date: 2024-09-21 00:00 | Status: error
# ID: 752527 | Date: 2024-09-21 00:00 | Status: error
# ID: 752528 | Date: 2024-09-21 00:00 | Status: error
# ID: 752529 | Date: 2024-09-21 00:00 | Status: error
# ID: 752530 | Date: 2024-09-21 00:00 | Status: error
# ID: 752531 | Date: 2024-09-21 00:00 | Status: error
# ID: 752532 | Date: 2024-09-21 00:00 | Status: error
# ID: 752533 | Date: 2024-09-21 00:00 | Status: error
# ID: 752534 | Date: 2024-09-21 00:00 | Status: error
# ID: 752535 | Date: 2024-09-21 00:00 | Status: error
# ID: 752536 | Date: 2024-09-21 00:00 | Status: error
# ID: 752537 | Date: 2024-09-21 00:00 | Status: error
# ID: 752538 | Date: 2024-09-21 00:00 | Status: error
# ID: 752539 | Date: 2024-09-21 00:00 | Status: error
# ID: 752540 | Date: 2024-09-21 00:00 | Status: error
# ID: 752541 | Date: 2024-09-21 00:00 | Status: error
# ID: 752542 | Date: 2024-09-21 00:00 | Status: error
# ID: 752543 | Date: 2024-09-21 00:00 | Status: error
# ID: 752544 | Date: 2024-09-21 00:00 | Status: error
# ID: 752545 | Date: 2024-09-21 00:00 | Status: error
# ID: 752546 | Date: 2024-09-21 00:00 | Status: error
# ID: 752547 | Date: 2024-09-21 00:00 | Status: error
# ID: 752548 | Date: 2024-09-21 00:00 | Status: error
# ID: 752549 | Date: 2024-09-21 00:00 | Status: error
# ID: 752550 | Date: 2024-09-21 00:00 | Status: error
# ID: 752551 | Date: 2024-09-21 00:00 | Status: error
# ID: 752552 | Date: 2024-09-21 00:00 | Status: error
# ID: 752553 | Date: 2024-09-21 00:00 | Status: error
# ID: 752554 | Date: 2024-09-21 00:00 | Status: error
# ID: 752555 | Date: 2024-09-21 00:00 | Status: error
# ID: 752556 | Date: 2024-09-21 00:00 | Status: error
# ID: 752557 | Date: 2024-09-21 00:00 | Status: error
# ID: 752558 | Date: 2024-09-21 00:00 | Status: error
# ID: 752559 | Date: 2024-09-21 00:00 | Status: error
# ID: 752560 | Date: 2024-09-21 00:00 | Status: error
# ID: 752561 | Date: 2024-09-21 00:00 | Status: error
# ID: 752562 | Date: 2024-09-21 00:00 | Status: error
# ID: 752563 | Date: 2024-09-21 00:00 | Status: error
# ID: 752564 | Date: 2024-09-21 00:00 | Status: error
# ID: 752565 | Date: 2024-09-21 00:00 | Status: error
# ID: 752566 | Date: 2024-09-21 00:00 | Status: error
# ID: 752567 | Date: 2024-09-21 00:00 | Status: error
# ID: 752568 | Date: 2024-09-21 00:00 | Status: error
# ID: 752569 | Date: 2024-09-21 00:00 | Status: error
# ID: 752570 | Date: 2024-09-21 00:00 | Status: error
# ID: 752571 | Date: 2024-09-21 00:00 | Status: error
# ID: 752572 | Date: 2024-09-21 00:00 | Status: error
# ID: 752573 | Date: 2024-09-21 00:00 | Status: error
# ID: 752574 | Date: 2024-09-21 00:00 | Status: error
# ID: 752575 | Date: 2024-09-21 00:00 | Status: error
# ID: 752576 | Date: 2024-09-21 00:00 | Status: error
# ID: 752577 | Date: 2024-09-21 00:00 | Status: error
# ID: 752578 | Date: 2024-09-21 00:00 | Status: error
# ID: 752579 | Date: 2024-09-21 00:00 | Status: error
# ID: 752580 | Date: 2024-09-21 00:00 | Status: error
# ID: 752581 | Date: 2024-09-21 00:00 | Status: error
# ID: 752582 | Date: 2024-09-21 00:00 | Status: error
# ID: 752583 | Date: 2024-09-21 00:00 | Status: error
# ID: 752584 | Date: 2024-09-21 00:00 | Status: error
# ID: 752585 | Date: 2024-09-21 00:00 | Status: error
# ID: 752586 | Date: 2024-09-21 00:00 | Status: error
# ID: 752587 | Date: 2024-09-21 00:00 | Status: error
# ID: 752588 | Date: 2024-09-21 00:00 | Status: error
# ID: 752589 | Date: 2024-09-21 00:00 | Status: error
# ID: 752590 | Date: 2024-09-21 00:00 | Status: error
# ID: 752591 | Date: 2024-09-21 00:00 | Status: error
# ID: 752592 | Date: 2024-09-21 00:00 | Status: error
# ID: 752593 | Date: 2024-09-21 00:00 | Status: error
# ID: 752594 | Date: 2024-09-21 00:00 | Status: error
# ID: 752595 | Date: 2024-09-21 00:00 | Status: error
# ID: 752596 | Date: 2024-09-21 00:00 | Status: error
# ID: 752597 | Date: 2024-09-21 00:00 | Status: error
# ID: 752598 | Date: 2024-09-21 00:00 | Status: error
# ID: 752599 | Date: 2024-09-21 00:00 | Status: error
# ID: 752600 | Date: 2024-09-21 00:00 | Status: error
# ID: 752601 | Date: 2024-09-21 00:00 | Status: error
# ID: 752602 | Date: 2024-09-21 00:00 | Status: error
# ID: 752603 | Date: 2024-09-21 00:00 | Status: error
# ID: 752604 | Date: 2024-09-21 00:00 | Status: error
# ID: 752605 | Date: 2024-09-21 00:00 | Status: error
# ID: 752606 | Date: 2024-09-21 00:00 | Status: error
# ID: 752607 | Date: 2024-09-21 00:00 | Status: error
# ID: 752608 | Date: 2024-09-21 00:00 | Status: error
# ID: 752609 | Date: 2024-09-21 00:00 | Status: error
# ID: 752610 | Date: 2024-09-21 00:00 | Status: error
# ID: 752611 | Date: 2024-09-21 00:00 | Status: error
# ID: 752612 | Date: 2024-09-21 00:00 | Status: error
# ID: 752613 | Date: 2024-09-21 00:00 | Status: error
# ID: 752614 | Date: 2024-09-21 00:00 | Status: error
# ID: 752615 | Date: 2024-09-21 00:00 | Status: error
# ID: 752616 | Date: 2024-09-21 00:00 | Status: error
# ID: 752617 | Date: 2024-09-21 00:00 | Status: error
# ID: 752618 | Date: 2024-09-21 00:00 | Status: error
# ID: 752619 | Date: 2024-09-21 00:00 | Status: error
# ID: 752620 | Date: 2024-09-21 00:00 | Status: error
# ID: 752621 | Date: 2024-09-21 00:00 | Status: error
# ID: 752622 | Date: 2024-09-21 00:00 | Status: error
# ID: 752623 | Date: 2024-09-21 00:00 | Status: error
# ID: 752624 | Date: 2024-09-21 00:00 | Status: error
# ID: 752625 | Date: 2024-09-21 00:00 | Status: error
# ID: 752626 | Date: 2024-09-21 00:00 | Status: error
# ID: 752627 | Date: 2024-09-21 00:00 | Status: error
# ID: 752628 | Date: 2024-09-21 00:00 | Status: error
# ID: 752629 | Date: 2024-09-21 00:00 | Status: error
# ID: 752630 | Date: 2024-09-21 00:00 | Status: error
# ID: 752631 | Date: 2024-09-21 00:00 | Status: error
# ID: 752632 | Date: 2024-09-21 00:00 | Status: error
# ID: 752633 | Date: 2024-09-21 00:00 | Status: error
# ID: 752634 | Date: 2024-09-21 00:00 | Status: error
# ID: 752635 | Date: 2024-09-21 00:00 | Status: error
# ID: 752636 | Date: 2024-09-21 00:00 | Status: error
# ID: 752637 | Date: 2024-09-21 00:00 | Status: error
# ID: 752638 | Date: 2024-09-21 00:00 | Status: error
# ID: 752639 | Date: 2024-09-21 00:00 | Status: error
# ID: 752640 | Date: 2024-09-21 00:00 | Status: error
# ID: 752641 | Date: 2024-09-21 00:00 | Status: error
# ID: 752642 | Date: 2024-09-21 00:00 | Status: error
# ID: 752643 | Date: 2024-09-21 00:00 | Status: error
# ID: 752644 | Date: 2024-09-21 00:00 | Status: error
# ID: 752645 | Date: 2024-09-21 00:00 | Status: error
# ID: 752646 | Date: 2024-09-21 00:00 | Status: error
# ID: 752647 | Date: 2024-09-21 00:00 | Status: error
# ID: 752648 | Date: 2024-09-21 00:00 | Status: error
# ID: 752649 | Date: 2024-09-21 00:00 | Status: error
# ID: 752650 | Date: 2024-09-21 00:00 | Status: error
# ID: 752651 | Date: 2024-09-21 00:00 | Status: error
# ID: 752652 | Date: 2024-09-21 00:00 | Status: error
# ID: 752653 | Date: 2024-09-21 00:00 | Status: error
# ID: 752654 | Date: 2024-09-21 00:00 | Status: error
# ID: 752655 | Date: 2024-09-21 00:00 | Status: error
# ID: 752656 | Date: 2024-09-21 00:00 | Status: error
# ID: 752657 | Date: 2024-09-21 00:00 | Status: error
# ID: 752658 | Date: 2024-09-21 00:00 | Status: error
# ID: 752659 | Date: 2024-09-21 00:00 | Status: error
# ID: 752660 | Date: 2024-09-21 00:00 | Status: error
# ID: 752661 | Date: 2024-09-21 00:00 | Status: error
# ID: 752662 | Date: 2024-09-21 00:00 | Status: error
# ID: 752663 | Date: 2024-09-21 00:00 | Status: error
# ID: 752664 | Date: 2024-09-21 00:00 | Status: error
# ID: 752665 | Date: 2024-09-21 00:00 | Status: error
# ID: 752666 | Date: 2024-09-21 00:00 | Status: error
# ID: 752667 | Date: 2024-09-21 00:00 | Status: error
# ID: 752668 | Date: 2024-09-21 00:00 | Status: error
# ID: 752669 | Date: 2024-09-21 00:00 | Status: error
# ID: 752670 | Date: 2024-09-21 00:00 | Status: error
# ID: 752671 | Date: 2024-09-21 00:00 | Status: error
# ID: 752672 | Date: 2024-09-21 00:00 | Status: error
# ID: 752673 | Date: 2024-09-21 00:00 | Status: error
# ID: 752674 | Date: 2024-09-21 00:00 | Status: error
# ID: 752675 | Date: 2024-09-21 00:00 | Status: error
# ID: 752676 | Date: 2024-09-21 00:00 | Status: error
# ID: 752677 | Date: 2024-09-21 00:00 | Status: error
# ID: 752678 | Date: 2024-09-21 00:00 | Status: error
# ID: 752679 | Date: 2024-09-21 00:00 | Status: error
# ID: 752680 | Date: 2024-09-21 00:00 | Status: error
# ID: 752681 | Date: 2024-09-21 00:00 | Status: error
# ID: 752682 | Date: 2024-09-21 00:00 | Status: error
# ID: 752683 | Date: 2024-09-21 00:00 | Status: error
# ID: 752684 | Date: 2024-09-21 00:00 | Status: error
# ID: 752685 | Date: 2024-09-21 00:00 | Status: error
# ID: 752686 | Date: 2024-09-21 00:00 | Status: error
# ID: 752687 | Date: 2024-09-21 00:00 | Status: error
# ID: 752688 | Date: 2024-09-21 00:00 | Status: error
# ID: 752689 | Date: 2024-09-21 00:00 | Status: error
# ID: 752690 | Date: 2024-09-21 00:00 | Status: error
# ID: 752691 | Date: 2024-09-21 00:00 | Status: error
# ID: 752692 | Date: 2024-09-21 00:00 | Status: error
# ID: 752693 | Date: 2024-09-21 00:00 | Status: error
# ID: 752694 | Date: 2024-09-21 00:00 | Status: error
# ID: 752695 | Date: 2024-09-21 00:00 | Status: error
# ID: 752696 | Date: 2024-09-21 00:00 | Status: error
# ID: 752697 | Date: 2024-09-21 00:00 | Status: error
# ID: 752698 | Date: 2024-09-21 00:00 | Status: error
# ID: 752699 | Date: 2024-09-21 00:00 | Status: error
# ID: 752700 | Date: 2024-09-21 00:00 | Status: error
# ID: 752701 | Date: 2024-09-21 00:00 | Status: error
# ID: 752702 | Date: 2024-09-21 00:00 | Status: error
# ID: 752703 | Date: 2024-09-21 00:00 | Status: error
# ID: 752704 | Date: 2024-09-21 00:00 | Status: error
# ID: 752705 | Date: 2024-09-21 00:00 | Status: error
# ID: 752706 | Date: 2024-09-21 00:00 | Status: error
# ID: 752707 | Date: 2024-09-21 00:00 | Status: error
# ID: 752708 | Date: 2024-09-21 00:00 | Status: error
# ID: 752709 | Date: 2024-09-21 00:00 | Status: error
# ID: 752710 | Date: 2024-09-21 00:00 | Status: error
# ID: 752711 | Date: 2024-09-21 00:00 | Status: error
# ID: 752712 | Date: 2024-09-21 00:00 | Status: error
# ID: 752713 | Date: 2024-09-21 00:00 | Status: error
# ID: 752714 | Date: 2024-09-21 00:00 | Status: error
# ID: 752715 | Date: 2024-09-21 00:00 | Status: error
# ID: 752716 | Date: 2024-09-21 00:00 | Status: error
# ID: 752717 | Date: 2024-09-21 00:00 | Status: error
# ID: 752718 | Date: 2024-09-21 00:00 | Status: error
# ID: 752719 | Date: 2024-09-21 00:00 | Status: error
# ID: 752720 | Date: 2024-09-21 00:00 | Status: error
# ID: 752721 | Date: 2024-09-21 00:00 | Status: error
# ID: 752722 | Date: 2024-09-21 00:00 | Status: error
# ID: 752723 | Date: 2024-09-21 00:00 | Status: error
# ID: 752724 | Date: 2024-09-21 00:00 | Status: error
# ID: 752725 | Date: 2024-09-21 00:00 | Status: error
# ID: 752726 | Date: 2024-09-21 00:00 | Status: error
# ID: 752727 | Date: 2024-09-21 00:00 | Status: error
# ID: 752728 | Date: 2024-09-21 00:00 | Status: error
# ID: 752729 | Date: 2024-09-21 00:00 | Status: error
# ID: 752730 | Date: 2024-09-21 00:00 | Status: error
# ID: 752731 | Date: 2024-09-21 00:00 | Status: error
# ID: 752732 | Date: 2024-09-21 00:00 | Status: error
# ID: 752733 | Date: 2024-09-21 00:00 | Status: error
# ID: 752734 | Date: 2024-09-21 00:00 | Status: error
# ID: 752735 | Date: 2024-09-21 00:00 | Status: error
# ID: 752736 | Date: 2024-09-21 00:00 | Status: error
# ID: 752737 | Date: 2024-09-21 00:00 | Status: error
# ID: 752738 | Date: 2024-09-21 00:00 | Status: error
# ID: 752739 | Date: 2024-09-21 00:00 | Status: error
# ID: 752740 | Date: 2024-09-21 00:00 | Status: error
# ID: 752741 | Date: 2024-09-21 00:00 | Status: error
# ID: 752742 | Date: 2024-09-21 00:00 | Status: error
# ID: 752743 | Date: 2024-09-21 00:00 | Status: error
# ID: 752744 | Date: 2024-09-21 00:00 | Status: error
# ID: 752745 | Date: 2024-09-21 00:00 | Status: error
# ID: 752746 | Date: 2024-09-21 00:00 | Status: error
# ID: 752747 | Date: 2024-09-21 00:00 | Status: error
# ID: 752748 | Date: 2024-09-21 00:00 | Status: error
# ID: 752749 | Date: 2024-09-21 00:00 | Status: error
# ID: 752750 | Date: 2024-09-21 00:00 | Status: error
# ID: 752751 | Date: 2024-09-21 00:00 | Status: error
# ID: 752752 | Date: 2024-09-21 00:00 | Status: error
# ID: 752753 | Date: 2024-09-21 00:00 | Status: error
# ID: 752754 | Date: 2024-09-21 00:00 | Status: error
# ID: 752755 | Date: 2024-09-21 00:00 | Status: error
# ID: 752756 | Date: 2024-09-21 00:00 | Status: error
# ID: 752757 | Date: 2024-09-21 00:00 | Status: error
# ID: 752758 | Date: 2024-09-21 00:00 | Status: error
# ID: 752759 | Date: 2024-09-21 00:00 | Status: error
# ID: 752760 | Date: 2024-09-21 00:00 | Status: error
# ID: 752761 | Date: 2024-09-21 00:00 | Status: error
# ID: 752762 | Date: 2024-09-21 00:00 | Status: error
# ID: 752763 | Date: 2024-09-21 00:00 | Status: error
# ID: 752764 | Date: 2024-09-21 00:00 | Status: error
# ID: 752765 | Date: 2024-09-21 00:00 | Status: error
# ID: 752766 | Date: 2024-09-21 00:00 | Status: error
# ID: 752767 | Date: 2024-09-21 00:00 | Status: error
# ID: 752768 | Date: 2024-09-21 00:00 | Status: error
# ID: 752769 | Date: 2024-09-21 00:00 | Status: error
# ID: 752770 | Date: 2024-09-21 00:00 | Status: error
# ID: 752771 | Date: 2024-09-21 00:00 | Status: error
# ID: 752772 | Date: 2024-09-21 00:00 | Status: error
# ID: 752773 | Date: 2024-09-21 00:00 | Status: error
# ID: 752774 | Date: 2024-09-21 00:00 | Status: error
# ID: 752775 | Date: 2024-09-21 00:00 | Status: error
# ID: 752776 | Date: 2024-09-21 00:00 | Status: error
# ID: 752777 | Date: 2024-09-21 00:00 | Status: error
# ID: 752778 | Date: 2024-09-21 00:00 | Status: error
# ID: 752779 | Date: 2024-09-21 00:00 | Status: error
# ID: 752780 | Date: 2024-09-21 00:00 | Status: error
# ID: 752781 | Date: 2024-09-21 00:00 | Status: error
# ID: 752782 | Date: 2024-09-21 00:00 | Status: error
# ID: 752783 | Date: 2024-09-21 00:00 | Status: error
# ID: 752784 | Date: 2024-09-21 00:00 | Status: error
# ID: 752785 | Date: 2024-09-21 00:00 | Status: error
# ID: 752786 | Date: 2024-09-21 00:00 | Status: error
# ID: 752787 | Date: 2024-09-21 00:00 | Status: error
# ID: 752788 | Date: 2024-09-21 00:00 | Status: error
# ID: 752789 | Date: 2024-09-21 00:00 | Status: error
# ID: 752790 | Date: 2024-09-21 00:00 | Status: error
# ID: 752791 | Date: 2024-09-21 00:00 | Status: error
# ID: 752792 | Date: 2024-09-21 00:00 | Status: error
# ID: 752793 | Date: 2024-09-21 00:00 | Status: error
# ID: 752794 | Date: 2024-09-21 00:00 | Status: error
# ID: 752795 | Date: 2024-09-21 00:00 | Status: error
# ID: 752796 | Date: 2024-09-21 00:00 | Status: error
# ID: 752797 | Date: 2024-09-21 00:00 | Status: error
# ID: 752798 | Date: 2024-09-21 00:00 | Status: error
# ID: 752799 | Date: 2024-09-21 00:00 | Status: error
# ID: 752800 | Date: 2024-09-21 00:00 | Status: error
# ID: 752801 | Date: 2024-09-21 00:00 | Status: error
# ID: 752802 | Date: 2024-09-21 00:00 | Status: error
# ID: 752803 | Date: 2024-09-21 00:00 | Status: error
# ID: 752804 | Date: 2024-09-21 00:00 | Status: error
# ID: 752805 | Date: 2024-09-21 00:00 | Status: error
# ID: 752806 | Date: 2024-09-21 00:00 | Status: error
# ID: 752807 | Date: 2024-09-21 00:00 | Status: error
# ID: 752808 | Date: 2024-09-21 00:00 | Status: error
# ------------------------------
# --- Cleaned. Remaining events: 700912 ---
#
# SUCCESS! Final dataset saved to: D:\Development\RESEARCH\urban_flood_database\chronicle\imerg_rain_outputs\chronicle_urban_df_with_IMERG_FULL.pkl
#
# --- IMERG Data Quality Summary ---
#  - FINAL: 700912 events
# Total verified valid Rain Data events: 700912

# %%
# Check the distribution of IMERG data quality
print(df_final['imerg_type'].value_counts())
# Out:
# final    700912
# Name: imerg_type, dtype: int64

# %% [markdown]
# # HERE SHOULD BE COMPLEMENTERY CODE:
# הקוד צריך לעבור שוב על כל האירועים שהוסרו מהבאצים כי לא היה בהם דאטא.
# הוא יבחן שוב אם יש את הדאטא שלהם בגרסה הטובה ביותר ואם לא אז בגרסה השנייה הפחות טובה.
# הרעיון - לודא שלא נפלו האירועים בגלל מגבלות גישה ועומס על הענן של גוגל בשלב ראשון, ואם לא זה אז האם יש בעיה בזמינות הנתונים עצמם בגרסה המירבית ואז זה יגש לגרסה הפחות טובה.
#
#
# המלצת הגימיני:
#
# # --- COMPLEMENTARY CLEANUP STEP ---
# print("\n--- RUNNING COMPLEMENTARY RECOVERY ---")
#
# # Load the reference (all events) and the current results
# df_base = pd.read_pickle(INPUT_PKL)
# df_final = pd.read_pickle(OUT_FINAL_PKL)
#
# # Find IDs that are in base but NOT in final
# missing_mask = ~df_base['event_id'].isin(df_final['event_id'])
# df_missing = df_base[missing_mask].copy()
#
# print(f"Status check: {len(df_missing)} events are currently missing from the final PKL.")
#
# if len(df_missing) > 0:
#     print(f"Attempting to recover {len(df_missing)} events...")
#     recovered_list = []
#
#     # Try one last time for each missing event
#     for idx, row in tqdm(df_missing.iterrows(), total=len(df_missing), desc="Recovery"):
#         # This will use the Fallback logic (Final -> Late)
#         mat, msk, mt, itype = extract_rain_data(row)
#
#         # Only keep if we actually found data this time
#         if mat is not None:
#             recovered_row = row.to_dict()
#             recovered_row.update({
#                 'imerg_matrix': mat,
#                 'imerg_mask': msk,
#                 'imerg_meta': mt,
#                 'imerg_type': itype
#             })
#             recovered_list.append(recovered_row)
#
#     if recovered_list:
#         df_recovered = pd.DataFrame(recovered_list)
#         # Combine the old final results with the newly recovered ones
#         df_updated = pd.concat([df_final, df_recovered], ignore_index=True)
#
#         # Final save
#         df_updated.to_pickle(OUT_FINAL_PKL)
#         print(f"Recovery successful! Added {len(recovered_list)} events.")
#         print(f"Final count: {len(df_updated)} events.")
#     else:
#         print("No additional data could be recovered (all remaining events likely out of range or truly empty).")

# %%
df_final

# %% [markdown]
# # לעדכן לגרסה V07 של imerg

# %%
700912

# %%
print(ee.ImageCollection("NASA/GPM_L3/IMERG_V06").limit(1, "system:time_start", False).first().date().format().getInfo())
# Out:
# 2024-06-02T18:30:00

# %%
print(ee.ImageCollection("NASA/GPM_L3/IMERG_V07").limit(1, "system:time_start", False).first().date().format().getInfo())
# Out:
# 2026-02-14T03:30:00
