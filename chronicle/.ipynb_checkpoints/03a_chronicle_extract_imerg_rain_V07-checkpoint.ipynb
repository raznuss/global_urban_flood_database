# %%
# ============================================
# 0) IMPORTS
# ============================================
import os
import glob
import pandas as pd
import numpy as np
import shapely.wkt
import shapely.geometry
import geopandas as gpd
from affine import Affine
import rasterio.features
from tqdm import tqdm  # Progress bar
import gc  # Garbage Collector for memory management

import ee

# ============================================
# 1) CONFIGURATION
# ============================================

# --- INPUT: The consolidated PKL from step 02a ---
INPUT_PKL = r"D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\chronicle_df_with_pfdi_FULL.pkl"

# --- OUTPUT: Where rain data will be saved (Updated to network path) ---
OUT_DIR = r"\\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle"
OUT_FINAL_PKL = os.path.join(OUT_DIR, "chronicle_urban_df_with_IMERG_FULL.pkl")

# IMERG Constants (Updated to V07)
# Data available from June 2000
IMERG_START_DATE = pd.Timestamp("2000-06-01") 
SCALE = 0.1  # 0.1 Degree resolution
CRS = 'EPSG:4326'

# Batch Settings
BATCH_SIZE = 1000 
N_BATCHES_TO_RUN = 900  

# ============================================
# 2) HELPERS
# ============================================

def ensure_out_dir(path):
    """Create output directory if it doesn't exist."""
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

def initialize_ee():
    """Initialize Earth Engine."""
    try:
        ee.Initialize()
        print("Earth Engine initialized.")
    except Exception:
        print("Authenticating Earth Engine...")
        ee.Authenticate()
        ee.Initialize()
        print("Earth Engine initialized after auth.")

def get_next_batch_index(out_dir):
    """
    Scans output directory for 'imerg_batch_XXXX.pkl' to determine 
    the next batch number for file naming.
    """
    if not os.path.exists(out_dir):
        return 0
    
    pattern = os.path.join(out_dir, "imerg_batch_*.pkl")
    files = glob.glob(pattern)
    
    if not files:
        return 0
    
    max_batch = -1
    for f in files:
        try:
            filename = os.path.basename(f)
            num_part = filename.split('_')[-1].split('.')[0]
            batch_num = int(num_part)
            if batch_num > max_batch:
                max_batch = batch_num
        except ValueError:
            continue
            
    return max_batch + 1

def extract_rain_data(event_row):
    """
    Extracts IMERG rain matrix, metadata, and mask for a single event.
    Updated for V07: Band name changed from 'precipitationCal' to 'precipitation'.
    """
    try:
        # 1. Geometry Setup
        if isinstance(event_row['geometry_wkt'], str):
            poly_geom = shapely.wkt.loads(event_row['geometry_wkt'])
        else:
            poly_geom = event_row['geometry_wkt']
            
        bounds = poly_geom.bounds 
        roi = ee.Geometry.BBox(*bounds)
        
        # 2. Time Window Calculation
        start_t = event_row['start_time'] - pd.Timedelta(hours=72)
        end_t = event_row['end_time'] + pd.Timedelta(hours=24) 
        
        # 3. GEE Request (Updated band name to 'precipitation')
        imerg_type = 'final'
        imerg_coll = ee.ImageCollection("NASA/GPM_L3/IMERG_V07") \
            .select('precipitation') \
            .filterBounds(roi) \
            .filterDate(start_t, end_t)
        
        if imerg_coll.size().getInfo() == 0:
            imerg_type = 'late'
            imerg_coll = ee.ImageCollection("NASA/GPM_L3/IMERG_V07_LATE") \
                .select('precipitation') \
                .filterBounds(roi) \
                .filterDate(start_t, end_t)

        if imerg_coll.size().getInfo() == 0:
            return None, None, None, 'missing'

        # 4. Download Data
        stack = imerg_coll.toBands()
        pixel_dict = stack.sampleRectangle(region=roi, defaultValue=0).getInfo()
        properties = pixel_dict['properties']
        
        # 5. Parse & Stack Arrays
        band_keys = sorted(list(properties.keys()))
        arrays_list = [np.array(properties[b], dtype=np.float32) for b in band_keys]
        rain_matrix = np.stack(arrays_list)
        
        # 6. Create Metadata
        height, width = rain_matrix.shape[1], rain_matrix.shape[2]
        min_lon, min_lat, max_lon, max_lat = bounds
        transform = Affine(SCALE, 0, min_lon, 0, -SCALE, max_lat)
        
        meta = {
            'origin_top_left': (max_lat, min_lon),
            'scale': SCALE,
            'shape': (height, width),
            'timestamps': band_keys
        }

        # 7. Create Binary Mask
        mask = rasterio.features.rasterize(
            [(poly_geom, 1)],
            out_shape=(height, width),
            transform=transform,
            fill=0,
            all_touched=True,
            dtype=np.uint8
        )
        
        return rain_matrix, mask, meta, imerg_type

    except Exception as e:
        print(f"Error processing ID {event_row.get('event_id')}: {e}")
        return None, None, None, 'error'

# %%
# ============================================
# 3) INITIALIZATION
# ============================================
initialize_ee()
ensure_out_dir(OUT_DIR)

print(f"Loading full dataset: {INPUT_PKL}")
if not os.path.exists(INPUT_PKL):
    raise FileNotFoundError(f"Input file not found: {INPUT_PKL}.")

df = pd.read_pickle(INPUT_PKL)
df = df.replace([np.inf, -np.inf], np.nan)

# Ensure datetime format
if not pd.api.types.is_datetime64_any_dtype(df['start_time']):
    df['start_time'] = pd.to_datetime(df['start_time'], unit='s')
if not pd.api.types.is_datetime64_any_dtype(df['end_time']):
    df['end_time'] = pd.to_datetime(df['end_time'], unit='s')

# Filter for IMERG Era (Data from June 2000 onwards)
df_valid = df[df['start_time'] >= IMERG_START_DATE].copy()

print(f"Total events in input: {len(df)}")
print(f"Events valid for IMERG V07 (post-2000): {len(df_valid)}")

# ============================================
# 4) SMART BATCH PROCESSING (ID-BASED)
# ============================================

print(f"--- PREPARING WORK PLAN ---")

processed_ids = set()
pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
existing_files = glob.glob(pkl_pattern)

if existing_files:
    print(f"Found {len(existing_files)} existing batch files in network path. Scanning...")
    for f in tqdm(existing_files, desc="Indexing existing data"):
        try:
            df_temp = pd.read_pickle(f)
            if 'event_id' in df_temp.columns:
                # Add IDs to set for O(1) lookup
                processed_ids.update(df_temp['event_id'].tolist())
            del df_temp
        except Exception as e:
            print(f"Skipping corrupted file {f}: {e}")

print(f"Total events already processed: {len(processed_ids)}")

# Filter out what's already done
df_todo = df_valid[~df_valid['event_id'].isin(processed_ids)].copy()
print(f"Events remaining to process: {len(df_todo)}")

if len(df_todo) == 0:
    print("All events are already processed! Nothing to do.")
else:
    start_batch_num = get_next_batch_index(OUT_DIR)
    n_remaining = len(df_todo)
    max_rows_limit = N_BATCHES_TO_RUN * BATCH_SIZE
    stop_at_row = min(n_remaining, max_rows_limit)

    print(f"Plan: Processing {min(N_BATCHES_TO_RUN, (stop_at_row // BATCH_SIZE) + 1)} batches.")
    
    for batch_i in range(0, stop_at_row, BATCH_SIZE):
        current_file_num = start_batch_num + (batch_i // BATCH_SIZE)
        batch_df = df_todo.iloc[batch_i : batch_i + BATCH_SIZE].copy()
        
        print(f"\nProcessing Batch {current_file_num} ({len(batch_df)} events)...")
        
        matrices, masks, metas, types = [], [], [], []
        
        for idx, row in tqdm(batch_df.iterrows(), total=len(batch_df), desc=f"Batch {current_file_num}"):
            # Calls the updated V07 extraction function
            mat, msk, mt, itype = extract_rain_data(row)
            matrices.append(mat)
            masks.append(msk)
            metas.append(mt)
            types.append(itype)
        
        # Assign results to the batch dataframe
        batch_df['imerg_matrix'] = matrices
        batch_df['imerg_mask'] = masks
        batch_df['imerg_meta'] = metas
        batch_df['imerg_type'] = types
        
        # Save with network error handling
        out_path = os.path.join(OUT_DIR, f"imerg_batch_{current_file_num:04d}.pkl")
        try:
            batch_df.to_pickle(out_path)
            print(f"Successfully saved to network: {out_path}")
        except Exception as e:
            print(f"CRITICAL ERROR: Could not save {out_path}. Network might be down. Error: {e}")
            # Optional: break or continue depending on your preference
        
        # Clear memory
        del batch_df, matrices, masks, metas, types
        gc.collect()

    print("\n--- BATCH LIMIT REACHED OR PROCESSING FINISHED ---")
# Out:
# Earth Engine initialized.
# Loading full dataset: D:\Development\RESEARCH\urban_flood_database\chronicle\hydromerit_pluvial_outputs\chronicle_df_with_pfdi_FULL.pkl
# Total events in input: 882957
# Events valid for IMERG V07 (post-2000): 882661
# --- PREPARING WORK PLAN ---
# Found 487 existing batch files in network path. Scanning...
# Indexing existing data: 100%|████████████████████████████████████████████████████████| 487/487 [08:16<00:00,  1.02s/it]
# Total events already processed: 487000
# Events remaining to process: 395661
# Plan: Processing 396 batches.
#
# Processing Batch 487 (1000 events)...
# Batch 487: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [22:27<00:00,  1.35s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0487.pkl
#
# Processing Batch 488 (1000 events)...
# Batch 488: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:59<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0488.pkl
#
# Processing Batch 489 (1000 events)...
# Batch 489: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:23<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0489.pkl
#
# Processing Batch 490 (1000 events)...
# Batch 490: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:14<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0490.pkl
#
# Processing Batch 491 (1000 events)...
# Batch 491: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:40<00:00,  1.06s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0491.pkl
#
# Processing Batch 492 (1000 events)...
# Batch 492: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:46<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0492.pkl
#
# Processing Batch 493 (1000 events)...
# Batch 493: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:26<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0493.pkl
#
# Processing Batch 494 (1000 events)...
# Batch 494: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:46<00:00,  1.01s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0494.pkl
#
# Processing Batch 495 (1000 events)...
# Batch 495: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [18:17<00:00,  1.10s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0495.pkl
#
# Processing Batch 496 (1000 events)...
# Batch 496: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:00<00:00,  1.02s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0496.pkl
#
# Processing Batch 497 (1000 events)...
# Batch 497: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:13<00:00,  1.03s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0497.pkl
#
# Processing Batch 498 (1000 events)...
# Batch 498: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:07<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0498.pkl
#
# Processing Batch 499 (1000 events)...
# Batch 499: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:44<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0499.pkl
#
# Processing Batch 500 (1000 events)...
# Batch 500: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:45<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0500.pkl
#
# Processing Batch 501 (1000 events)...
# Batch 501: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:48<00:00,  1.07s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0501.pkl
#
# Processing Batch 502 (1000 events)...
# Batch 502: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:07<00:00,  1.03s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0502.pkl
#
# Processing Batch 503 (1000 events)...
# Batch 503: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [18:33<00:00,  1.11s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0503.pkl
#
# Processing Batch 504 (1000 events)...
# Batch 504: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [19:35<00:00,  1.18s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0504.pkl
#
# Processing Batch 505 (1000 events)...
# Batch 505: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:55<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0505.pkl
#
# Processing Batch 506 (1000 events)...
# Batch 506: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:11<00:00,  1.03s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0506.pkl
#
# Processing Batch 507 (1000 events)...
# Batch 507: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:26<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0507.pkl
#
# Processing Batch 508 (1000 events)...
# Batch 508: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:24<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0508.pkl
#
# Processing Batch 509 (1000 events)...
# Batch 509: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:03<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0509.pkl
#
# Processing Batch 510 (1000 events)...
# Batch 510: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:21<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0510.pkl
#
# Processing Batch 511 (1000 events)...
# Batch 511: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:40<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0511.pkl
#
# Processing Batch 512 (1000 events)...
# Batch 512: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:58<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0512.pkl
#
# Processing Batch 513 (1000 events)...
# Batch 513: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:14<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0513.pkl
#
# Processing Batch 514 (1000 events)...
# Batch 514: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:32<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0514.pkl
#
# Processing Batch 515 (1000 events)...
# Batch 515: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:10<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0515.pkl
#
# Processing Batch 516 (1000 events)...
# Batch 516:  73%|█████████████████████████████████████████████████▋                  | 731/1000 [10:22<08:31,  1.90s/it]
# Error processing ID 517034: Response size exceeds limit
# Batch 516: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:16<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0516.pkl
#
# Processing Batch 517 (1000 events)...
# Batch 517: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0517.pkl
#
# Processing Batch 518 (1000 events)...
# Batch 518: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:13<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0518.pkl
#
# Processing Batch 519 (1000 events)...
# Batch 519: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:11<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0519.pkl
#
# Processing Batch 520 (1000 events)...
# Batch 520: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:54<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0520.pkl
#
# Processing Batch 521 (1000 events)...
# Batch 521: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:27<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0521.pkl
#
# Processing Batch 522 (1000 events)...
# Batch 522: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:14<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0522.pkl
#
# Processing Batch 523 (1000 events)...
# Batch 523: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:49<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0523.pkl
#
# Processing Batch 524 (1000 events)...
# Batch 524: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:12<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0524.pkl
#
# Processing Batch 525 (1000 events)...
# Batch 525: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:29<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0525.pkl
#
# Processing Batch 526 (1000 events)...
# Batch 526: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:43<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0526.pkl
#
# Processing Batch 527 (1000 events)...
# Batch 527: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [18:43<00:00,  1.12s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0527.pkl
#
# Processing Batch 528 (1000 events)...
# Batch 528: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:33<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0528.pkl
#
# Processing Batch 529 (1000 events)...
# Batch 529: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:33<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0529.pkl
#
# Processing Batch 530 (1000 events)...
# Batch 530: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:35<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0530.pkl
#
# Processing Batch 531 (1000 events)...
# Batch 531: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:52<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0531.pkl
#
# Processing Batch 532 (1000 events)...
# Batch 532: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:23<00:00,  1.02it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0532.pkl
#
# Processing Batch 533 (1000 events)...
# Batch 533: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:42<00:00,  1.06s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0533.pkl
#
# Processing Batch 534 (1000 events)...
# Batch 534: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:07<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0534.pkl
#
# Processing Batch 535 (1000 events)...
# Batch 535: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:06<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0535.pkl
#
# Processing Batch 536 (1000 events)...
# Batch 536: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:01<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0536.pkl
#
# Processing Batch 537 (1000 events)...
# Batch 537: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:08<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0537.pkl
#
# Processing Batch 538 (1000 events)...
# Batch 538: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [13:52<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0538.pkl
#
# Processing Batch 539 (1000 events)...
# Batch 539: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:59<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0539.pkl
#
# Processing Batch 540 (1000 events)...
# Batch 540: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:44<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0540.pkl
#
# Processing Batch 541 (1000 events)...
# Batch 541: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:06<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0541.pkl
#
# Processing Batch 542 (1000 events)...
# Batch 542: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:18<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0542.pkl
#
# Processing Batch 543 (1000 events)...
# Batch 543: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:20<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0543.pkl
#
# Processing Batch 544 (1000 events)...
# Batch 544: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:36<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0544.pkl
#
# Processing Batch 545 (1000 events)...
# Batch 545: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:36<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0545.pkl
#
# Processing Batch 546 (1000 events)...
# Batch 546: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:23<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0546.pkl
#
# Processing Batch 547 (1000 events)...
# Batch 547: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:40<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0547.pkl
#
# Processing Batch 548 (1000 events)...
# Batch 548: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:37<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0548.pkl
#
# Processing Batch 549 (1000 events)...
# Batch 549: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:41<00:00,  1.00s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0549.pkl
#
# Processing Batch 550 (1000 events)...
# Batch 550: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:13<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0550.pkl
#
# Processing Batch 551 (1000 events)...
# Batch 551: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:46<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0551.pkl
#
# Processing Batch 552 (1000 events)...
# Batch 552: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:13<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0552.pkl
#
# Processing Batch 553 (1000 events)...
# Batch 553: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:18<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0553.pkl
#
# Processing Batch 554 (1000 events)...
# Batch 554: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:00<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0554.pkl
#
# Processing Batch 555 (1000 events)...
# Batch 555: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:33<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0555.pkl
#
# Processing Batch 556 (1000 events)...
# Batch 556: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:55<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0556.pkl
#
# Processing Batch 557 (1000 events)...
# Batch 557: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0557.pkl
#
# Processing Batch 558 (1000 events)...
# Batch 558: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:12<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0558.pkl
#
# Processing Batch 559 (1000 events)...
# Batch 559: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0559.pkl
#
# Processing Batch 560 (1000 events)...
# Batch 560: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:18<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0560.pkl
#
# Processing Batch 561 (1000 events)...
# Batch 561: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:03<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0561.pkl
#
# Processing Batch 562 (1000 events)...
# Batch 562: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:51<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0562.pkl
#
# Processing Batch 563 (1000 events)...
# Batch 563: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:36<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0563.pkl
#
# Processing Batch 564 (1000 events)...
# Batch 564: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:50<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0564.pkl
#
# Processing Batch 565 (1000 events)...
# Batch 565: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:48<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0565.pkl
#
# Processing Batch 566 (1000 events)...
# Batch 566: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:00<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0566.pkl
#
# Processing Batch 567 (1000 events)...
# Batch 567: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:26<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0567.pkl
#
# Processing Batch 568 (1000 events)...
# Batch 568: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:15<00:00,  1.02it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0568.pkl
#
# Processing Batch 569 (1000 events)...
# Batch 569: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:22<00:00,  1.04s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0569.pkl
#
# Processing Batch 570 (1000 events)...
# Batch 570: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:06<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0570.pkl
#
# Processing Batch 571 (1000 events)...
# Batch 571: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:47<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0571.pkl
#
# Processing Batch 572 (1000 events)...
# Batch 572: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:56<00:00,  1.08s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0572.pkl
#
# Processing Batch 573 (1000 events)...
# Batch 573: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:30<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0573.pkl
#
# Processing Batch 574 (1000 events)...
# Batch 574: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:52<00:00,  1.07s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0574.pkl
#
# Processing Batch 575 (1000 events)...
# Batch 575: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [28:17<00:00,  1.70s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0575.pkl
#
# Processing Batch 576 (1000 events)...
# Batch 576: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:33<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0576.pkl
#
# Processing Batch 577 (1000 events)...
# Batch 577: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:09<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0577.pkl
#
# Processing Batch 578 (1000 events)...
# Batch 578: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:06<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0578.pkl
#
# Processing Batch 579 (1000 events)...
# Batch 579: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:33<00:00,  1.01it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0579.pkl
#
# Processing Batch 580 (1000 events)...
# Batch 580: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:39<00:00,  1.00it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0580.pkl
#
# Processing Batch 581 (1000 events)...
# Batch 581: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:35<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0581.pkl
#
# Processing Batch 582 (1000 events)...
# Batch 582: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:14<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0582.pkl
#
# Processing Batch 583 (1000 events)...
# Batch 583: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:55<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0583.pkl
#
# Processing Batch 584 (1000 events)...
# Batch 584: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:49<00:00,  1.01s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0584.pkl
#
# Processing Batch 585 (1000 events)...
# Batch 585: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:29<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0585.pkl
#
# Processing Batch 586 (1000 events)...
# Batch 586: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:58<00:00,  1.04it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0586.pkl
#
# Processing Batch 587 (1000 events)...
# Batch 587: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:39<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0587.pkl
#
# Processing Batch 588 (1000 events)...
# Batch 588: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:19<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0588.pkl
#
# Processing Batch 589 (1000 events)...
# Batch 589: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:16<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0589.pkl
#
# Processing Batch 590 (1000 events)...
# Batch 590: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:36<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0590.pkl
#
# Processing Batch 591 (1000 events)...
# Batch 591: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:57<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0591.pkl
#
# Processing Batch 592 (1000 events)...
# Batch 592: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:13<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0592.pkl
#
# Processing Batch 593 (1000 events)...
# Batch 593: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0593.pkl
#
# Processing Batch 594 (1000 events)...
# Batch 594: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:34<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0594.pkl
#
# Processing Batch 595 (1000 events)...
# Batch 595: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:41<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0595.pkl
#
# Processing Batch 596 (1000 events)...
# Batch 596: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [24:35<00:00,  1.48s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0596.pkl
#
# Processing Batch 597 (1000 events)...
# Batch 597: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:48<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0597.pkl
#
# Processing Batch 598 (1000 events)...
# Batch 598: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:45<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0598.pkl
#
# Processing Batch 599 (1000 events)...
# Batch 599: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0599.pkl
#
# Processing Batch 600 (1000 events)...
# Batch 600: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:06<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0600.pkl
#
# Processing Batch 601 (1000 events)...
# Batch 601: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [20:26<00:00,  1.23s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0601.pkl
#
# Processing Batch 602 (1000 events)...
# Batch 602: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [18:13<00:00,  1.09s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0602.pkl
#
# Processing Batch 603 (1000 events)...
# Batch 603: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:28<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0603.pkl
#
# Processing Batch 604 (1000 events)...
# Batch 604: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:53<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0604.pkl
#
# Processing Batch 605 (1000 events)...
# Batch 605: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:45<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0605.pkl
#
# Processing Batch 606 (1000 events)...
# Batch 606: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:41<00:00,  1.00s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0606.pkl
#
# Processing Batch 607 (1000 events)...
# Batch 607: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:51<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0607.pkl
#
# Processing Batch 608 (1000 events)...
# Batch 608: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:41<00:00,  1.00s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0608.pkl
#
# Processing Batch 609 (1000 events)...
# Batch 609: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:15<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0609.pkl
#
# Processing Batch 610 (1000 events)...
# Batch 610: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:47<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0610.pkl
#
# Processing Batch 611 (1000 events)...
# Batch 611: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:23<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0611.pkl
#
# Processing Batch 612 (1000 events)...
# Batch 612: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:25<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0612.pkl
#
# Processing Batch 613 (1000 events)...
# Batch 613: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:53<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0613.pkl
#
# Processing Batch 614 (1000 events)...
# Batch 614: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:12<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0614.pkl
#
# Processing Batch 615 (1000 events)...
# Batch 615: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:49<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0615.pkl
#
# Processing Batch 616 (1000 events)...
# Batch 616: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:01<00:00,  1.04it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0616.pkl
#
# Processing Batch 617 (1000 events)...
# Batch 617: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:55<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0617.pkl
#
# Processing Batch 618 (1000 events)...
# Batch 618: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:56<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0618.pkl
#
# Processing Batch 619 (1000 events)...
# Batch 619: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:29<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0619.pkl
#
# Processing Batch 620 (1000 events)...
# Batch 620: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:11<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0620.pkl
#
# Processing Batch 621 (1000 events)...
# Batch 621: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:54<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0621.pkl
#
# Processing Batch 622 (1000 events)...
# Batch 622: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:29<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0622.pkl
#
# Processing Batch 623 (1000 events)...
# Batch 623: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:24<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0623.pkl
#
# Processing Batch 624 (1000 events)...
# Batch 624: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:22<00:00,  1.02it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0624.pkl
#
# Processing Batch 625 (1000 events)...
# Batch 625: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0625.pkl
#
# Processing Batch 626 (1000 events)...
# Batch 626: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:58<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0626.pkl
#
# Processing Batch 627 (1000 events)...
# Batch 627: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:05<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0627.pkl
#
# Processing Batch 628 (1000 events)...
# Batch 628: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:14<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0628.pkl
#
# Processing Batch 629 (1000 events)...
# Batch 629: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:58<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0629.pkl
#
# Processing Batch 630 (1000 events)...
# Batch 630: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:08<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0630.pkl
#
# Processing Batch 631 (1000 events)...
# Batch 631: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:46<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0631.pkl
#
# Processing Batch 632 (1000 events)...
# Batch 632: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:34<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0632.pkl
#
# Processing Batch 633 (1000 events)...
# Batch 633: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:10<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0633.pkl
#
# Processing Batch 634 (1000 events)...
# Batch 634: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:49<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0634.pkl
#
# Processing Batch 635 (1000 events)...
# Batch 635: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:47<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0635.pkl
#
# Processing Batch 636 (1000 events)...
# Batch 636: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:52<00:00,  1.07s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0636.pkl
#
# Processing Batch 637 (1000 events)...
# Batch 637: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:07<00:00,  1.03it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0637.pkl
#
# Processing Batch 638 (1000 events)...
# Batch 638: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:44<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0638.pkl
#
# Processing Batch 639 (1000 events)...
# Batch 639: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:52<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0639.pkl
#
# Processing Batch 640 (1000 events)...
# Batch 640: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [14:59<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0640.pkl
#
# Processing Batch 641 (1000 events)...
# Batch 641: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:14<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0641.pkl
#
# Processing Batch 642 (1000 events)...
# Batch 642: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:37<00:00,  1.07it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0642.pkl
#
# Processing Batch 643 (1000 events)...
# Batch 643: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:54<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0643.pkl
#
# Processing Batch 644 (1000 events)...
# Batch 644: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:59<00:00,  1.04it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0644.pkl
#
# Processing Batch 645 (1000 events)...
# Batch 645: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [17:21<00:00,  1.04s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0645.pkl
#
# Processing Batch 646 (1000 events)...
# Batch 646: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:25<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0646.pkl
#
# Processing Batch 647 (1000 events)...
# Batch 647: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:40<00:00,  1.00s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0647.pkl
#
# Processing Batch 648 (1000 events)...
# Batch 648: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:44<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0648.pkl
#
# Processing Batch 649 (1000 events)...
# Batch 649: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:21<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0649.pkl
#
# Processing Batch 650 (1000 events)...
# Batch 650: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:02<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0650.pkl
#
# Processing Batch 651 (1000 events)...
# Batch 651: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:30<00:00,  1.01it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0651.pkl
#
# Processing Batch 652 (1000 events)...
# Batch 652: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:01<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0652.pkl
#
# Processing Batch 653 (1000 events)...
# Batch 653: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:55<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0653.pkl
#
# Processing Batch 654 (1000 events)...
# Batch 654: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:44<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0654.pkl
#
# Processing Batch 655 (1000 events)...
# Batch 655: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:54<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0655.pkl
#
# Processing Batch 656 (1000 events)...
# Batch 656: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:48<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0656.pkl
#
# Processing Batch 657 (1000 events)...
# Batch 657: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [15:53<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0657.pkl
#
# Processing Batch 658 (1000 events)...
# Batch 658: 100%|███████████████████████████████████████████████████████████████████| 1000/1000 [16:41<00:00,  1.00s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0658.pkl
#
# Processing Batch 659 (1000 events)...
# Batch 659: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:39<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0659.pkl
#
# Processing Batch 660 (1000 events)...
# Batch 660: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [16:03<00:00,  1.04it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0660.pkl
#
# Processing Batch 661 (1000 events)...
# Batch 661: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [16:35<00:00,  1.00it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0661.pkl
#
# Processing Batch 662 (1000 events)...
# Batch 662: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [16:28<00:00,  1.01it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0662.pkl
#
# Processing Batch 663 (1000 events)...
# Batch 663: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [16:19<00:00,  1.02it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0663.pkl
#
# ...
#
# Processing Batch 789 (1000 events)...
# Batch 789: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:24<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0789.pkl
#
# Processing Batch 790 (1000 events)...
# Batch 790: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:44<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0790.pkl
#
# Processing Batch 791 (1000 events)...
# Batch 791: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:16<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0791.pkl
#
# Processing Batch 792 (1000 events)...
# Batch 792: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:08<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0792.pkl
#
# Processing Batch 793 (1000 events)...
# Batch 793: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:45<00:00,  1.21it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0793.pkl
#
# Processing Batch 794 (1000 events)...
# Batch 794: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:20<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0794.pkl
#
# Processing Batch 795 (1000 events)...
# Batch 795: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:39<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0795.pkl
#
# Processing Batch 796 (1000 events)...
# Batch 796: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:00<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0796.pkl
#
# Processing Batch 797 (1000 events)...
# Batch 797: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:33<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0797.pkl
#
# Processing Batch 798 (1000 events)...
# Batch 798: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:17<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0798.pkl
#
# Processing Batch 799 (1000 events)...
# Batch 799: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:54<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0799.pkl
#
# Processing Batch 800 (1000 events)...
# Batch 800: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:09<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0800.pkl
#
# Processing Batch 801 (1000 events)...
# Batch 801: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:06<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0801.pkl
#
# Processing Batch 802 (1000 events)...
# Batch 802: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:14<00:00,  1.17it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0802.pkl
#
# Processing Batch 803 (1000 events)...
# Batch 803: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:20<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0803.pkl
#
# Processing Batch 804 (1000 events)...
# Batch 804: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:50<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0804.pkl
#
# Processing Batch 805 (1000 events)...
# Batch 805: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:50<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0805.pkl
#
# Processing Batch 806 (1000 events)...
# Batch 806: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:52<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0806.pkl
#
# Processing Batch 807 (1000 events)...
# Batch 807: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:43<00:00,  1.21it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0807.pkl
#
# Processing Batch 808 (1000 events)...
# Batch 808: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:55<00:00,  1.05it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0808.pkl
#
# Processing Batch 809 (1000 events)...
# Batch 809: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:01<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0809.pkl
#
# Processing Batch 810 (1000 events)...
# Batch 810: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:20<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0810.pkl
#
# Processing Batch 811 (1000 events)...
# Batch 811: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0811.pkl
#
# Processing Batch 812 (1000 events)...
# Batch 812: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:53<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0812.pkl
#
# Processing Batch 813 (1000 events)...
# Batch 813: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:55<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0813.pkl
#
# Processing Batch 814 (1000 events)...
# Batch 814: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:58<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0814.pkl
#
# Processing Batch 815 (1000 events)...
# Batch 815: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:01<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0815.pkl
#
# Processing Batch 816 (1000 events)...
# Batch 816: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [17:26<00:00,  1.05s/it]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0816.pkl
#
# Processing Batch 817 (1000 events)...
# Batch 817: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:59<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0817.pkl
#
# Processing Batch 818 (1000 events)...
# Batch 818: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:52<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0818.pkl
#
# Processing Batch 819 (1000 events)...
# Batch 819: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:50<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0819.pkl
#
# Processing Batch 820 (1000 events)...
# Batch 820: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:18<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0820.pkl
#
# Processing Batch 821 (1000 events)...
# Batch 821: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:05<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0821.pkl
#
# Processing Batch 822 (1000 events)...
# Batch 822: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0822.pkl
#
# Processing Batch 823 (1000 events)...
# Batch 823: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:43<00:00,  1.21it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0823.pkl
#
# Processing Batch 824 (1000 events)...
# Batch 824: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:35<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0824.pkl
#
# Processing Batch 825 (1000 events)...
# Batch 825: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:58<00:00,  1.11it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0825.pkl
#
# Processing Batch 826 (1000 events)...
# Batch 826: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:08<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0826.pkl
#
# Processing Batch 827 (1000 events)...
# Batch 827: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:24<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0827.pkl
#
# Processing Batch 828 (1000 events)...
# Batch 828: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:07<00:00,  1.10it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0828.pkl
#
# Processing Batch 829 (1000 events)...
# Batch 829: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:21<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0829.pkl
#
# Processing Batch 830 (1000 events)...
# Batch 830: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0830.pkl
#
# Processing Batch 831 (1000 events)...
# Batch 831: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0831.pkl
#
# Processing Batch 832 (1000 events)...
# Batch 832: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:03<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0832.pkl
#
# Processing Batch 833 (1000 events)...
# Batch 833: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [16:38<00:00,  1.00it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0833.pkl
#
# Processing Batch 834 (1000 events)...
# Batch 834: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:46<00:00,  1.06it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0834.pkl
#
# Processing Batch 835 (1000 events)...
# Batch 835: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:28<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0835.pkl
#
# Processing Batch 836 (1000 events)...
# Batch 836: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:09<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0836.pkl
#
# Processing Batch 837 (1000 events)...
# Batch 837: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:28<00:00,  1.08it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0837.pkl
#
# Processing Batch 838 (1000 events)...
# Batch 838: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [15:20<00:00,  1.09it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0838.pkl
#
# Processing Batch 839 (1000 events)...
# Batch 839: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:33<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0839.pkl
#
# Processing Batch 840 (1000 events)...
# Batch 840: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:50<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0840.pkl
#
# Processing Batch 841 (1000 events)...
# Batch 841: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:25<00:00,  1.16it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0841.pkl
#
# Processing Batch 842 (1000 events)...
# Batch 842: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:35<00:00,  1.14it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0842.pkl
#
# Processing Batch 843 (1000 events)...
# Batch 843: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:09<00:00,  1.18it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0843.pkl
#
# Processing Batch 844 (1000 events)...
# Batch 844: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:48<00:00,  1.13it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0844.pkl
#
# Processing Batch 845 (1000 events)...
# Batch 845: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:51<00:00,  1.12it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0845.pkl
#
# Processing Batch 846 (1000 events)...
# Batch 846: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [14:32<00:00,  1.15it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0846.pkl
#
# Processing Batch 847 (1000 events)...
# Batch 847: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:57<00:00,  1.19it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0847.pkl
#
# Processing Batch 848 (1000 events)...
# Batch 848: 100%|███████████████████████████████████████████████████████████████| 1000/1000 [13:54<00:00,  1.20it/s]
# Successfully saved to network: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle\imerg_batch_0848.pkl
#
# Processing Batch 849 (1000 events)...
# Batch 849:  77%|█████████████████████████████████████████████████▍              | 772/1000 [12:03<03:07,  1.22it/s]

# %%
# ============================================
# 5) FINAL MERGE & CLEANUP (V07 Version)
# ============================================
print("\n--- FINALIZING V07 DATASET ---")
print(f"Merging batches from: {OUT_DIR}")

pkl_pattern = os.path.join(OUT_DIR, "imerg_batch_*.pkl")
all_pkl_files = glob.glob(pkl_pattern)

if not all_pkl_files:
    print("No output files found. Check your OUT_DIR path.")
else:
    df_list = []
    for f in tqdm(all_pkl_files, desc="Loading Batches"):
        try:
            # Code comments must be in English only as per your preference
            df_list.append(pd.read_pickle(f))
        except Exception as e:
            print(f"Error loading {f}: {e}")
            
    if df_list:
        df_results = pd.concat(df_list, ignore_index=True)
        
        # Define relevant columns for V07
        merge_cols = ['event_id', 'imerg_matrix', 'imerg_mask', 'imerg_meta']
        if 'imerg_type' in df_results.columns:
            merge_cols.append('imerg_type')
        
        # Load base dataset to merge with extracted rain data
        df_base = pd.read_pickle(INPUT_PKL)
        
        df_final = df_base.merge(
            df_results[merge_cols], 
            on='event_id', 
            how='inner' 
        )
        
        # Tag data as V07 for future tracking
        if 'imerg_type' in df_final.columns:
            df_final['imerg_type'] = df_final['imerg_type'].fillna('V07_final')
        else:
            df_final['imerg_type'] = 'V07_final'

        # Cleanup and save
        missing_rain_mask = df_final['imerg_matrix'].isnull()
        df_final = df_final[~missing_rain_mask].copy()
        
        df_final.to_pickle(OUT_FINAL_PKL)
        print(f"SUCCESS! Final V07 dataset saved to: {OUT_FINAL_PKL}")
# Out:
# --- FINALIZING V07 DATASET ---
# Merging batches from: \\vscifs\hydrolab1\hydrolab\home\Raz\Research\chronicle
# Loading Batches: 100%|███████████████████████████████████████████████████████████████| 883/883 [05:56<00:00,  2.48it/s]

# %%
df_final

# %%
# Check the distribution of IMERG data quality
print(df_final['imerg_type'].value_counts())

# %% [markdown]
# # HERE SHOULD BE COMPLEMENTERY CODE:
# הקוד צריך לעבור שוב על כל האירועים שהוסרו מהבאצים כי לא היה בהם דאטא.
# הוא יבחן שוב אם יש את הדאטא שלהם בגרסה הטובה ביותר ואם לא אז בגרסה השנייה הפחות טובה.
# הרעיון - לודא שלא נפלו האירועים בגלל מגבלות גישה ועומס על הענן של גוגל בשלב ראשון, ואם לא זה אז האם יש בעיה בזמינות הנתונים עצמם בגרסה המירבית ואז זה יגש לגרסה הפחות טובה.
#
#
# המלצת הגימיני:
#
# # --- COMPLEMENTARY CLEANUP STEP ---
# print("\n--- RUNNING COMPLEMENTARY RECOVERY ---")
#
# # Load the reference (all events) and the current results
# df_base = pd.read_pickle(INPUT_PKL)
# df_final = pd.read_pickle(OUT_FINAL_PKL)
#
# # Find IDs that are in base but NOT in final
# missing_mask = ~df_base['event_id'].isin(df_final['event_id'])
# df_missing = df_base[missing_mask].copy()
#
# print(f"Status check: {len(df_missing)} events are currently missing from the final PKL.")
#
# if len(df_missing) > 0:
#     print(f"Attempting to recover {len(df_missing)} events...")
#     recovered_list = []
#
#     # Try one last time for each missing event
#     for idx, row in tqdm(df_missing.iterrows(), total=len(df_missing), desc="Recovery"):
#         # This will use the Fallback logic (Final -> Late)
#         mat, msk, mt, itype = extract_rain_data(row)
#
#         # Only keep if we actually found data this time
#         if mat is not None:
#             recovered_row = row.to_dict()
#             recovered_row.update({
#                 'imerg_matrix': mat,
#                 'imerg_mask': msk,
#                 'imerg_meta': mt,
#                 'imerg_type': itype
#             })
#             recovered_list.append(recovered_row)
#
#     if recovered_list:
#         df_recovered = pd.DataFrame(recovered_list)
#         # Combine the old final results with the newly recovered ones
#         df_updated = pd.concat([df_final, df_recovered], ignore_index=True)
#
#         # Final save
#         df_updated.to_pickle(OUT_FINAL_PKL)
#         print(f"Recovery successful! Added {len(recovered_list)} events.")
#         print(f"Final count: {len(df_updated)} events.")
#     else:
#         print("No additional data could be recovered (all remaining events likely out of range or truly empty).")

# %%
df_final

# %% [markdown]
# # לעדכן לגרסה V07 של imerg

# %%
700912

# %%
print(ee.ImageCollection("NASA/GPM_L3/IMERG_V06").limit(1, "system:time_start", False).first().date().format().getInfo())

# %%
print(ee.ImageCollection("NASA/GPM_L3/IMERG_V07").limit(1, "system:time_start", False).first().date().format().getInfo())
